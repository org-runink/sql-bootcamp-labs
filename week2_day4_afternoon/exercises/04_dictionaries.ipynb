# %% [markdown]
# # Week 2, day 4 (afternoon) — Worksheet 04: Dictionaries   (L04)
#
# A dictionary stores **key–value pairs**: you look things up by a name you
# chose rather than by a position you have to remember. It is the structure
# almost all real data arrives in — a JSON record, a config file, a row keyed
# by column name.
#
# Run the setup cell once, then work down. **Questions 3 and 9 are supposed to
# raise errors** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_L04]_Python_data_structures.pdf`, slides 31–47.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 04 — Dictionaries. Run this once.
contact = {"name": "Ada", "phone": "416-555-0134", "city": "Toronto"}
grocery_items = {"milk": 2, "beef": 1, "eggs": 12, "bread": 3}
tweet = {
    "user": {"handle": "@dataninja", "followers": 1200},
    "text": "sets are just lists that refuse to repeat themselves",
    "tags": ["python", "data"],
}

print("contact:      ", contact)
print("grocery_items:", grocery_items)
print("tweet:        ", tweet)

# %% [markdown]
# PART A — Creating and reading a dictionary

# %% [markdown]
# ### Question 1
#
# Warm-up. Build the same idea three ways and print each, plus the `type()` of the first: `car` as a literal with keys `"brand"`, `"model"` and `"year"`; `car2` using the `dict()` constructor with keyword arguments; and `blank` using `dict.fromkeys()` over the keys `["brand", "model", "year"]` with the default value `0`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Read values out with square brackets. Print the name from `contact`. Then, from `tweet`, print the handle (which is nested one level down), the number of followers, and the first tag.
# > **HINT:** `tweet["user"]` hands you another dictionary, so you can index it again. `tweet["tags"]` hands you a list, so index it with a number.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Ada has no email on file. Print `contact["email"]`. Run it, read the error, and write in a comment what Python is complaining about. This cell is meant to fail.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Now ask the same question safely. Print `contact.get("email")`. Then print `contact.get("email", "none on file")`. Then print `grocery_items.get("milk", -1)` and `grocery_items.get("caviar", -1)`, and say in a comment when you would prefer `[]` over `.get()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Changing a dictionary

# %% [markdown]
# ### Question 5
#
# Dictionaries are mutable and dynamic. Print `contact` after each of these: add an `"email"` key with the value `"ada@example.com"`; change `"city"` to `"Ottawa"`; and `del` the `"phone"` key.
# > **HINT:** adding a key and changing a key are the same statement. Which one happens depends only on whether the key already existed.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Print `grocery_items` after each step: `update` it with `{"milk": 3, "rice": 1}`; `pop` the `"eggs"` key, printing the value it hands back; and `popitem()`, printing what that hands back. Then copy the dictionary, `clear()` the copy, and print both.
# > **HINT:** notice that one `update` call both changed an existing key and added a new one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Views, keys, and iteration

# %% [markdown]
# ### Question 7
#
# Print `contact.keys()`, `contact.values()` and `contact.items()` exactly as they come back, then print `len(contact)`. Now print `list(contact.keys())` and plain `list(contact)`, and say in a comment what the difference is between the first three prints and the last two.
# > **CAREFUL:** `keys()` does not return a list. Look closely at what gets printed.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Loop over `grocery_items` twice. First loop over it directly and print each key. Then loop over `.items()`, unpacking into `item` and `quantity`, and print a line like `milk: 3` for each. Use an f-string for the second one.
# > **HINT:** looping a dictionary gives you its keys, not its values. `.items()` is how you get both at once.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Three rules about keys, in one cell. Print `{"a": 1, "b": 2, "a": 99}` and explain the result in a comment. Print a dictionary that uses the tuple `(43.65, -79.38)` as a key. Then try to use the list `[43.65, -79.38]` as a key and let it fail. This cell is meant to fail at the end.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Print whether `"milk"` is in `grocery_items`, and whether `3` is in `grocery_items`. One of those is `True` and one is `False` — explain why in a comment, then print a test that correctly asks whether the quantity `3` appears anywhere.
# > **CAREFUL:** `in` on a dictionary searches the keys only.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Stretch. In one line each, build and print: `doubled`, mapping every item in `grocery_items` to twice its quantity; `plentiful`, holding only the pairs with a quantity above 1; and `by_quantity`, the same dictionary with keys and values swapped. Then print `len(grocery_items)` and `len(by_quantity)` and explain any difference.
# > **HINT:** `{key_expression: value_expression for k, v in d.items()}`.

# %%
############################
## Your Code Here
############################
