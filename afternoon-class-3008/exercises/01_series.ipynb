# %% [markdown]
# # Afternoon class 30/08 — Worksheet 01: Series   (L01)
#
# A Series is one column: values plus the labels that identify them. That second
# half is the whole point — it is what a Python list does not have, and it is why
# the rest of Pandas behaves the way it does.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L01]_introduction_to_Pandas.pdf`, slides 2–20.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 01 — Series. Run this once.
import pandas as pd

# The three students from the lecture slides.
ages = pd.Series([22, 24, 21], index=["Abdullah", "Sara", "Ahmed"])

# A plain Series with no index given, so Pandas supplies one.
plain = pd.Series([10, 20, 30])

# Marks, used later for filtering.
marks = pd.Series([85, 90, 75], index=["S1", "S2", "S3"])

print(ages)
print()
print("pandas version:", pd.__version__)

# %% [markdown]
# PART A — values and labels

# %% [markdown]
# ### Question 1
#
# Print `ages` on its own, then print `ages.values` and `ages.index` on separate labelled lines. Look at what type each one is — the values and the labels are stored separately, and that separation is the thing to notice.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Select Sara's age two ways: by her label, `ages["Sara"]`, and by position with `ages.iloc[1]`. Print both. Then print `plain[0]` and explain to yourself why that one is ambiguous in a way `ages["Sara"]` is not.
# > **NOTE:** `plain` has the default index `0, 1, 2`, so its labels *are* integers. That is exactly when label-lookup and position-lookup stop being distinguishable.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print `ages.mean()`. The lecture slide shows the answer as `22.33`. Print the value Python actually gives you, and then print `round(ages.mean(), 2)` next to it. State which of the two the slide is showing.
# > **NOTE:** the slide is not wrong about the arithmetic — it is wrong about what Python prints. Those are different claims, and only one of them is what you will see on screen.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Print `ages.max()`, `ages.min()`, and `ages.sum()`, each labelled. Then print `len(ages)` and use it with `.sum()` to compute the mean by hand, confirming it matches `.mean()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — comparisons produce a Series, not a single answer

# %% [markdown]
# ### Question 5
#
# Print `ages > 21`. Read the result carefully: it is not one True/False, it is one per student. Then print its `.dtype`, and print `(ages > 21).sum()` — explain to yourself why summing booleans is a count.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Use the comparison from Q5 to keep only the students over 21: print `ages[ages > 21]`. Then print how many rows came back, and confirm it equals the count you got from `.sum()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Ahmed is exactly 21. Print `ages > 21`, `ages >= 21` and count the Trues in each. Say in a comment which operator you would want if the question were 'who is at least 21', and which if it were 'who is over 21'.
# > **NOTE:** boundary values are where filters quietly go wrong. Ahmed sits exactly on the boundary, so he is the whole test.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — the index is doing work you did not ask for

# %% [markdown]
# ### Question 8
#
# Build `bonus = pd.Series([1, 1, 1], index=["Ahmed", "Sara", "Abdullah"])` — note the order is reversed from `ages`. Print `ages + bonus`. Check whether Abdullah got 23 or 25, and say which order Pandas used.
# > **NOTE:** this is the single most important behaviour in the whole library, and it is the reason a Series is not a list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Now build `partial = pd.Series([1, 1], index=["Sara", "Nadia"])` and print `ages + partial`. Three of the four labels come back as `NaN`. Print the result's `.dtype` too, and note that whole-number ages have become floats.
# > **NOTE:** Nadia is not in `ages` at all, and Pandas did not complain. It produced a row for her anyway. A missing label is not an error — it is a `NaN`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, ask for a label that does not exist: print `ages["Nadia"]`. **This is supposed to fail.** Read the exception name and the message.
# > **NOTE:** compare this with Q9. Adding a missing label gave you `NaN` and no complaint; *asking* for one raises. Same missing label, two completely different outcomes.

# %%
############################
## Your Code Here
############################
