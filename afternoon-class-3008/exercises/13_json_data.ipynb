# %% [markdown]
# # Afternoon class 30/08 — Worksheet 13: JSON data   (L03)
#
# JSON is what an API hands you. When it is already flat it loads like a CSV;
# when it is nested you have to decide what the table should look like, because
# a table cannot hold a dictionary in a cell and still be useful.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L03]_reading_and_writing_data_with_Pandas.pdf`,
# slides 18–22.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 13 — JSON. Run this once.
import json
import pandas as pd

#   data/customers.json      120 flat records
#   data/orders_nested.json   80 records, each with a nested "customer" object

with open("data/orders_nested.json") as fh:
    nested_raw = json.load(fh)

print("first nested record:")
print(json.dumps(nested_raw[0], indent=2))

# %% [markdown]
# PART A — flat JSON

# %% [markdown]
# ### Question 1
#
# Read the flat file: `pd.read_json("data/customers.json")`. Print the shape, the columns and the dtypes.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# This file is a list of objects — `orient="records"` in the deck's terms. Print the first 120 characters of the raw file to confirm the shape, then print `cust["Region"].value_counts()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Compare it with the CSV route. Read `data/sales.csv` and `data/customers.json` and print the type of each. Then say what JSON gave you that CSV could not, and vice versa.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — nested JSON

# %% [markdown]
# ### Question 4
#
# Now read the nested file with the same function: `pd.read_json("data/orders_nested.json")`. Print the shape, the columns, and then print `type()` of the value in the first row's `customer` cell.
# > **NOTE:** this does not raise. Look carefully at what is inside the `customer` column before deciding it worked.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Try to use that column as if it were data: print `nested["customer"].value_counts().head(3)` and then try `nested["customer"].str.upper().head(3)`. Wrap each in a `try` so the sheet continues.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Flatten it properly with `pd.json_normalize(nested_raw)`. Print the shape and the column names, and compare with Q4.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Now the flattened columns are usable. Print `flat["customer.region"].value_counts()` and the mean `Sales` per region using `groupby`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — writing JSON back out

# %% [markdown]
# ### Question 8
#
# Take the first three rows of `flat` and write them out both ways: `to_json(orient="records", indent=2)` and `to_json(orient="columns", indent=2)`. Print both strings.
# > **NOTE:** the deck says `columns` is the pandas default. Check which one you would actually want to hand to another system.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Round-trip it. Write `small` to `/tmp/out.json` with `orient="records"`, read it back with `pd.read_json`, and confirm the result equals what you wrote with `.equals()`. Then do the same with the default orient and compare.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, hand `read_json` something that is not JSON: `pd.read_json("data/sales.csv")`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
