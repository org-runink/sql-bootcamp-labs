# %% [markdown]
# # Afternoon class 30/08 — Worksheet 09: apply and map   (L02)
#
# `map` translates values through a lookup. `apply` runs your own function over
# them. The deck gives you a clean rule for choosing between them; this sheet is
# mostly about what each one does with the cases the rule does not cover.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L02]_Pandas_core_functionalities.pdf`,
# slides 21–25.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 09 — apply and map. Run this once.
import pandas as pd

# The deck's example, plus one student it does not account for.
grades = pd.DataFrame(
    {"Grade": ["A", "B", "C", "D"]},
    index=["S1", "S2", "S3", "S4"],
)
grade_map = {"A": "Excellent", "B": "Good", "C": "Needs Review"}

marks = pd.Series([85, 90, 55, 72], index=["S1", "S2", "S3", "S4"], name="Marks")

sales = pd.read_csv("data/sales.csv")

print(grades)
print()
print("grade_map covers:", list(grade_map))

# %% [markdown]
# PART A — apply

# %% [markdown]
# ### Question 1
#
# Write the deck's `pass_fail(mark)` function — `"Pass"` if the mark is at least 60, otherwise `"Fail"` — and print `marks.apply(pass_fail)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Do the same thing without a named function, using a lambda: print `marks.apply(lambda m: "Pass" if m >= 60 else "Fail")`. Confirm it matches Q1 with `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now do it with no function at all: print `marks.ge(60).map({True: "Pass", False: "Fail"})`, and also the plain vectorised form using `numpy.where` is not needed — instead just print `(marks >= 60)`. Compare the three ways of expressing one rule.
# > **NOTE:** `apply` runs your Python function once per row. The comparison operators do the same work in one vectorised step, which matters when there are a million rows rather than four.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — map, and the value nobody planned for

# %% [markdown]
# ### Question 4
#
# Print `grades["Grade"].map(grade_map)`. Four students went in. Look at what came back for `S4`, whose grade is `D`.
# > **NOTE:** the deck's version of this slide uses exactly three students with exactly the three grades in the dictionary. Nothing in it can go wrong.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Catch it before it happens. Print the set of grades present in the data, the set of keys the map covers, and the difference between them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Two ways to handle the gap. Print `grades["Grade"].map(grade_map).fillna("Unknown")`, and then use a dict subclass that supplies a default: `grades["Grade"].map(lambda g: grade_map.get(g, "Unknown"))`. Confirm they agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — on the real file

# %% [markdown]
# ### Question 7
#
# On `sales`, create a `Band` column using `apply`: `"large"` if `Sales` is over 1000, else `"small"`. Print `value_counts()` of the result and check the two counts add to 300.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Use `map` to translate the real `Region` column through a partial lookup: map only `{"Ontario": "Central", "West": "Pacific"}` and print `value_counts(dropna=False)` of the result.
# > **NOTE:** pass `dropna=False`, or the rows that failed to map disappear from the tally as well as from the data.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Apply a function across a whole row instead of one column. Print the first five results of `sales.apply(lambda r: r["Sales"] - r["Profit"], axis=1)`, and compare with the vectorised `sales["Sales"] - sales["Profit"]`.
# > **NOTE:** `axis=1` is what makes `apply` see rows. Without it your function is handed whole columns and the result is nonsense — or an error.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, apply a function that cannot cope with one of the values. Run `marks.apply(lambda m: 100 / (m - 72))` — `S4` has a mark of exactly 72. **This is supposed to fail.** Read the exception.
# > **NOTE:** compare with Q4. `map` met a value it could not handle and returned `NaN`; `apply` met one and stopped everything.

# %%
############################
## Your Code Here
############################
