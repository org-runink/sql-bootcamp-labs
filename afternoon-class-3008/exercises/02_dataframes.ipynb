# %% [markdown]
# # Afternoon class 30/08 — Worksheet 02: DataFrames   (L01)
#
# A DataFrame is a collection of Series sharing one index. This sheet builds them
# from the two shapes you will actually meet — a dict of columns and a list of
# records — and then looks at what Pandas decided about your data without asking.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L01]_introduction_to_Pandas.pdf`, slides 21–30.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 02 — DataFrames. Run this once.
import pandas as pd

# Shape 1: a dict of columns. Each key becomes a column.
students = pd.DataFrame({
    "Name": ["Abdullah", "Sara", "Ahmed"],
    "Age": [22, 24, 21],
    "City": ["Riyadh", "Jeddah", "Dammam"],
})

# Shape 2: a list of records. Each dict becomes a ROW.
records = pd.DataFrame([
    {"Name": "Lina", "Age": 23, "City": "Riyadh"},
    {"Name": "Omar", "Age": 25, "City": "Jeddah"},
    {"Name": "Nadia", "Age": 22},          # note: no City
])

print(students)
print()
print(records)

# %% [markdown]
# PART A — two ways in, one thing out

# %% [markdown]
# ### Question 1
#
# Print `students` and `records`. Then print `students.shape` and `records.shape`. Confirm that the dict-of-columns form and the list-of-records form produced the same kind of object.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Nadia's record had no `City` key. Print `records` again and find what Pandas put there. Then print `records.isna().sum()` to count the missing values per column.
# > **NOTE:** you did not ask for a `City` value for Nadia and you did not get an error. You got a filled-in blank.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print `students.columns` and `students.index`, labelled. Then print `students.dtypes`. Read the dtype of `Name` carefully and write down what it says.
# > **NOTE:** most Pandas tutorials — and the lecture slides — will tell you a text column is `object`. Check what this Pandas says.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Print `students["Age"]` and then `students[["Age"]]`. They look almost the same. Print `type(...)` of each to see what actually came back, and print `.shape` of each.
# > **NOTE:** one bracket and two brackets are different operations, not a style choice.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — what Pandas inferred without asking

# %% [markdown]
# ### Question 5
#
# Run `students.info()`. Read every line of the output: the index type, the non-null counts, the dtype of each column, and the memory figure. Then run `records.info()` and compare the non-null counts.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Print `students.describe()`. Notice which columns it chose to describe. Then print `students.describe(include="all")` and compare.
# > **NOTE:** `describe()` silently picks the numeric columns. If your numbers were loaded as text, they will be missing here and the omission looks exactly like a column that has no statistics.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Add a column: `students["Adult"] = students["Age"] >= 21`. Print the frame. Then add `students["AgeInMonths"] = students["Age"] * 12` and print it again.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Print `records["City"].count()` and `len(records["City"])`. They disagree. Then print `records["City"].value_counts()` and check whether Nadia appears anywhere in it.
# > **NOTE:** `count()` is not `len()`. One of them silently drops a person.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Print the mean age of `records` two ways: `records["Age"].mean()`, and by hand as `records["Age"].sum() / len(records)`. Then do the same for a column with a missing value — compute `records["City"].count() / len(records)` — and say what fraction of cities you actually have.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, ask for a column that does not exist: print `students["Salary"]`. **This is supposed to fail.** Read the exception name and message.
# > **NOTE:** compare with Q2. A missing *value* was filled with `NaN` silently; a missing *column* raises immediately.

# %%
############################
## Your Code Here
############################
