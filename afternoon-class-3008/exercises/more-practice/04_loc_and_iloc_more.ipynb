# %% [markdown]
# # Afternoon class 30/08 — Extra practice 04: loc and iloc   (L01/L02)
#
# A second pass at worksheet 04, on 300 real rows where the index stops matching
# the positions as soon as you touch it.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 04 — loc and iloc. Run this once.
import pandas as pd

sales = pd.read_csv("../data/sales.csv")

# Sorted by Sales descending -- the labels are now out of order.
ranked = sales.sort_values("Sales", ascending=False)

print("sales index starts:", list(sales.index[:5]))
print("ranked index starts:", list(ranked.index[:5]))

# %% [markdown]
# ### Question 1
#
# Print `ranked.head(3)` showing only `OrderID` and `Sales`. Then print `ranked.index[:3]` and say why those labels are not `0, 1, 2`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print `ranked.iloc[0]["OrderID"]` and `ranked.loc[0, "OrderID"]`. They are different orders. Say which one is the biggest sale.
# > **NOTE:** `iloc[0]` is 'the first row of this sorted frame'. `loc[0]` is 'the row that was row 0 of the original file'.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print the top five sales two ways: `ranked.head(5)` and `ranked.iloc[:5]`. Confirm they match with `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Select two columns for the top three rows in one `.loc` call, using a slice of positions is not allowed there — so use `ranked.iloc[:3][["Region", "Sales"]]` and then `ranked.iloc[:3, [2, 7]]`. Print both and confirm they agree.
# > **NOTE:** `2` and `7` are the positions of `Region` and `Sales`. Check that against `list(sales.columns)` before trusting them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Reset the index of `ranked` with `reset_index(drop=True)` and print the first three labels. Then print `.loc[0, "OrderID"]` and `.iloc[0]["OrderID"]` and confirm they now agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Use `.loc` with a condition and a column together: print the `OrderID` and `Sales` of every order over 8000, using `sales.loc[sales["Sales"] > 8000, ["OrderID", "Sales"]]`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Compare a label slice with a position slice on the *unsorted* frame: print how many rows `sales.loc[0:4]` and `sales.iloc[0:4]` each return.
# > **NOTE:** the labels here are `0..299`, so both expressions read identically. They do not mean the same thing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, ask `.loc` for a label that the sorted frame no longer starts with — but pick one beyond the end of the file: print `ranked.loc[500, "OrderID"]`. **This is supposed to fail.**

# %%
############################
## Your Code Here
############################
