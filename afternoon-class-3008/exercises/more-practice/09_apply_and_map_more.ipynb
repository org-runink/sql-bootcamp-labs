# %% [markdown]
# # Afternoon class 30/08 — Extra practice 09: apply and map   (L02)
#
# A second pass at worksheet 09, on the real sales file — including what happens
# when your lookup does not cover the data and nobody tells you.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 09 — apply and map. Run this once.
import pandas as pd

sales = pd.read_csv("../data/sales.csv")

# A lookup that covers only two of the three categories.
margin_target = {"Technology": 0.25, "Furniture": 0.15}

print("categories in the data:", sorted(sales["Category"].unique()))
print("categories in the map: ", sorted(margin_target))

# %% [markdown]
# ### Question 1
#
# Use `map` to attach `margin_target` to each row as a new column `Target`. Print `value_counts(dropna=False)` of it.
# > **NOTE:** pass `dropna=False`, or the rows that failed to map vanish from the tally too.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Find which category was missed, using set difference between the values present and the keys covered.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Fix it two ways: with `.fillna(0.10)` after the map, and with `.map(lambda c: margin_target.get(c, 0.10))`. Confirm they agree and print the resulting `value_counts`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Compute an actual margin per order with arithmetic: `sales["Profit"] / sales["Sales"]`. Print its describe(), and count how many orders exceed their category target from Q3.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Do the same classification with `apply` and a named function returning `"beat"` or `"missed"`, then confirm the counts match Q4.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Compare the cost of the two approaches. Time `sales.apply(verdict, axis=1)` against the vectorised `sales["Margin"] > sales["Target"]`, and print both.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Use `map` on a *numeric* column via a Series lookup instead of a dict: build `pd.Series` of region codes from `sales["Region"].unique()` and map the region names to short codes. Print the first five results.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, apply a function that cannot handle one of the values. First count how many orders have a `Discount` of exactly `0`, and how many have a `Profit` of exactly `0`. Then compute `1 / sales["Discount"]` via `apply`. **This is supposed to fail.**
# > **NOTE:** the two counts are the point. Run the same expression against `Profit` and it succeeds — the failure depends entirely on which column you picked, not on the code.

# %%
############################
## Your Code Here
############################
