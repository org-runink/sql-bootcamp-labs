# %% [markdown]
# # Afternoon class 30/08 — Worksheet 14: Excel, writing out, and a capstone   (L03)
#
# Excel is where most business data actually lives, and a workbook can hold many
# sheets — so `read_excel` has to answer a question `read_csv` never faces: which
# one? The last three questions put the whole day together into one pipeline.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L03]_reading_and_writing_data_with_Pandas.pdf`,
# slides 23–32.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 14 — Excel, writing, capstone. Run this once.
import pandas as pd

# data/quarterly.xlsx holds the same 300 orders split into four sheets by
# the quarter of OrderDate.
sales = pd.read_csv("data/sales.csv", parse_dates=["OrderDate"])

print("sales.csv:", sales.shape)
print("date range:", sales["OrderDate"].min().date(), "to", sales["OrderDate"].max().date())

# %% [markdown]
# PART A — reading a workbook

# %% [markdown]
# ### Question 1
#
# Read one sheet: `pd.read_excel("data/quarterly.xlsx", sheet_name="Q1")`. Print its type and shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Now read every sheet: `pd.read_excel("data/quarterly.xlsx", sheet_name=None)`. Print the type of the result, its keys, and the shape of each sheet. Then check the row counts add up to 300.
# > **NOTE:** `sheet_name=None` does not mean 'no sheet'. It means 'all of them', and it changes the return type.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print `pd.read_excel("data/quarterly.xlsx", sheet_name=0)` shape and confirm with `.equals()` that it is the same as the `"Q1"` sheet. Then say why passing `0` is riskier than passing the name.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Combine the sheets back into one frame with `pd.concat(book.values(), ignore_index=True)`. Print the shape and confirm the total `Sales` matches `sales["Sales"].sum()` — print both with `repr()`.
# > **NOTE:** this is the same sum computed in a different grouping. Recall worksheet 12.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — writing, and the column you did not ask for

# %% [markdown]
# ### Question 5
#
# Write three rows to CSV twice — once with defaults and once with `index=False` — then print the first line of each file, and read the default one back and print its columns.
# > **NOTE:** this is the deck's first 'common trap'. It is worth seeing rather than being told.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Write a multi-sheet workbook with `pd.ExcelWriter`: put orders over 1000 on a sheet called `Large` and the rest on `Small`. Then read it back with `sheet_name=None` and print the shapes.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — capstone: the whole pipeline

# %% [markdown]
# ### Question 7
#
# Build the deck's four-step workflow on `data/sales_messy.csv`. **Load** it with `na_values=["?", "Missing"]` and `parse_dates=["OrderDate"]`. **Check** by printing shape, dtypes and `isna().sum()`. Print how many rows are complete.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# **Process.** Report the total `Sales` per `Region`, keeping the rows whose `Region` is missing visible rather than dropping them. Use `groupby(..., dropna=False)`. Print the result and check the group totals sum to the ungrouped total.
# > **NOTE:** `groupby` drops missing keys by default. On this file that silently discards 28 orders.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# **Save.** Write the per-region totals to `/tmp/region_totals.csv` — think about whether the index is meaningful here — and write the cleaned rows to a two-sheet workbook alongside a summary. Read both back and confirm.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, ask for a sheet that is not in the workbook: `pd.read_excel("data/quarterly.xlsx", sheet_name="Q5")`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
