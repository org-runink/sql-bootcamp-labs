# %% [markdown]
# # Afternoon class 30/08 — Worksheet 03: The Index   (L01)
#
# The index is a real object with its own rules, not a decoration on the left of
# the table. This sheet covers replacing it, slicing it, duplicate labels, and
# what `set_index` does when you hand it more than one column.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L01]_introduction_to_Pandas.pdf`, slides 31–36.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 03 — The Index. Run this once.
import pandas as pd

students = pd.DataFrame({
    "Name": ["Abdullah", "Sara", "Ahmed"],
    "Age": [22, 24, 21],
    "City": ["Riyadh", "Jeddah", "Dammam"],
})

# The four-row frame the lecture uses for duplicate labels.
dup = pd.DataFrame(
    {"Col1": ["D1", "D2", "D3", "D4"], "Col2": ["D1", "D2", "D3", "D4"]},
    index=[11, 12, 12, 14],
)

# Two columns that only identify a row when taken together.
pairs = pd.DataFrame({
    "Region": ["West", "West", "East", "East"],
    "Quarter": ["Q1", "Q2", "Q1", "Q2"],
    "Sales": [100, 150, 120, 180],
})

print(students)
print()
print(dup)

# %% [markdown]
# PART A — replacing and reading the index

# %% [markdown]
# ### Question 1
#
# Print `students.index`. Then assign `students.index = ["S1", "S2", "S3"]` and print both the frame and the index again.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# The index is an object in its own right. Print `students.index[0]`, `students.index[1:]`, and `len(students.index)`. Then print `type(students.index)`.
# > **NOTE:** you can read and slice it exactly like a sequence. Q10 is about the one thing you cannot do.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print `students.loc["S2"]`. Then print `students.loc["S2", "City"]`. Note what type comes back in each case.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — duplicate labels

# %% [markdown]
# ### Question 4
#
# Print `dup`, then `dup.index.is_unique` and `dup.index.duplicated()`. Read the boolean array carefully — work out which position it is flagging and why it is not flagging both of the repeated labels.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Print `dup.loc[12]`. Then print `type(dup.loc[12])` and `dup.loc[11]` with its type. The same expression returned two different shapes — say why.
# > **NOTE:** this is the practical cost of a duplicate label. Code that assumes `.loc[x]` gives you one row will work fine until the day it does not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Count how many rows `dup.loc[12]` returns, and compare with `dup.loc[11]`. Use `len()` on each — but wrap it so a Series and a DataFrame are treated the same way by printing `dup.loc[[12]]` and `dup.loc[[11]]` (double brackets) instead.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# The lecture concatenates a new row onto `dup`. Build `extra = pd.DataFrame({"Col1": ["D5"], "Col2": ["D5"]}, index=[12])` and print `pd.concat([dup, extra])`. Then print `list(...index)` of the result. The slide shows the resulting index as `11, 12, 13, 14, 12`. Compare that with what you get.
# > **NOTE:** check the slide's own *previous* page too. The frame it says it is concatenating onto has index `11, 12, 12, 14`, so a `13` cannot appear in the result.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — building an index out of columns

# %% [markdown]
# ### Question 8
#
# Print `pairs`. Then print `pairs.set_index("Region")` and note that the labels repeat. Now print `pairs.set_index(["Region", "Quarter"])` and print its `.index`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Using the two-level frame from Q8, print `multi.loc["West"]` and then `multi.loc[("West", "Q2")]`. Then call `.reset_index()` on it and print the result — check whether `Region` and `Quarter` came back as columns.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, try to change a single label in place. Run `idx = pd.Index(["a", "b", "c"])` and then `idx[1] = "d"`. **This is supposed to fail.** Read the exception name and message.
# > **NOTE:** you replaced the whole index in Q1 without any complaint. Editing one label of it is forbidden. That asymmetry is the point.

# %%
############################
## Your Code Here
############################
