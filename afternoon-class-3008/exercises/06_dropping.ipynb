# %% [markdown]
# # Afternoon class 30/08 — Worksheet 06: Dropping rows and columns   (L02)
#
# `drop` removes what you do not want. The operation is simple; the thing that
# catches people is what it does with the result, which is not what most people
# assume on first reading.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L02]_Pandas_core_functionalities.pdf`,
# slides 9–11.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 06 — Dropping. Run this once.
import pandas as pd

people = pd.DataFrame(
    {
        "Name": ["Sara", "Ahmed", "Lina", "Omar"],
        "Age": [22, 21, 23, 25],
        "Address": ["Riyadh", "Jeddah", "Dammam", "Riyadh"],
        "Notes": [None, None, None, None],       # the empty column from the slide
    },
    index=["S1", "S2", "S3", "S4"],
)

print(people)
print()
print("shape:", people.shape)

# %% [markdown]
# PART A — the operation

# %% [markdown]
# ### Question 1
#
# Print `people.drop(index=["S2"])` and then `people.drop(columns=["Notes"])`. Confirm each removed what you expected.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Now print `people` again, on its own, and print `people.shape`. Compare with the setup cell. Say what `drop` actually did to `people` in Q1.
# > **NOTE:** this is the question. If you assumed Q1 changed `people`, you have just written a bug that no error will ever tell you about.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Do it properly: assign the result. Run `trimmed = people.drop(columns=["Notes"])` and print `trimmed.shape` and `people.shape` side by side.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Drop several things at once: print `people.drop(index=["S1", "S4"], columns=["Notes", "Address"])`. Both axes in one call.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — deciding what deserves to go

# %% [markdown]
# ### Question 5
#
# The `Notes` column is entirely empty. Prove it before dropping it: print `people["Notes"].isna().all()` and `people["Notes"].count()`. Only then drop it.
# > **NOTE:** 'this column looks empty' and 'this column is empty' are different claims. One of them you can check in a line.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Use `dropna` instead, and see how differently it behaves. Print `people.dropna(axis=1, how="all")` — drop columns that are entirely missing — and then `people.dropna()` with no arguments. Compare the shapes.
# > **NOTE:** the default `dropna()` drops any ROW with any missing value. On this frame that is all of them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Drop by condition rather than by label. Keep everyone under 24 by dropping the others: print `people.drop(index=people[people["Age"] >= 24].index)`. Then write the same thing as a filter and confirm they match.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Print `people.drop(columns=["Notes"]).drop(index=["S1"])` — chained — and its shape. Then print `people.shape` once more to confirm the original is still whole.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Try to drop something that is not there, but tell Pandas not to mind: print `people.drop(columns=["Nickname"], errors="ignore").shape`. Then think about when that is helpful and when it hides a typo.
# > **NOTE:** `errors="ignore"` turns Q10's exception off. That is occasionally what you want and usually not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, drop a column that does not exist, without `errors="ignore"`: print `people.drop(columns=["Nickname"])`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
