# %% [markdown]
# # Afternoon class 30/08 — Worksheet 05: Reindexing   (L02)
#
# Selection asks 'which of these rows do I want?'. Reindexing asks 'what labels
# should the answer have?' — and if you name a label that is not there, you get a
# row for it anyway. That difference is the whole sheet.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L02]_Pandas_core_functionalities.pdf`,
# slides 5–8.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 05 — Reindexing. Run this once.
import pandas as pd

# The lecture's three students.
marks = pd.Series([85, 90, 75], index=["S1", "S2", "S3"], name="Marks")

# The roster the registrar says SHOULD exist -- note S4, who has no marks.
roster = ["S1", "S2", "S3", "S4"]

frame = pd.DataFrame(
    {"Marks": [85, 90, 75], "Grade": ["A", "A", "B"]},
    index=["S1", "S2", "S3"],
)

print(marks)
print()
print("roster:", roster)

# %% [markdown]
# PART A — asking for labels you do not have

# %% [markdown]
# ### Question 1
#
# Print `marks.reindex(roster)`. `S4` was not in the data. Find what value it got, and check whether anything warned you.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print `marks.reindex(["S3", "S1", "S4"])`. Note that this both reordered the rows and invented one. Print the result's `.index` to confirm it is exactly the list you asked for.
# > **NOTE:** the result's index is whatever you passed, in that order — not a subset of the original. That is the definition of reindexing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print `marks.dtype`, then print `marks.reindex(roster).dtype`. The marks were whole numbers. Say what changed and why.
# > **NOTE:** you added no data and removed no data. You asked for one extra label.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Print `marks.reindex(roster, fill_value=0)` and compare its dtype with Q3's. Then say, in a comment, why `fill_value=0` is a decision and not a fix.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — reindexing vs selecting

# %% [markdown]
# ### Question 5
#
# Print `marks.loc[["S1", "S2"]]` and `marks.reindex(["S1", "S2"])`. When every label exists, they agree. Confirm that with `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Now print `marks.reindex(["S1", "S2", "S4"])`. Then, in the *next* question, you will try the same list with `.loc`. Before you do, write down what you expect.
# > **NOTE:** they agreed in Q5. The only change is that one label is now missing from the data.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Reindex the DataFrame, not just the Series: print `frame.reindex(roster)`. Check what happened to *both* columns for `S4`, and print the resulting dtypes.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Reindex the *columns* instead of the rows: print `frame.reindex(columns=["Grade", "Marks", "Attendance"])`. Note the reordering and the invented column.
# > **NOTE:** same operation, other axis. `Attendance` is a column nobody ever recorded, and you now have one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Use reindex to make a genuine check: print `marks.reindex(roster).isna()`, then `marks.reindex(roster).isna().sum()`, and finally print the labels that are missing using `[...].index[...]`.
# > **NOTE:** this is what reindexing is *for*. Not reordering — making an expected-but-absent record visible instead of silently absent.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, ask `.loc` for the same list that reindex accepted: print `marks.loc[["S1", "S2", "S4"]]`. **This is supposed to fail.** Read the exception.
# > **NOTE:** compare with Q6. The identical list of labels: reindex returns a row of `NaN`, `.loc` refuses.

# %%
############################
## Your Code Here
############################
