# %% [markdown]
# # Afternoon class 30/08 — Worksheet 04: loc and iloc   (L01/L02)
#
# `.loc` takes labels. `.iloc` takes positions. That sentence is the whole rule,
# and it is still the thing people get wrong most often — because on a default
# index the two agree, right up until they do not.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake, and the error is one the lecture
# slide says will not happen.
#
# Lecture reference: `[Python_Pandas_L01]` slides 37–38 and
# `[Python_Pandas_L02]_Pandas_core_functionalities.pdf` slides 13–17.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 04 — loc and iloc. Run this once.
import pandas as pd

# The lecture's frame: labels S1..S3, and only TWO columns.
marks = pd.DataFrame(
    {"Name": ["Sara", "Ahmed", "Lina"], "Marks": [85, 90, 75]},
    index=["S1", "S2", "S3"],
)

# The same data on a DEFAULT index, where labels and positions look alike.
plain = marks.reset_index(drop=True)

# An index of integers running BACKWARDS, so that no label sits at the
# position that shares its number. That is what makes loc and iloc diverge.
shuffled = pd.DataFrame(
    {"Name": ["Sara", "Ahmed", "Lina"], "Marks": [85, 90, 75]},
    index=[3, 2, 1],
)

print(marks)
print()
print("columns:", list(marks.columns), "-> there are only two")

# %% [markdown]
# PART A — the rule

# %% [markdown]
# ### Question 1
#
# Print `marks.loc["S1"]` and `marks.iloc[0]`. They return the same row. Then print `marks.loc["S1", "Marks"]` and `marks.iloc[0, 1]` — the same cell, addressed both ways.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print `plain` — the same data with a default index. Now print `plain.loc[0]` and `plain.iloc[0]`. They agree. Write a one-line comment saying why that agreement is a coincidence rather than a rule.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now print `shuffled` — its index runs `[3, 2, 1]`. Print `shuffled.loc[1]` and `shuffled.iloc[1]` and compare them. They name different students.
# > **NOTE:** this is the same expression that agreed in Q2. Nothing changed except the labels.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — selecting more than one thing

# %% [markdown]
# ### Question 4
#
# Print `marks.loc[["S1", "S3"]]` and `marks.iloc[[0, 2]]`. Then print `marks.loc[:, "Marks"]` and `marks.iloc[:, 1]`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Print `marks.loc["S1":"S2"]` and `marks.iloc[0:2]`. Count the rows each one returned before reading the next question.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# `S3` is the third row, and position `2` is also the third row. So write both slices ending on that same third row — `marks.loc["S1":"S3"]` and `marks.iloc[0:2]` — and count what each returns. Then state the rule about which endpoint each one includes.
# > **NOTE:** neither lecture deck mentions this. It is the difference between a slice that returns what you meant and one that quietly drops the last row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — filtering

# %% [markdown]
# ### Question 7
#
# Print `marks[marks["Marks"] > 80]`. Then print the same thing written as `marks.loc[marks["Marks"] > 80]`. Confirm they agree, then print `marks.loc[marks["Marks"] > 80, "Name"]` to filter rows and pick a column in one step.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Filtering keeps the original labels. Print `marks[marks["Marks"] > 80]` and then its `.index`. Then print `.iloc[0]` of that filtered frame and say which student it is — and which student is at position 0 of the *original*.
# > **NOTE:** filtering renumbers nothing. Positions shift, labels do not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Print `marks.loc["S2", "Marks"]` — the value the lecture summary table gives as `df.iloc[0, 1]`. Then print `marks.iloc[0, 1]` and `marks.iloc[1, 1]`, and match each expression to the student it names.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# The L02 slide 'Select Data by Label or by Position' prints `df.iloc[0, 2]` and gives the answer as `85`. Run `marks.iloc[0, 2]`. **This is supposed to fail.** Read the exception and then count the columns in `marks`.
# > **NOTE:** the very next slide's summary table writes the same idea as `df.iloc[0, 1]`. Two consecutive slides disagree, and only one of them can run.

# %%
############################
## Your Code Here
############################
