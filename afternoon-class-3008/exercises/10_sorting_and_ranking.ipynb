# %% [markdown]
# # Afternoon class 30/08 — Worksheet 10: Sorting and ranking   (L02)
#
# Sorting reorders the rows. Ranking leaves them where they are and adds a
# position. The deck says ties 'need a ranking rule, such as average, min, or
# dense' and then never shows you what the default does — which is this sheet.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L02]_Pandas_core_functionalities.pdf`,
# slides 26–30.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 10 — Sorting and ranking. Run this once.
import pandas as pd

# The deck's three students...
students = pd.DataFrame(
    {"Student": ["Sara", "Ahmed", "Lina"], "Marks": [85, 90, 75]}
)

# ...and the same three with a fourth who TIES with Ahmed.
tied = pd.DataFrame(
    {"Student": ["Sara", "Ahmed", "Lina", "Omar"], "Marks": [85, 90, 75, 90]}
)

sales = pd.read_csv("data/sales.csv")

print(students)
print()
print(tied)

# %% [markdown]
# PART A — sorting

# %% [markdown]
# ### Question 1
#
# Print `students.sort_values("Marks")` and then `students.sort_values("Marks", ascending=False)`. Check which student is on top in each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print `students` on its own again. Compare with the setup cell and say what `sort_values` did to it.
# > **NOTE:** exactly the same lesson as worksheet 06 Q2. `sort_values` returns a sorted copy.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Sorting keeps the labels. Print `students.sort_values("Marks").index` and then `students.sort_values("Marks").reset_index(drop=True)`. Say when you would want the second form.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Sort by two columns: print `sales.sort_values(["Region", "Sales"], ascending=[True, False]).head(8)[["Region", "Sales"]]`. Read the result and describe the ordering in words.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — ranking, and what a tie does

# %% [markdown]
# ### Question 5
#
# Print `students["Marks"].rank(ascending=False)` for the three students with no tie. Then print its `.dtype`.
# > **NOTE:** three students, three distinct marks, and the ranks are still not integers.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Now rank the four students where Ahmed and Omar are tied on 90: print `tied["Marks"].rank(ascending=False)` alongside the names. Read the two ranks the tied pair received.
# > **NOTE:** the deck says ties 'need a ranking rule, such as average, min, or dense'. It never says which one you get if you do not choose.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Print all five tie rules side by side: for each of `"average"`, `"min"`, `"max"`, `"dense"`, `"first"`, print `tied["Marks"].rank(ascending=False, method=...)` as a list. Then say which one a sports league would use.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Compare ranking with sorting on the same data. Print `tied.sort_values("Marks", ascending=False)` and then `tied` with a `Rank` column added. Say what each one is good for.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# On the real file: add a `Rank` column ranking `Sales` descending with `method="min"`, then print the three highest-selling orders. Then print how many orders share the rank `1`, and check `Rank` for duplicates with `.duplicated().sum()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, sort by a column that does not exist: print `sales.sort_values("Revenue")`. **This is supposed to fail.** Read the exception.
# > **NOTE:** `Revenue` is a perfectly reasonable name for what this file calls `Sales`. That is exactly why this happens.

# %%
############################
## Your Code Here
############################
