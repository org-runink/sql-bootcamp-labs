# %% [markdown]
# # Afternoon class 30/08 — Worksheet 08: Arithmetic and label alignment   (L02)
#
# When you add two Pandas objects, it matches them up by label first. That single
# decision is what makes Pandas safe with real data — and it is also the source of
# the most baffling `NaN`s you will ever produce.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L02]_Pandas_core_functionalities.pdf`,
# slides 18–20.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 08 — Alignment. Run this once.
import pandas as pd

# The lecture's two Series. Note they overlap on S2 only.
s1 = pd.Series([10, 20], index=["S1", "S2"])
s2 = pd.Series([5, 8], index=["S2", "S3"])

# Same numbers, as plain Python lists, for the comparison in Q2.
list1 = [10, 20]
list2 = [5, 8]

# Two frames that share some rows and some columns, but not all.
q1 = pd.DataFrame({"Sales": [100, 150], "Cost": [60, 90]}, index=["West", "East"])
q2 = pd.DataFrame({"Sales": [120, 200], "Tax": [12, 20]}, index=["East", "North"])

print(s1)
print()
print(s2)

# %% [markdown]
# PART A — matched by label, not by position

# %% [markdown]
# ### Question 1
#
# Print `s1 + s2`. Three labels come back and only one of them has a number. Work out which label got `25` and why the other two are `NaN`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Now do it the Python-list way. Print `[a + b for a, b in zip(list1, list2)]`. Compare the first element with what Pandas gave for `S1`, and say which of the two answers is about the same student.
# > **NOTE:** the list version produces two clean numbers and no warnings. That is the problem with it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Print the result's index with `list((s1 + s2).index)` and confirm it is the *union* of the two inputs, sorted. Then print `(s1 + s2).isna().sum()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# If you want the missing side treated as zero, say so: print `s1.add(s2, fill_value=0)`. Compare it with `s1 + s2` and note which labels changed.
# > **NOTE:** `fill_value=0` is a claim that a missing entry means 'nothing', not 'unknown'. Sometimes true, often not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — labels that look the same and are not

# %% [markdown]
# ### Question 5
#
# Build `lower = pd.Series([1, 1], index=["s1", "s2"])` — lower-case — and print `s1 + lower`. Then print the result's index and count the `NaN`s.
# > **NOTE:** the deck warns that `"S1"` and `"s1"` are different labels. This is what that looks like when it happens to you.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Diagnose it the way you would in real life. Print `set(s1.index) & set(lower.index)` to show the overlap is empty, then fix it with `lower.index = lower.index.str.upper()` and print `s1 + lower` again.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Whitespace does the same thing and is harder to see. Build `padded = pd.Series([1, 1], index=["S1 ", "S2"])` — note the trailing space on the first label — and print `s1 + padded`. Then print `repr(padded.index[0])`.
# > **NOTE:** printing the index shows `S1`. Only `repr()` shows the space.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — two axes at once

# %% [markdown]
# ### Question 8
#
# Print `q1` and `q2`, then `q1 + q2`. Both the rows and the columns are aligned. Count how many of the resulting cells actually have a number in them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Only `East`/`Sales` was present in both. Print `q1.add(q2, fill_value=0)` and count the populated cells again. Then say why one cell is *still* `NaN` even with a fill value.
# > **NOTE:** `fill_value` fills where one side is missing. It cannot invent a value where neither side had one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, compare two differently-labelled Series directly: run `s1 == s2`. **This is supposed to fail.** Read the exception, then confirm that `s1 + s2` from Q1 still works.
# > **NOTE:** adding them was fine. Comparing them is not. That difference is deliberate.

# %%
############################
## Your Code Here
############################
