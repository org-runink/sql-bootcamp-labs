# %% [markdown]
# # Afternoon class 30/08 — Worksheet 11: Reading CSV and TSV   (L03)
#
# `pd.read_csv` has around fifty parameters and the deck's advice is right: do not
# add them until the file gives you a reason. This sheet is about recognising the
# reasons — and about the fact that a wrong parameter usually produces a table
# rather than an error.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L03]_reading_and_writing_data_with_Pandas.pdf`,
# slides 5–10.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 11 — Reading CSV and TSV. Run this once.
import pandas as pd

# All of these describe the SAME 300 orders, stored four different ways.
#   data/sales.csv         clean, comma-separated
#   data/sales.tsv         tab-separated
#   data/sales_report.csv  three metadata lines, a blank line, then the header
#   data/sales_messy.csv   '?' and 'Missing' used as placeholders

sales = pd.read_csv("data/sales.csv")
print("sales.csv ->", sales.shape)
print(list(sales.columns))

# %% [markdown]
# PART A — the default read, and what to check

# %% [markdown]
# ### Question 1
#
# Print `sales.head(3)`, `sales.shape`, and `sales.dtypes`. Then run `sales.info()`. Before touching any parameters, confirm the row count, the column count and that nothing is missing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Read the tab-separated copy: `pd.read_csv("data/sales.tsv", sep="\t")`. Print its shape and confirm it holds the same data as `sales` with `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now read the TSV *without* telling Pandas about the tabs: `pd.read_csv("data/sales.tsv")`, catching the exception so the sheet continues. Then write a two-column TSV containing no commas at all, read *that* one the same wrong way, and print its shape.
# > **NOTE:** the same mistake on two files. One of them stops you and the other does not, and which you get depends on the contents rather than on the mistake.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the metadata preamble

# %% [markdown]
# ### Question 4
#
# Open `data/sales_report.csv` in the file browser and look at the top of it. Then read it four ways — `skiprows=2`, `3`, `4`, `5` — and print the shape and first column name for each.
# > **NOTE:** the deck's slide shows this file shape and says `skiprows=3`. Try to work out, before running it, how many of the four values give you the right table.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Two of those four gave `(300, 10)`. Explain why, by printing the first five raw lines of the file with plain Python.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — placeholders that are not missing values

# %% [markdown]
# ### Question 6
#
# Read `data/sales_messy.csv` with no parameters. Print `.dtypes` for `Discount` and `Profit`, and print `isna().sum()`. Then print `df["Discount"].unique()[:6]`.
# > **NOTE:** this file uses `?` and `Missing` as placeholders. Look at what that did to the *type* of the columns, not just their contents.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Try to compute `messy["Discount"].mean()`. Then read the same file with `na_values=["?", "Missing"]`, print the dtypes and `isna().sum()` again, and compute the mean.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Read only two columns with `usecols=["OrderDate", "Sales"]`. Print the shape. Then read with `parse_dates=["OrderDate"]` and print the `OrderDate` dtype with and without it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Without `parse_dates`, `OrderDate` is text. Print `sales["OrderDate"].max()` and `dated["OrderDate"].max()` and check whether they agree. Then explain why they happen to agree for this file, and when they would not.
# > **NOTE:** these dates are `YYYY-MM-DD`. That format sorts identically as text and as dates. Almost no other format does.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, read a file that is not there: `pd.read_csv("data/sales_2027.csv")`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
