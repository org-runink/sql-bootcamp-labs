# %% [markdown]
# # Afternoon class 24/08 — Worksheet 07: Subqueries (company-data, superstore-data)   (L08)

# %% [markdown]
# Run this once to connect. Then every `%%sql` cell below works.

# %%
# %load_ext sql
# %config SqlMagic.autocommit = True
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = False
# %sql mysql+pymysql://root:123456@mysql:3306/?local_infile=1

# %% [markdown]
# ## Check Database Tables

# %%
# %%sql
# USE company;

# %% [markdown]
# ## Subqueries

# %% [markdown]
# ### Question 1
#
# What is the highest performance score in `review`?

# %%
# %%sql

# %% [markdown]
# ### Question 2
#
# Which employee(s) had that highest performance score?
# > **HINT:** review's key column is called `name`, holding employee_id values

# %%
# %%sql

# %% [markdown]
# ### Question 3
#
# What is the average salary of employees with the highest performance score? (nest the query from #2 inside a subquery against `employee`)

# %%
# %%sql

# %% [markdown]
# ## EXERCISE

# %%
# %%sql
# USE superstore;

# %% [markdown]
# ### Question 1
#
# What was the total Sales lost to returned products?
# > **HINT:** SUM Sales from `orders` where OrderID is in the set of
# returned OrderIDs from `returns` (Status = 'Returned')

# %%
# %%sql

# %% [markdown]
# ### Question 2
#
# What is the highest single-day total sales number?
# > **HINT:** subquery sums Sales per OrderDate; outer query picks the max

# %%
# %%sql
