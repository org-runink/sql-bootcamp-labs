# %% [markdown]
# # Afternoon class 26/08 — Worksheet 05: Sets   (L04)
#
# A set holds **unique** items, unordered and unindexed. That one sentence
# explains everything on this sheet: what sets are brilliant at (membership
# tests, deduplication, comparing two collections) and what they simply refuse
# to do (give you the third item).
#
# Run the setup cell once, then work down. **Questions 2 and 8 are supposed to
# raise errors** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_L04]_Python_data_structures.pdf`, slides 48–55.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 05 — Sets. Run this once.
devops_skills = {"linux", "docker", "python", "bash", "terraform"}
data_skills = {"python", "sql", "statistics", "linux"}
letters = {"a", "b", "c", "d", "e"}
vowels = {"a", "e", "i", "o", "u"}
signups = ["ana", "bo", "ana", "cai", "bo", "ana", "dee"]

print("devops_skills:", devops_skills)
print("data_skills:  ", data_skills)
print("signups:      ", signups)

# %% [markdown]
# PART A — Creating a set, and what it silently throws away

# %% [markdown]
# ### Question 1
#
# Warm-up. Build `fruits` as a set literal holding `"apple"`, `"banana"` and `"orange"`. Build `numbers_set` from the list `[1, 2, 2, 2, 3, 4, 5]` using `set()`. Build an empty set `x` with `set()`, then `add` `1`, `2` and `2` again. Print all three and the `len()` of each.
# > **HINT:** an empty set must be written `set()`. Plain `{}` builds an empty *dictionary*.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print whether `"a"` is in `letters` and whether `"f"` is in `letters`. Then try to print `letters[0]`. Run it, read the error, and write in a comment why a set cannot answer that question. This cell is meant to fail.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# `signups` is a list with repeats. Print how many names it holds. Then build `unique_signups` by passing it to `set()`, print it and its length, and finally convert it back to a list with `list()` and print that. Compare the two lengths.
# > **CAREFUL:** deduplicating through a set also throws the original order away. You get uniqueness and lose sequence — both, always, not one or the other.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — The four set operations

# %% [markdown]
# ### Question 4
#
# Compare `devops_skills` and `data_skills` using the method form of all four operations, printing each: every skill either role needs, the skills both need, the skills only a DevOps engineer needs, and the skills exactly one of the two needs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Repeat all four comparisons using the operator form instead of the methods, and prove they agree: print the result of comparing each operator result to its method result with `==`. You should get `True` four times.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Print `devops_skills - data_skills` and then `data_skills - devops_skills`. Then print whether the two results are equal. Explain the result in a comment.
# > **CAREFUL:** union and intersection do not care which side you write first. Difference does.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Changing a set, comparing sets, and a stretch

# %% [markdown]
# ### Question 7
#
# Change `letters`, printing it after each step: `add` `"f"`; `update` it with `{"g", "h"}`; `remove` `"a"`; and `discard` `"z"`, which is not there. Then take a copy, `clear()` the copy, and print both the copy and `letters` to show the original survived.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Show the difference between the two removal methods. First `discard` `"nope"` from `letters` and print the set — nothing should happen. Then `remove` `"nope"` and let it fail. Write in a comment which one you would use when you are not certain the item is there.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Using `letters`, `vowels` and the sets you have, print: whether `vowels` and `{"x", "y"}` have nothing in common; whether `{"a", "e"}` is a subset of `vowels`; and whether `vowels` is a superset of `{"a", "e"}`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Stretch. In one line each, build and print `initials`, the set of first letters of every name in `signups`, and `long_names`, the set of names in `signups` longer than two characters. Then explain in a comment why `initials` is shorter than `signups`.
# > **HINT:** a set comprehension is a list comprehension in `{}` instead of `[]`.

# %%
############################
## Your Code Here
############################
