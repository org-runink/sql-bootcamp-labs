# %% [markdown]
# # Afternoon class 26/08 — Worksheet 08: Dictionaries, more practice   (L04)
#
# Extra repetition on worksheet 07, with different data and the two dictionary
# jobs you will actually do most often: **counting things**, and **grouping
# things**. Both are the same accumulator loop with a different value type.
#
# Run the setup cell once, then work down. **Question 4 is supposed to raise an
# error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 08 — Dictionaries, more practice. Run this once.
stock = {"widget": 12, "gizmo": 0, "doohickey": 7}
config = {
    "server": {"host": "localhost", "port": 8888},
    "debug": True,
    "users": ["ada", "bo"],
}
words = ["red", "blue", "red", "green", "blue", "red"]
animals = ["cat", "cow", "crow", "dog", "duck", "emu"]

print("stock: ", stock)
print("config:", config)
print("words: ", words)

# %% [markdown]
# PART A — Building and reading

# %% [markdown]
# ### Question 1
#
# Warm-up. Build `prices` as a literal mapping `"tea"` to `2.50` and `"coffee"` to `3.75`. Build the same thing with `dict()` and keyword arguments. Build `counters` with `dict.fromkeys()` over `["a", "b", "c"]` starting at `0`. Print all three plus `len(prices)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# From `config` print: the whole server section; the port; the second user; and whether debug is on. The port is two levels down.
# > **HINT:** follow the shape one bracket at a time — a key gets you a dict, then another key; a key gets you a list, then a number.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Ask about keys that may not exist, safely. Print `stock.get("widget")`, `stock.get("sprocket")`, and `stock.get("sprocket", 0)`. Then print whether `"gizmo"` is in `stock`, and print `stock["gizmo"]`.
# > **CAREFUL:** `gizmo` has a stock level of `0`. Being present and being truthy are different questions — `.get()` returning `0` does not mean the key was missing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Print `stock["sprocket"]` with square brackets and let it fail. This cell is meant to fail.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Changing a dictionary

# %% [markdown]
# ### Question 5
#
# Modify `stock`, printing it after each step: add `"sprocket"` with `5`; set `"gizmo"` to `3`; `update` with `{"widget": 15, "cog": 2}`; `pop` `"doohickey"` printing what came back; and `del` `"cog"`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Print `stock.keys()`, `stock.values()` and `stock.items()` as they come. Then print the total number of units in stock, the name of the item with the most units, and a list of the item names sorted alphabetically.
# > **HINT:** `sum()` works on `.values()`. For the busiest item, `max()` takes a `key=` argument — `max(stock, key=stock.get)` reads well.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — The two jobs you will actually do
#
# Counting and grouping. Both are one loop, an empty dict, and a check for
# whether the key exists yet — only the value type changes.

# %% [markdown]
# ### Question 7
#
# Count how many times each word appears in `words`, building the dictionary with a loop, and print it. Then print the most common word.
# > **HINT:** start with an empty dict; for each word, set the count to `0` if the key is missing, then add one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Group `animals` by their first letter into a dictionary mapping each letter to a **list** of the animals starting with it. Print it, then print how many groups there are and the largest group.
# > **HINT:** identical shape to Q7, except the value starts as `[]` and you `append` instead of adding one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Stretch. In one line each, print: `in_stock`, only the entries with more than zero units; `doubled`, every value doubled; and `by_count`, the counts dictionary from Q7 inverted. Then print the length of `counts` and of `by_count` and explain any difference.
# > **CAREFUL:** you saw inversion lose data in worksheet 07 Q11. Check the lengths before you trust the result.

# %%
############################
## Your Code Here
############################
