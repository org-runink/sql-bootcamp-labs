# %% [markdown]
# # Afternoon class 26/08 — Worksheet 02: Tuples   (L04)
#
# A tuple is an ordered collection, like a list — but it cannot be changed
# after you build it. Most of this sheet is therefore the same operations you
# did in worksheet 01, and the interesting part is the short list of things
# that now fail.
#
# Run the setup cell once, then work down. **Question 5 is supposed to raise an
# error** — that is the answer, not a mistake. Run it, read the message, then
# carry on.
#
# Lecture reference: `[Python_L04]_Python_data_structures.pdf`, slides 22–30.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 02 — Tuples. Run this once.
user_profile = ("Data Ninja", 23, "Male", "Master's")
toronto = (43.666667, -79.416667)
colors = ("red", "green", "blue", "green")
location_history = [(43.65, -79.38), (45.42, -75.70), (49.28, -123.12)]
nested = ((1, 2), (3, 4), (5, 6))

print("user_profile:    ", user_profile)
print("toronto:         ", toronto)
print("colors:          ", colors)
print("location_history:", location_history)
print("nested:          ", nested)

# %% [markdown]
# PART A — Creating and reading a tuple

# %% [markdown]
# ### Question 1
#
# Warm-up. Build `oily_fish` as a tuple holding `"salmon"`, `"mackerel"` and `"sardines"`. Then build `single = (5,)` and `not_a_tuple = (5)`. Print all three, and print the `type()` of the last two.
# > **CAREFUL:** the comma is what makes a tuple, not the brackets.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Tuples index exactly like lists. From `user_profile` print the name, the age, and the last field using a negative index.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Slice `colors` three ways and print each: the first two, the items at index 1 and 2, and the last two. Then print the `type()` of one of those slices.
# > **HINT:** slicing a tuple gives you back a tuple, not a list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `nested` is a tuple of tuples and `location_history` is a list of tuples — the shape you get when each row of a file becomes one record. Print the second inner tuple of `nested`, then its first element. Then print the second location in `location_history`, and just the latitude from it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — What a tuple will not let you do

# %% [markdown]
# ### Question 5
#
# Try to move Toronto: assign `44.0` to `toronto[0]`. Run it, read the error, and write in a comment what the message is telling you. This cell is meant to fail.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Since you cannot change a tuple, the only option is to build a new one. Make `toronto_moved` holding `44.0` and the original longitude, and print it alongside `toronto` to show the original survived. Then make `trip` by concatenating `toronto` with `(76.0,)` and print it.
# > **HINT:** you can read `toronto[1]` freely — reading was never the problem.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Unpack tuples straight into variables. Unpack `toronto` into `lat` and `lon` and print them. Unpack `user_profile` into four named variables and print the name and education. Then use `first, *rest = colors` and print both parts.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Operators, methods, and choosing between the two

# %% [markdown]
# ### Question 8
#
# Print how many fields `user_profile` has. Print `colors + ("yellow", "purple")` and `colors * 2`. Then print whether `"green"` is in `colors` and whether `"black"` is not in `colors`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# A tuple has exactly two methods. Use both: print the index of `"green"` in `colors`, and how many times `"green"` appears. Then say in a comment why a tuple has no `append`, `remove` or `sort`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Stretch. `location_history` is a list of `(lat, lon)` tuples. In one line each, build and print `latitudes` holding every latitude, and `northern` holding the full tuples whose latitude is above 44. Unpack each tuple inside the comprehension rather than indexing it.
# > **HINT:** `for lat, lon in location_history` unpacks as it loops, exactly like Q7 did in one line.

# %%
############################
## Your Code Here
############################
