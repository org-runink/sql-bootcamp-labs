# %% [markdown]
# # Afternoon class 26/08 — Worksheet 10: Built-in functions, more practice   (L04)
#
# Extra repetition on worksheet 09, with different data and the combinations
# that come up most in real work: `max` with a `key=`, sorting records by a
# chosen field, and `dict(zip(...))` to build a dictionary from two lists.
#
# Run the setup cell once, then work down. Nothing here raises on purpose.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 10 — Built-in functions, more practice. Run this once.
cities = ["Toronto", "Ottawa", "Montreal", "Halifax"]
populations = [2794356, 1017449, 1762949]
scores = [88, 42, 95, 67, 73]
people = [("Ada", 36), ("Bo", 24), ("Cai", 41), ("Dee", 29)]
raw_ages = ["36", "24", "41"]

print("cities:     ", cities)
print("populations:", populations)
print("scores:     ", scores)
print("people:     ", people)

# %% [markdown]
# PART A — Measuring and converting

# %% [markdown]
# ### Question 1
#
# Warm-up. Print the number of cities, the total of `scores`, the highest and lowest score, and the average rounded to two decimal places. Then print the `type()` of that average.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Convert `raw_ages` from strings to integers and print the resulting list, its total and its average. Then print what `raw_ages[0] + raw_ages[1]` gives you without conversion, and explain the difference in a comment.
# > **CAREFUL:** `+` on two strings is not an error. It joins them, and the result looks like a number.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Ordering, and choosing what to order by

# %% [markdown]
# ### Question 3
#
# Print `cities` sorted alphabetically, sorted by length shortest-first, and sorted by length longest-first. Then print `cities` again to confirm it never changed.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `people` is a list of `(name, age)` tuples. Print it sorted by name, then sorted by age youngest-first, then sorted by age oldest-first. Sorting by age needs a `key`.
# > **HINT:** `key=lambda person: person[1]` picks the second field of each tuple to compare. Without a key, Python sorts by the first field.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Using `max` and `min` with a `key`, print the longest city name, the shortest city name, and the oldest person in `people`. Then print just the oldest person's name.
# > **HINT:** `max` returns the whole item, not the value the key produced — so `max(people, key=...)` gives you a tuple back.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Lazy iterators, combined

# %% [markdown]
# ### Question 6
#
# Print `list(range(0, 51, 10))` and `list(range(5, 0, -1))`. Then pair `cities` with `populations` using `zip`, print the pairs as a list, and print how many pairs you got alongside the length of each input.
# > **CAREFUL:** there are 4 cities and 3 populations. Count the pairs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Turn those two lists into a dictionary in one expression with `dict(zip(...))` and print it. Then print the population of Ottawa from that dictionary, and print whether `"Halifax"` is in it.
# > **HINT:** `dict()` accepts any sequence of `(key, value)` pairs — which is exactly what `zip` produces.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Use `enumerate` to print a ranked table of `people` sorted oldest-first, numbered from 1, as `1. Cai (41)`. Then print the same list reversed using `reversed()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Stretch. Using `map` and `filter` with lambdas, print the scores as percentages-of-100 strings and the passing scores (60 or more). Then produce both with comprehensions. Finally build `report = zip(cities, populations)`, print `list(report)` twice, and explain the second result.
# > **CAREFUL:** the last part is the one-shot trap from worksheet 09 Q9. Predict the second line before you run it.

# %%
############################
## Your Code Here
############################
