# %% [markdown]
# # Afternoon class 26/08 — Worksheet 05: Built-in functions   (L04)
#
# The four structures are done. This sheet is about the functions that come
# with Python and work across all of them — measuring, converting, ordering,
# and the lazy iterators that so often surprise people.
#
# Run the setup cell once, then work down. **Question 3 ends in an error on
# purpose.**
#
# Reference: the `Demo_Data_Structures_5_Builtin_Functions` notebook.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 05 — Built-in functions. Run this once.
words = ["banana", "fig", "apple", "kiwi"]
sales = [120, 340, 90, 500, 210]
monthly = [120, 340, 90, 500, 210]   # a spare copy, sorted in place in Q4
regions = ["East", "West", "Central", "North"]
raw = ["12", "7", "23"]

print("words:  ", words)
print("sales:  ", sales)
print("regions:", regions)
print("raw:    ", raw)

# %% [markdown]
# PART A — Measuring, inspecting, converting

# %% [markdown]
# ### Question 1
#
# Warm-up. Print the `len()` of `words`, of the string `"banana"`, and of the dictionary `{"a": 1, "b": 2}`. Then print the `type()` of `words`, of `(1, 2)`, of `{1, 2}` and of `{"a": 1}`.
# > **HINT:** `len()` works on anything with a size — a list, a string, a set, a dict — which is why you keep reaching for it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the largest and smallest value in `sales`, and their total. Then print the average, calculated from two of those functions. Finally print `max(words)` and say in a comment what it is actually comparing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Convert `raw`, a list of strings, into numbers. Print `int(raw[0]) + int(raw[1])`. Print `float("3.5") * 2`. Print `str(99) + " bottles"`. Then try `int("twelve")` and let it fail. This cell is meant to fail at the end.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Ordering things

# %% [markdown]
# ### Question 4
#
# Print `sorted(monthly)` and then print `monthly` itself. Now call `monthly.sort()` and print `monthly` again. Write in a comment which of the two you would use when you must not disturb the original.
# > **CAREFUL:** you met this trap in worksheet 01 Q9 from the other direction. `sorted()` returns a new list; `.sort()` returns `None` and rearranges the one you already have.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Print `words` sorted alphabetically, then sorted in reverse alphabetical order, then sorted by length shortest-first. Then print `words` one last time to confirm none of it stuck.
# > **HINT:** `key=len` tells `sorted` what to compare instead of the items themselves.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Lazy iterators, and the trap they all share

# %% [markdown]
# ### Question 6
#
# Print `range(5)` as it comes back, then print `list(range(5))`. Then print `list(range(2, 10, 2))` and `list(range(3, 0, -1))`. Say in a comment why the first print does not show any numbers.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Print `reversed(words)` as it comes back, then print it wrapped in `list()`. Then use `zip()` to pair `regions` with `sales` and print the result as a list. Count the pairs and compare with `len(regions)` and `len(sales)`.
# > **CAREFUL:** `regions` has 4 entries and `sales` has 5. Look at how many pairs you get.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Use `enumerate()` to print a numbered list of `words`, one per line, in the form `1. banana`. Start the numbering at 1, not 0.
# > **HINT:** `enumerate()` takes a `start=` argument, so you do not have to write `index + 1`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Build `report = zip(regions, sales)`. Print `list(report)`. Then print `list(report)` a second time, on the very same object. Explain the second result in a comment.
# > **CAREFUL:** this catches almost everyone once. Read the second line of output carefully before you decide it is a typo.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Stretch. Do the same job twice, two ways. Using `map()` with a `lambda`, print every value in `sales` increased by 10%, as a list. Using `filter()` with a `lambda`, print only the values in `sales` above 200, as a list. Then reproduce both results with list comprehensions and print those too.
# > **HINT:** `map(f, seq)` applies `f` to every item; `filter(f, seq)` keeps the items where `f` is true. Both are lazy, so wrap them in `list()`.

# %%
############################
## Your Code Here
############################
