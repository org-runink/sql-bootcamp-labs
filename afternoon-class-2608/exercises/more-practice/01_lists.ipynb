# %% [markdown]
# # Afternoon class 26/08 — More practice 01: Lists   (L04)
#
# Extra repetition on worksheet 01, with different data and a few angles that
# sheet did not cover — slicing with a **step**, building a list from `range`,
# and a grid built from nested lists.
#
# Use this if lists did not land the first time, or after class. Nothing here
# needs worksheets 02 onward.
#
# Run the setup cell once, then work down.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# More practice 01 — Lists. Run this once.
temperatures = [18, 21, 19, 25, 30, 27, 22, 16]
playlist = ["intro", "verse", "chorus", "verse", "bridge"]
grid = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

print("temperatures:", temperatures)
print("playlist:    ", playlist)
print("grid:        ", grid)

# %% [markdown]
# PART A — Building and reading

# %% [markdown]
# ### Question 1
#
# Warm-up. Build `countdown` holding the integers 10 down to 1 by wrapping a `range` in `list()`. Build `empty` as an empty list and print its length. Build `repeated` as the list `[0]` repeated 5 times. Print all three.
# > **HINT:** `range(start, stop, step)` — a negative step counts down, and the stop value is never included.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# From `temperatures` print: the first reading, the last reading, the highest and the lowest, and the average rounded to one decimal place.
# > **HINT:** `max`, `min`, `sum` and `len` all take the whole list — no loop required.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Slice `temperatures` four ways and print each: the first three readings; readings 3 to 5 inclusive; every second reading; and the whole list backwards. The last two need a step.
# > **HINT:** a slice takes a third value, `[start:stop:step]`. `[::2]` is every second item and `[::-1]` walks the list backwards.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `grid` is a list of three rows. Print the middle row, the single value `5` from it, the first column as a list built with a comprehension, and the value in the bottom-right corner using two negative indices.
# > **HINT:** for the column, loop over the rows and take index 0 from each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Changing it, and the two traps again

# %% [markdown]
# ### Question 5
#
# Modify `playlist`, printing it after each step: replace the item at index 0 with `"opening"`; `append` `"outro"`; `insert` `"solo"` before the bridge (index 4); and `extend` it with `["applause"]`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# `playlist` contains `"verse"` more than once. Print how many times it appears and the index of the first one. Then `remove("verse")` once, print the list, and print the count again. Finally `pop()` with no argument at all, printing what came back.
# > **CAREFUL:** `pop()` with no index removes the *last* item, not the first.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Sort a copy of `temperatures` ascending without disturbing the original, and print both. Then sort the copy descending in place and print it. Then print what `sorted(temperatures, reverse=True)` returns.
# > **CAREFUL:** `.sort()` changes the list and returns `None`; `sorted()` returns a new list and changes nothing. Worksheet 01 Q9 is the same trap from the other side.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Show the aliasing trap once more on nested data. Set `original = [[1, 2], [3, 4]]`, then `shallow = original.copy()`, then append `99` to `shallow[0]`. Print both and explain what you see in a comment.
# > **CAREFUL:** `copy()` makes a new *outer* list, but the inner lists are still shared. This is the one case where `copy()` is not enough.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Stretch. In one line each, build and print: `hot`, the readings above 20; `celsius_to_f`, every reading converted with `c * 9 / 5 + 32`; and `labels`, the string `"warm"` for readings above 20 and `"cool"` otherwise.
# > **HINT:** the third one needs a conditional *expression* inside the comprehension: `[a if test else b for x in items]`. Note that `if` goes before the `for`, unlike a filter.

# %%
############################
## Your Code Here
############################
