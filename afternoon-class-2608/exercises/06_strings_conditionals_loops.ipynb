# %% [markdown]
# # Afternoon class 26/08 — Worksheet 06: Strings, conditionals and loops
#
# Worksheets 01–10 were about the four data structures and the built-ins. This one is about the
# language around them: arithmetic, picking strings apart, making decisions,
# and repeating work.
#
# It covers the same ground as the course's own `Python Exercises 1`
# (in `exercises/wcd-originals/`) — so if you have already worked through that
# notebook, this is the second pass, with the expected output written down.
#
# Run the setup cell once, then work down. Nothing here raises on purpose, so
# Restart & Run All should stay clean the whole way.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 06 — Strings, conditionals and loops. Run this once.
sentence = "Data engineering is mostly plumbing. The rest is naming things. Both are hard."
emails = ["ada@runink.org", "bo@example.co.uk", "cai@data.example.com"]
price_tags = ["$1,200.00", "$4.50", "$890.00", "$22.00"]
numbers = [8, 3, 12, 7, 20, 5, 16]
answer_word = "python"

print("sentence:  ", sentence)
print("emails:    ", emails)
print("price_tags:", price_tags)
print("numbers:   ", numbers)

# %% [markdown]
# PART A — Numbers and strings

# %% [markdown]
# ### Question 1
#
# Warm-up. A train leaves the depot with 34 passengers. At the first stop 12 get off and 7 get on. At the second stop 9 get off and 15 get on. Print how many passengers are aboard now, using **one** expression.
# > **HINT:** one `print()`, one arithmetic expression, no intermediate variables.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Without changing `numbers`: print it sorted ascending; print the second-largest value using a negative index on the sorted list; and print the three smallest values. Then print `numbers` itself to prove it never changed.
# > **HINT:** `sorted()` returns a new list — worksheet 05 Q4. Sort once and reuse the result rather than sorting three times.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# `sentence` contains three sentences separated by `". "`. Split it on that separator, print the resulting list and how many pieces you got, then print the first piece in upper case. Look closely at the last piece.
# > **CAREFUL:** you are splitting on `". "` — a full stop *and* a space. The final sentence has no space after its full stop.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# For each address in `emails`, print the full domain (everything after the `@`) and its top-level domain (the piece after the final dot), on one line each.
# > **HINT:** split twice. `"a@b.com".split("@")` gives you two pieces; splitting the second of those on `"."` and taking `[-1]` gives the last piece however many dots there are.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# `price_tags` holds strings, not numbers. Convert each one to a float and print the running list, then print the total. You will have to remove the `$` and the thousands comma first.
# > **CAREFUL:** `float("$1,200.00")` raises. Strip both characters before converting, or the very first tag stops you.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Making decisions

# %% [markdown]
# ### Question 6
#
# For each score in `[95, 73, 41]`, print the score and a band: `high` for 80 or more, `medium` for 60 or more, and `low` otherwise. Use `if`/`elif`/`else`.
# > **HINT:** order matters. Test the highest threshold first, or 95 will match the `60 or more` branch on its way past.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# `answer_word` is `"python"`. For each letter in `["a", "y", "z", "t"]`, print the letter and whether it is a `hit` or a `miss` against `answer_word`.
# > **HINT:** `in` works on a string as well as on a list — it asks whether one string appears inside another.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Repeating work

# %% [markdown]
# ### Question 8
#
# Using a `for` loop over `range`, print the sum of the first 10 positive integers. Then, in a second loop, print the sum of the even numbers from 1 to 20 inclusive. Build both totals with an accumulator rather than a formula.
# > **HINT:** `range(1, 11)` stops before 11, so it gives you 1 to 10. For the evens, a step of 2 saves you an `if`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Using a `while` loop, count down from 5 to 1 printing each number, then print `liftoff` once the loop has finished.
# > **CAREFUL:** the counter must change inside the loop. Forget that line and the condition stays true forever — press the stop button if you do.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# From `numbers`, build a list of only the even values three different ways, printing each result: with a `for` loop and `append`; with a list comprehension; and with `filter()` and a `lambda`. Confirm all three agree.
# > **HINT:** a number is even when `n % 2 == 0`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Stretch: a whole small program
#
# Hangman. Everything you need is on this sheet already: a list, a string, a
# loop, a conditional and a counter. Nothing new.

# %% [markdown]
# ### Question 11
#
# Play Hangman against `answer_word` using the fixed list `guesses = ["p", "a", "t", "e", "h", "o", "n", "y"]`. Start with a board of underscores, one per letter, and 5 lives. For each guess: if it is in the word, reveal every position where it appears; if not, lose a life. Print the board after each guess. Stop early with a message when the board is complete or the lives run out.
# > **HINT:** build the board as a **list** of `"_"` so you can assign to positions, and print it with `"".join(board)`. A string would not let you change a character — worksheet 02's lesson, arriving where you need it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 12
#
# Stretch. Turn Q11 into a real game driven by `input()` instead of a fixed list. Write it out, but leave every line commented, and say in a comment why a live `input()` is a problem in a notebook you want to re-run.
# > **CAREFUL:** do not leave `input()` live in a saved notebook. It blocks the kernel waiting for typing, so Restart & Run All hangs on that cell forever.

# %%
############################
## Your Code Here
############################
