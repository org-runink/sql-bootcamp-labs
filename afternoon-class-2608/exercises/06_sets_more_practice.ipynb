# %% [markdown]
# # Afternoon class 26/08 — Worksheet 06: Sets, more practice   (L04)
#
# Extra repetition on worksheet 05, with different data and two things that
# sheet did not cover: building a set from a string, and deduplicating a list
# **while keeping its order** — which a plain `set()` cannot do.
#
# Run the setup cell once, then work down. **Question 7 is supposed to raise an
# error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 06 — Sets, more practice. Run this once.
monday_visitors = {"ada", "bo", "cai", "dee"}
tuesday_visitors = {"bo", "dee", "eve", "fay"}
required_skills = {"python", "sql"}
applicant_skills = {"python", "sql", "docker"}
tags = ["data", "python", "data", "sql", "python", "data"]

print("monday:   ", monday_visitors)
print("tuesday:  ", tuesday_visitors)
print("tags:     ", tags)

# %% [markdown]
# PART A — Building sets

# %% [markdown]
# ### Question 1
#
# Warm-up. Build `letters` from the string `"mississippi"` using `set()` and print it with its length. Build `evens` from `range(2, 11, 2)`. Build an empty set and add `"x"` twice, printing the length after each add.
# > **HINT:** `set("word")` iterates the string character by character — the same behaviour that made `extend("salt")` surprising in worksheet 01.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print whether `"ada"` visited on Monday, whether `"eve"` did, and how many distinct people visited on each day.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Comparing two collections

# %% [markdown]
# ### Question 3
#
# Using `monday_visitors` and `tuesday_visitors`, print: everyone who visited at all; those who came both days; those who came Monday only; those who came Tuesday only; and those who came on exactly one of the two days. Use the operator form.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Answer three hiring questions with set comparisons, printing each: does the applicant have every required skill; does the applicant have any skill that is not required; and are the required skills and `{"java", "scala"}` completely unrelated?
# > **HINT:** "has every required skill" is a subset/superset question, not a loop.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Show that the three set relationships agree with each other. Print `applicant_skills.issuperset(required_skills)` and `required_skills.issubset(applicant_skills)`, then print whether the two results are equal.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Changing sets, and the order problem

# %% [markdown]
# ### Question 6
#
# Change `monday_visitors`, printing it after each step: `add` `"gus"`; `update` it with the list `["hal", "ivy"]`; `discard` `"nobody"`, who is not there; and `remove` `"ada"`, who is.
# > **HINT:** `update` accepts any iterable, so a list works — it does not have to be another set.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Now call `remove("ada")` a second time and let it fail. Then write the safe version underneath as a comment. This cell is meant to fail.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# `tags` has repeats. Print its length, then print the distinct tags via `set()` with the count. Then deduplicate it **keeping the original order** using a loop and a `seen` set, and print that. Compare the two results.
# > **CAREFUL:** `list(set(tags))` deduplicates but scrambles the order. When order matters you need the loop.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Stretch. In one line each, print: the set of tag lengths; the set of tags with more than three characters; and the set of the first letters of everyone who visited on either day.

# %%
############################
## Your Code Here
############################
