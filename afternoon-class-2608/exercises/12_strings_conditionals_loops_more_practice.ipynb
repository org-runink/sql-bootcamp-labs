# %% [markdown]
# # Afternoon class 26/08 — Worksheet 12: Strings, conditionals and loops, more practice
#
# Extra repetition on worksheet 11, with different data and three things that
# sheet did not cover: `and`/`or` in a condition, `break`/`continue` inside a
# loop, and parsing a whole CSV-shaped line into fields.
#
# It ends with FizzBuzz — the most-asked interview warm-up there is, and a fair
# test of whether the `if`/`elif` ordering rule has landed.
#
# Run the setup cell once, then work down. Nothing here raises on purpose.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 12 — Strings, conditionals and loops, more practice. Run this once.
log_line = "2026-08-26,ERROR,payment-service,timeout after 30s"
csv_rows = [
    "ada,36,Toronto",
    "bo,24,Ottawa",
    "cai,41,Montreal",
]
title = "  the Rest is Naming Things  "
basket = [12.99, 4.50, 30.00, 7.25, 99.99]

print("log_line:", log_line)
print("csv_rows:", csv_rows)
print("title:   ", repr(title))
print("basket:  ", basket)

# %% [markdown]
# PART A — Taking strings apart

# %% [markdown]
# ### Question 1
#
# Warm-up. A shop sells 3 items at 12.50 and 2 items at 7.25, then applies a 10.00 delivery charge. Print the total in one expression, then print it again rounded to two decimal places.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# `title` has stray spaces and inconsistent capitals. Print it with the surrounding spaces removed; then in lower case; then in upper case; then with every word capitalised. Finally print the original to show none of it stuck.
# > **HINT:** `.strip()` removes leading and trailing whitespace, `.title()` capitalises each word. Every string method returns a NEW string.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# `log_line` has four comma-separated fields. Split it, print the list and its length, then print the date, the severity and the service on separate lines by unpacking the four fields into named variables.
# > **HINT:** the number of names on the left of the `=` must match the number of fields exactly — the tuple-unpacking rule from worksheet 03.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `csv_rows` is a list of comma-separated records. Loop over it, split each row, convert the age to an integer, and print a line like `ada is 36 and lives in Toronto`. Then print the average age.
# > **HINT:** collect the ages into a list as you go, so you can total them afterwards.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Conditions that combine

# %% [markdown]
# ### Question 5
#
# For each price in `basket`, print the price and a label: `bargain` if it is under 10, `mid` if it is 10 or more **and** under 50, and `premium` otherwise. Use `and` in the middle test even though `elif` makes it optional, then say in a comment why it is optional.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Print whether the log line is worth alerting on: `True` when the severity is `ERROR` **or** `CRITICAL`. Then print whether it is a quiet line: severity is `INFO` **and** the message does not contain `timeout`.
# > **HINT:** `or` is true when either side is; `and` needs both. `not` flips a condition.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Controlling a loop

# %% [markdown]
# ### Question 7
#
# Loop over `basket` and print each price, but stop the loop entirely as soon as you meet a price above 50. Then loop again and print every price *except* those under 10, without stopping early.
# > **HINT:** `break` leaves the loop; `continue` skips to the next item. Only one of the two ends the loop.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Using a `while` loop, spend from a budget of `50.00`: walk through `basket` in order, subtracting each price while the budget can still afford the next item. Print the remaining budget after each purchase, and print how many items you bought.
# > **CAREFUL:** the loop needs two ways to end — running out of budget, and running out of items. Miss the second and you index past the end of the list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Count the vowels in `log_line`, ignoring case, using a loop and a counter. Print the total. Then print the same number using a one-line comprehension with `len()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Stretch. FizzBuzz. For every number from 1 to 20, print `Fizz` when it divides by 3, `Buzz` when it divides by 5, `FizzBuzz` when it divides by both, and the number itself otherwise. Get all 20 lines right.
# > **CAREFUL:** test the both-case FIRST. Put it last and 15 prints `Fizz`, because the `elif` chain stops at the first branch that matches.

# %%
############################
## Your Code Here
############################
