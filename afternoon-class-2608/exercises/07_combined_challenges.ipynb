# %% [markdown]
# # Afternoon class 26/08 — Worksheet 07: Combined challenges   (L04)
#
# The capstone. Nothing here teaches a new structure or a new function —
# every challenge is answered with lists, tuples, sets, dictionaries and the
# built-ins from worksheets 01–06.
#
# What is new is the shape of the work. `order_lines` is a **list of tuples**,
# one tuple per order line, which is what a file of records looks like once you
# have read it in. Each challenge is a question a manager would actually ask,
# and **each one ends with a question to answer in words** — in a comment, in
# the cell. Those are not padding. Writing the code is the easy half; knowing
# what the number does *not* entitle you to conclude is the half that matters.
#
# If you did the SQL sessions on 24/08 and 25/08, `order_lines` will feel
# familiar on purpose: one row per order LINE, not per order. That distinction
# caused most of the wrong answers there, and it is waiting for you here too.
#
# Run the setup cell once, then work down.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 07 — Combined challenges. Run this once.
#
# One tuple per ORDER LINE. An order with three products is three lines
# here, all sharing an OrderID -- exactly like superstore.orders on 24/08.
#
#              OrderID  Customer  Region     Category           Qty   UnitPrice
order_lines = [
    (1001,    "Ada",    "East",    "Technology",       1,  1200.00),
    (1001,    "Ada",    "East",    "Office Supplies",  3,     4.50),
    (1001,    "Ada",    "East",    "Furniture",        1,   340.00),
    (1002,    "Bo",     "West",    "Technology",       2,   650.00),
    (1003,    "Ada",    "East",    "Office Supplies", 10,     4.50),
    (1004,    "Cai",    "Central", "Furniture",        1,   890.00),
    (1004,    "Cai",    "Central", "Office Supplies",  5,    12.00),
    (1005,    "Dee",    "North",   "Technology",       1,   320.00),
    (1005,    "Dee",    "North",   "Technology",       1,    99.00),
    (1005,    "Dee",    "North",   "Office Supplies",  2,     4.50),
    (1005,    "Dee",    "North",   "Furniture",        2,   150.00),
    (1006,    "Bo",     "West",    "Office Supplies",  1,    22.00),
]

# A second structure, to be joined onto the first later.
customer_city = {"Ada": "Toronto", "Bo": "Vancouver", "Cai": "Montreal"}

print("order lines loaded:", len(order_lines))
print("first line:", order_lines[0])

# %% [markdown]
# CHALLENGE 1 — How big is this dataset, really?
#
# Before any analysis, three different numbers could all be called "the size"
# of this data, and they disagree. Find all three.

# %% [markdown]
# ### Question 1a
#
# Print the number of order lines, the number of distinct orders, and the number of distinct customers. Print the set of customers too.
# > **HINT:** the OrderID is `line[0]` and the customer is `line[1]`. A set comprehension over one field gives you the distinct values.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 1b
#
# Answer in words, in a comment. Your manager asks "how many orders did we take?" Which of the three numbers is the honest answer, and what would go wrong if you reported one of the others?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 2 — Where does the revenue come from?
#
# Each line's revenue is quantity times unit price. Nothing in the data holds
# that figure; you have to compute it.

# %% [markdown]
# ### Question 2a
#
# Build a dictionary of total revenue per category, then print each category and its total, biggest first. Also print the grand total.
# > **HINT:** start with an empty dict, and for each line add to `revenue[category]` — creating the key with a zero first if it is not there yet. To order by value, `sorted(d.items(), key=lambda pair: pair[1], reverse=True)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2b
#
# Answer in words, in a comment. Technology is the biggest category. Is it the most *important* one, on this evidence?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 3 — The biggest order
#
# Same accumulator pattern, different key. This is the one place the
# line-versus-order distinction does real work.

# %% [markdown]
# ### Question 3a
#
# Build a dictionary of total revenue per OrderID and print every order with its total, biggest first. Then print just the winning OrderID and its value.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3b
#
# Answer in words, in a comment. Order 1001 wins. Would it still have won if you had ranked individual order *lines* instead of orders?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 4 — Customer reach
#
# A dictionary whose values are SETS. This is the shape to reach for whenever
# the question is "which distinct things does each X touch".

# %% [markdown]
# ### Question 4a
#
# Build a dictionary mapping each customer to the set of categories they bought from. Print it, then print each customer with how many distinct categories they touched, and finally the set of customers who touched all three.
# > **HINT:** the value starts as an empty `set()` and you `add` to it. Because it is a set, buying the same category twice cannot double-count.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4b
#
# Answer in words, in a comment. Why is a set the right value type here, and what would have happened had you used a list?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 5 — Joining two structures
#
# `customer_city` is a second, separate structure. Attaching it to the order
# data is the Python equivalent of the joins you wrote on 24/08 — and it has
# the same failure mode.

# %% [markdown]
# ### Question 5a
#
# Build a dictionary of total revenue per customer. Then print each customer, their city and their revenue, using `customer_city` to look the city up. Handle a customer who is not in `customer_city` without crashing.
# > **CAREFUL:** look at `customer_city` before you start. Not every customer is in it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5b
#
# Answer in words, in a comment. Dee has no city. Suppose you had written this as a report grouped by city, skipping customers that `customer_city` does not know. How much revenue would silently vanish, and what fraction of the total is that?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 6 — A report someone could actually read
#
# Same numbers as Challenge 2, presented properly. `enumerate` supplies the
# rank and an f-string does the alignment.

# %% [markdown]
# ### Question 6a
#
# Print a ranked table of categories by revenue: a rank number starting at 1, the category name padded to 16 characters, and the revenue right-aligned to 2 decimal places. Add a total row underneath.
# > **HINT:** inside an f-string, `{name:<16}` left-aligns in 16 characters and `{value:>10.2f}` right-aligns to 10 characters with 2 decimals.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6b
#
# Answer in words, in a comment. `enumerate(ranked_categories, start=1)` gives you `(rank, (category, total))`. Why are there brackets around `(category, total)` in the `for` statement?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 7 — Inverting a dictionary
#
# A reasonable-looking transformation with a trap in it. Read the lengths
# before you read anything else.

# %% [markdown]
# ### Question 7a
#
# Build a dictionary mapping each category to the number of DISTINCT ORDERS it appears in. Print it and its length. Then invert it, so the counts become the keys, print that and its length too.
# > **HINT:** the value is again a set of OrderIDs while you accumulate; take `len()` of each at the end.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7b
#
# Answer in words, in a comment. The inverted dictionary is shorter than the one you inverted. Which category disappeared, why, and what does that tell you about when inverting is safe?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# CHALLENGE 8 — Stretch: the executive summary
#
# One cell, the headline numbers, the way they would appear on a slide. Every
# one of them has a grain trap somewhere near it.

# %% [markdown]
# ### Question 8a
#
# Stretch. In one cell print: total revenue; the number of order lines; the number of orders; the number of customers; the average order value; the average line value; and the best category with its revenue. Then check each figure against a separate simple calculation before you trust it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8b
#
# Answer in words, in a comment. Two of the numbers you just printed could each be called "the average order value", and they differ by a factor of two. Which is which, and which one would you put on the slide?

# %%
############################
## Your Code Here
############################
