# %% [markdown]
# # Afternoon class 26/08 — Worksheet 04: Tuples, more practice   (L04)
#
# Extra repetition on worksheet 03, with different data and two angles that
# sheet did not cover: swapping variables through unpacking, and what happens
# when a tuple contains something mutable.
#
# Run the setup cell once, then work down. **Question 5 is supposed to raise an
# error** — that is the answer, not a mistake.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 04 — Tuples, more practice. Run this once.
rgb = (255, 128, 0)
student = ("Ada", 23, "Data Engineering", 3.9)
week = ("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun")
readings = [("Mon", 18), ("Tue", 21), ("Wed", 19), ("Thu", 25)]

print("rgb:     ", rgb)
print("student: ", student)
print("week:    ", week)
print("readings:", readings)

# %% [markdown]
# PART A — Building and reading

# %% [markdown]
# ### Question 1
#
# Warm-up. Build `origin` as the tuple `(0, 0)`. Build `one_item` as a tuple holding only the string `"solo"`. Build `from_list` by passing the list `[1, 2, 3]` to `tuple()`. Print all three and the `type()` of `one_item`.
# > **CAREFUL:** a one-item tuple needs its trailing comma. Without it you have made a plain string.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# From `student` print the name, the GPA using a negative index, and the middle two fields as a slice. Then print how many fields the record has.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# From `week` print the first three days, the weekend as a slice using negative indices, and every second day using a step. Then print the days backwards.
# > **HINT:** step slicing works on tuples exactly as it did on lists in worksheet 02 Q3.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Unpack `rgb` into `red`, `green` and `blue` and print them. Unpack `student` into four names and print a sentence using two of them. Then unpack `week` with `first, *rest, last` and print all three parts.
# > **HINT:** `*rest` can sit in the middle. It absorbs everything not claimed by the names on either side.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Try to brighten the colour: assign `255` to `rgb[1]`. Run it, read the error, and note in a comment how you would actually produce a brightened colour instead. This cell is meant to fail.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Two things worksheet 03 did not show you

# %% [markdown]
# ### Question 6
#
# Swap two variables using unpacking. Set `a = 1` and `b = 2`, print them, then swap them in a single line without a temporary variable, and print them again.
# > **HINT:** the right-hand side of `a, b = b, a` builds a tuple first, then unpacks it. That is why no temporary is needed.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# A tuple is immutable, but that only protects the tuple itself. Build `mixed = ("fixed", [1, 2])`, then append `3` to `mixed[1]` and print `mixed`. Explain in a comment why this is allowed when Q5 was not.
# > **CAREFUL:** read the result before you decide it contradicts everything you have been told. It does not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Operators, methods and a stretch

# %% [markdown]
# ### Question 8
#
# Print `week + ("Bank Holiday",)` and `("a", "b") * 3`. Then print whether `"Wed"` is in `week` and whether `"Funday"` is not in `week`. Finally print the index of `"Fri"` and how many times `"Mon"` appears.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Stretch. `readings` is a list of `(day, temperature)` tuples. In one line each, print: `days`, holding just the day names; `warm_days`, the day names where the temperature is above 19; and `total`, the sum of all temperatures. Unpack inside each comprehension rather than indexing.
# > **HINT:** `for day, temp in readings` names both halves as it loops — the pattern you will use constantly once data arrives as records.

# %%
############################
## Your Code Here
############################
