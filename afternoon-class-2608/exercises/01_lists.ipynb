# %% [markdown]
# # Afternoon class 26/08 — Worksheet 01: Lists   (L04)
#
# Python only. No database, no `%%sql`, no connection — just the standard
# library, which is all the lecture covers.
#
# Run the setup cell once, then work down. The questions run **in order**, and
# several of them change `grocery_list` in place, so a later question sees the
# list as the earlier ones left it. If you lose track of what it holds, print
# it; if you want to start over, re-run the setup cell and work down again.
#
# Lecture reference: `[Python_L04]_Python_data_structures.pdf`, slides 4–21.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 01 — Lists. Run this once.
grocery_list = ["milk", "beef", "eggs", "bread", "apples", "coffee"]
numbers = [5, 3, 9, 1, 7]
condiments = ["ketchup", "mustard", ["salt", "pepper", "chilli"]]

print("grocery_list:", grocery_list)
print("numbers:     ", numbers)
print("condiments:  ", condiments)

# %% [markdown]
# PART A — Creating and reading a list

# %% [markdown]
# ### Question 1
#
# Warm-up. Build three lists of your own and print each one: `oily_fish` holding the strings `"salmon"`, `"mackerel"` and `"sardines"`; `prices` holding the numbers `12.50`, `7.25` and `3.99`; and `mixed_row` holding `"salmon"`, `3`, `True` and `12.50` — one row of a file, with four different types in it. Finish by printing `type(oily_fish)` to confirm what you built.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Python counts from zero, and negative indices count from the end. From `grocery_list` print the first item, the fourth item, the last item, and the second-to-last item. Use negative indexing for the last two — do not call `len()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Slice `grocery_list` three ways and print each result: the first two items, the items at index 3 and 4, and the last three items.
# > **HINT:** the end of a slice is exclusive, so `[3:5]` gives you indices 3 and 4 — not 3, 4 and 5.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `condiments` holds another list as its third item. Print that inner list, then the third item inside it, then everything from its third item onward. Each step needs one more set of square brackets than the last.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Changing a list in place

# %% [markdown]
# ### Question 5
#
# Lists are mutable, so you can assign straight to an index. Replace the first item of `grocery_list` with `"oat milk"` and the last item with `"tea"`, then print the list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Grow `grocery_list` three ways, printing it after each step: `append` the single item `"rice"`, `insert` `"butter"` at index 1, then `extend` it with the list `["salt", "pepper"]`. Finally, on a throwaway list `trap = ["milk"]`, call `trap.extend("salt")` with the bare string instead of a list, and print what you get.
# > **CAREFUL:** `extend` walks through whatever you hand it. A string is a sequence of characters, so `extend("salt")` adds four items, not one. `append("salt")` would add one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Shrink `grocery_list` again, printing it after each step: `remove` the value `"eggs"`; `pop` the item at index 0, printing the value `pop` hands back as well as the list; then `del` whatever is now at index 0. Finally, on a fresh list `dupes = ["milk", "beef", "milk"]`, call `remove("milk")` once and print the result.
# > **CAREFUL:** `remove` deletes the *first* match only, not every match.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Operators, ordering, and two traps

# %% [markdown]
# ### Question 8
#
# No loops for any of this. Print how many items `grocery_list` now holds. Build `pantry` by concatenating `grocery_list` with `["rice", "salt"]` and print it. Print `["milk"] * 3`. Print whether `"beef"` is in `grocery_list`, and whether `"caviar"` is not in it. Then print the index of `"salt"` in `pantry` and how many times `"salt"` appears in `pantry`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Sort `numbers` ascending and print it, then reverse it and print it again. Now print the value that `numbers.sort()` itself returns, and print `numbers` once more. Say in a comment what would happen to your data if you wrote `numbers = numbers.sort()`.
# > **CAREFUL:** `sort()` and `reverse()` change the list in place and return `None`. Neither hands you a new sorted list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Set `original = [1, 2, 3]`, then `alias = original`, then append `4` to `alias` and print both names. Now build `true_copy = original.copy()`, append `5` to `true_copy`, and print both again. Explain the difference in a comment.
# > **CAREFUL:** `alias = original` does not copy anything. It gives one list a second name, and mutating either name changes the one list they share.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Stretch. In one line each, build and print three lists derived from `pantry`: `lengths`, holding the length of every item; `long_items`, holding only the items longer than four characters; and `shouted`, holding every item in upper case.
# > **HINT:** `[expression for item in iterable]`, with an optional `if condition` on the end to filter.

# %%
############################
## Your Code Here
############################
