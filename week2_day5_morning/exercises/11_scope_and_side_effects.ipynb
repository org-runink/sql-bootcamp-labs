# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 11: Scope and side effects   (L06)
#
# Slides 43–58 make the case for functions: less duplication, better readability,
# reuse. This sheet does that refactoring — and then asks the question the deck
# leaves out entirely.
#
# **Where do a function's variables live, and what can it change behind your
# back?** The deck's own resources list links *Python Scope: The LEGB Rule* and
# then never mentions scope again. This is that gap.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 43–58.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 11 — Scope and side effects. Run this once.
TAX_RATE = 0.20

orders_2019 = [2.50, 4.50, 2.00, 2.75, 2.50, 5.00, 8.00, 2.25]
orders_2020 = [3.50, 7.50, 1.10, 1.75, 3.50, 6.30, 4.60, 5.25]
orders_2021 = [4.00, 4.00, 9.90, 2.10, 3.30]

master_list = ["ana", "bo", "cai"]

print("TAX_RATE:", TAX_RATE)
print("master_list:", master_list)

# %% [markdown]
# PART A — Where names are looked up

# %% [markdown]
# ### Question 1
#
# Write `with_tax(amount)` that returns `amount * (1 + TAX_RATE)` — **without** taking `TAX_RATE` as a parameter. Call it on `100`. Then write `with_tax_explicit(amount, rate)` that takes the rate, and call that on `100, TAX_RATE`. Print both.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Now write `bump_rate()` which does `TAX_RATE = 0.25` and then prints `TAX_RATE`. Print `TAX_RATE` before the call, call `bump_rate()`, and print `TAX_RATE` again afterwards.
# > **THREE PRINTS. PREDICT ALL THREE.** The one inside the function and the one after it do not agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `bump_rate_global()` that declares `global TAX_RATE` before assigning `0.25`. Print `TAX_RATE` before and after, then call `with_tax(100)` again and compare it with Q1's answer. Finally set `TAX_RATE` back to `0.20`.
# > **THIS IS WHY Q1's SECOND VERSION IS THE BETTER ONE.** One function changed the answer of another function that never called it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — What a function can change behind your back

# %% [markdown]
# ### Question 4
#
# Write `rename(name)` that does `name = "CHANGED"` and prints it. Create `who = "ana"`, call `rename(who)`, and print `who` afterwards.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Now the same shape with a list. Write `add_name(names)` that does `names.append("dee")` and prints the list. Print `master_list` before, call `add_name(master_list)`, and print `master_list` after.
# > **Q4 AND Q5 ARE THE SAME CODE SHAPE AND THEY DO DIFFERENT THINGS.** Work out what changed before you read the answer.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Write the two honest versions. `added_copy(names, new)` returns a **new** list with `new` on the end and leaves the original alone; `added_inplace(names, new)` appends and returns `None`. Run each against a fresh `["x", "y"]` and print the original and the result in both cases.
# > **LOOK AT WHAT EACH ONE RETURNS.** The in-place version is not broken — `list.append` behaves exactly the same way.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — The case the deck is actually making

# %% [markdown]
# ### Question 7
#
# Slides 44 and 48 compute an average order size for 2019, then copy the whole block and do it again for 2020. Write `report_average(year, orders)` that does it once, and call it for 2019, 2020 **and** 2021. Print how many lines the deck's version would need for three years, and how many yours needs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Write `discounted(price)` returning `price * (1 - DISCOUNT)`, where `DISCOUNT` is a global you set to `0.10` **after** defining the function. Call it on `100`. Then set `DISCOUNT = 0.50` and call it on `100` again, with no other change. Print both results.
# > **THE FUNCTION WAS NOT EDITED BETWEEN THE TWO CALLS.** Neither was the argument.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# The LEGB order, in one cell. Set `value = "global"`. Define `outer()` which sets its own `value = "enclosing"` and defines `inner()` inside it; `inner()` sets `value = "local"` and prints it. Have `outer` call `inner` and then print its own `value`. Call `outer()`, then print `value` at the top level.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Print a function's own namespace. Write `inspect_me(a, b)` that creates a local `c = a + b`, then prints `sorted(locals())` and returns `c`. Call it with `1, 2`. Then print whether `"c"` is in `globals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Write `compute()` that sets a local `answer = 42` and prints it, call it, then print `answer` at the top level. Read the error, then write in a comment what the function should have done instead.
# > **THIS CELL IS SUPPOSED TO RAISE.** The function itself works perfectly.

# %%
############################
## Your Code Here
############################
