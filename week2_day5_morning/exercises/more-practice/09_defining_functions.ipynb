# %% [markdown]
# # Week 2, day 5 (morning) — Extra practice 09: Defining functions   (L06)
#
# A second pass at worksheet 09, on different data, plus two things the first
# sheet did not reach: composing small functions into bigger ones, and keeping
# functions in a **dictionary** so the caller can pick one by name.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 4–20.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 09 — Defining functions. Run this once.
raw_names = ["  Ana Lima ", "BO SILVA", "cai tan  ", " Dee  Okafor"]
temps_c = [0, 22, 37, -5]
readings = [3.2, 8.8, 1.0, 5.5]

print(raw_names)
print(temps_c)

# %% [markdown]
# ### Question 1
#
# Write `c_to_f(c)` and `f_to_c(f)`, each returning the converted temperature. Print the Fahrenheit value of every temperature in `temps_c`, then round-trip `22` through both and print whether you get `22` back.
# > **PREDICT THE ROUND TRIP.** Two exact formulas, and one of them involves dividing by 5.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Write `show_total(values)` that **prints** the sum, and `get_total(values)` that **returns** it. Try to use each one inside a bigger expression — `get_total(readings) * 2` and `show_total(readings) * 2` — printing the first and putting the second in a comment with what it would do.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `split_name(full)` that strips the whitespace, splits on spaces and returns the first and last parts as two values. Call it on every entry in `raw_names`, unpacking into two variables, and print them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Compose small functions. Write `tidy(text)` that strips, lowercases and collapses the name to `Title Case` by calling `.strip()`, `.lower()` and `.title()`. Then write `initials(text)` that **calls `tidy`** and returns the first letter of each word joined by dots. Print both for every raw name.
# > **`initials` MUST NOT REPEAT `tidy`'s WORK.** It calls it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Write a predicate — a function returning `True` or `False`. `is_freezing(c)` returns whether a temperature is at or below zero. Use it inside an `if` for each value in `temps_c`, and use it inside a list comprehension to count how many are freezing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Write `stats(values)` returning a dictionary with `count`, `total`, `mean`, `smallest` and `largest`. Give it a docstring naming what it assumes. Print it for `readings`, then print just the mean by indexing the result.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Keep functions in a dictionary. Build `converters = {"to_f": c_to_f, "to_c": f_to_c}` — the function objects, **no parentheses** — then look one up by name and call it. Print the result of `converters["to_f"](100)` and loop the dictionary printing each name with its result on `100`.
# > **NO PARENTHESES WHEN YOU PUT THEM IN.** Worksheet 09 Q5 is why this works.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Write `safe_first(values)` returning the first item, or `None` for an empty list. Call it on `readings`, on `[]`, and on `[0]`. Then print `safe_first([0]) is None` and `not safe_first([0])`, and say in a comment why those two disagree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Call `summarise_later(readings)` and define `summarise_later` on the line **after** the call. Read the error, then write in a comment what this says about when a `def` takes effect.
# > **THIS CELL IS SUPPOSED TO RAISE.** A working call prints first.

# %%
############################
## Your Code Here
############################
