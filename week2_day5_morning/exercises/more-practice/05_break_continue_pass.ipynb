# %% [markdown]
# # Week 2, day 5 (morning) — Extra practice 05: break, continue, pass   (L05)
#
# A second pass at worksheet 05, on different data, plus the question the first
# sheet did not ask: **what is the `break` of a comprehension?**
#
# The answer is that there isn't one, and knowing that is how you decide when a
# comprehension is the wrong tool.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 2 and 76–77.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 05 — break, continue, pass. Run this once.
log = [
    "INFO  service started",
    "DEBUG cache warm",
    "WARN  slow query 2.1s",
    "INFO  batch 1 ok",
    "ERROR disk full",
    "INFO  batch 2 ok",
    "ERROR connection lost",
]

numbers = [4, 7, 0, 9, 3, 0, 11, 6]
codes = {"AA": 1, "BB": 0, "CC": 7, "DD": 0}

print(len(log), "log lines,", len(numbers), "numbers")

# %% [markdown]
# ### Question 1
#
# Find the first `ERROR` line in `log`. Print it with its position, `break`, and print how many lines you had to read. Then print how many `ERROR` lines there are in total.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Search `log` for a `FATAL` line with a `for` … `else`, printing the line if found and `no fatal errors` if not. Then run the identical search for `WARN`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Total `numbers`, skipping the zeros with `continue`. Print the total, how many you added, and how many you skipped. Then print the mean over the values you kept and the mean over all of them.
# > **TWO MEANS, ONE SET OF NUMBERS.** Say which denominator you used.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Walk `numbers` and `break` out as soon as the running total passes `20`. Print the running total on each pass, then print where it stopped and how many values were never looked at.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Loop `codes.items()`. Use `pass` in the branch for entries whose value is `0` — you have not decided what to do with them yet — and print every code and value regardless. Print how many lines came out.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Now the question this sheet exists for. Build a list of the `numbers` up to but not including the first zero — that is, stop at the zero. Try it as a comprehension with a filter `if`, print the result, and then write the loop that actually does it. Print both and whether they agree.
# > **THE COMPREHENSION WILL RUN AND GIVE YOU SOMETHING.** It is not what you asked for.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Classify the log in one pass: count `INFO`, `WARN` and `ERROR` lines, `continue` past `DEBUG` lines entirely, and `break` if you ever see two `ERROR` lines. Print the counts, how many lines you read, and how many you never reached.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Nested. Loop `codes.items()` and, for each, loop `numbers` looking for a value equal to the code's number, `break`ing when you find it. Count the inner passes. Then add the flag that stops the whole search after the first match, and count again.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Loop `log` and `break` on the first `ERROR`, storing nothing. After the loop, print the variable `first_error`. Read the error, then write in a comment the one line that would have prevented it.
# > **THIS CELL IS SUPPOSED TO RAISE.** The loop itself works perfectly.

# %%
############################
## Your Code Here
############################
