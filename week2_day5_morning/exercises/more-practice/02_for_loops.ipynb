# %% [markdown]
# # Week 2, day 5 (morning) — Extra practice 02: For loops   (L05)
#
# A second pass at worksheet 02, on different data, plus the things the first
# sheet had no room for: `zip`, `sorted` in a loop header, iterating what
# `.split()` gives you, and building a list of lists.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 24–53.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 02 — For loops. Run this once.
cities = ["Toronto", "Lisbon", "Osaka", "Nairobi"]
populations = [2794, 545, 2691]          # thousands -- note the length
temps = [7, 17, 16, 26]

header = "order_id,customer,amount,status"
line = "1042,ana,88.50,shipped"

stock = {"widget": 12, "gizmo": 4, "sprocket": 30}

print(len(cities), "cities,", len(populations), "populations,",
      len(temps), "temperatures")

# %% [markdown]
# ### Question 1
#
# Loop `cities` and print each name with its length. Then loop it again with `enumerate` and print `1. Toronto`-style numbering, starting at 1.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Pair the cities with their temperatures using `zip`, printing `Toronto: 7`-style lines. Print `zip(cities, temps)` itself as well, without `list()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Loop the cities in alphabetical order with `sorted()`, then in reverse length order with `sorted(cities, key=len, reverse=True)`. Print `cities` afterwards to confirm it is unchanged.
# > **`sorted()` RETURNS A NEW LIST.** `cities.sort()` would change the original and return `None`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Now `zip` the cities with `populations`, which is one shorter. Print each pair, then print how many pairs came out and which city is missing.
# > **COUNT THE LINES AGAINST `len(cities)`.** Nothing raises here.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Split `header` and `line` on commas and loop the results with `zip`, printing `order_id = 1042`-style lines. Then build `record`, a dictionary of the same pairs, and print it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Loop `stock.items()` and print each item with a `low` or `ok` label at a threshold of 10. Count how many are low, and print the total number of units in stock.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Build a list of lists. For each city, build a two-item list holding the city and its temperature, and append it to `table`. Print `table`, then loop `table` and print `Toronto is 7 degrees` for each row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Loop the string `"Nairobi"` and count how many characters are vowels, using `in "aeiou"` on the lowercased character. Print the count, then print the same count for every city in one loop over `cities`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Loop `range(len(cities))` and print `cities[i]` next to `populations[i]`. Read the error, then write in a comment which line of Q4 does the same job safely.
# > **THIS CELL IS SUPPOSED TO RAISE.** Three lines print first.

# %%
############################
## Your Code Here
############################
