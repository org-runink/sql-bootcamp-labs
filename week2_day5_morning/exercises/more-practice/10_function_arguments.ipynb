# %% [markdown]
# # Week 2, day 5 (morning) — Extra practice 10: Function arguments   (L06)
#
# A second pass at worksheet 10, plus two things the first sheet did not reach:
# the bare `*` that makes arguments keyword-only on purpose, and the mutable
# default trap in its **dictionary** form, which is harder to spot than the list
# one.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 21–41.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 10 — Function arguments. Run this once.
scores = [88, 42, 95, 61, 77]
settings = {"host": "localhost", "port": 5432, "user": "lab"}
extra = {"timeout": 30, "retries": 3}

print("scores:  ", scores)
print("settings:", settings)

# %% [markdown]
# ### Question 1
#
# Write `connect(host, port=5432, secure=True)` printing its three arguments. Call it with only a host; with a host and a port; with a host and `secure=False`; and with all three named.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Make the options keyword-only. Write `connect_strict(host, *, port=5432, secure=True)` — note the bare `*` — and call it with `("db1", port=6432)`. Then put in a comment what `connect_strict("db1", 6432)` would do.
# > **THE BARE `*` TAKES NO ARGUMENTS.** It exists purely to say "everything after me must be named".

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `report(label, *values)` that prints the label, the count, and the total of everything it was given. Call it with three numbers written out, with no numbers at all, and with `*scores` unpacked.
# > **THE MIDDLE CALL IS THE ONE TO PREDICT.** `*args` with nothing in it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# The dictionary version of the trap. Write `remember(key, value, store={})` that puts the pair in `store` and returns it. Call it four times with different pairs, printing the result each time, with no `store` argument. Then write the fixed version and call it twice.
# > **FOUR CALLS, FOUR SEPARATE DICTIONARIES — OR NOT.** Predict all four lines.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Write `configure(**options)` that prints the options dictionary and returns how many were given. Call it with two named options, with none at all, with `**settings`, and with `**settings` merged with `**extra` in one call.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Write `grade(score, bands=None)` where `bands` defaults to `[(90, "A"), (80, "B"), (70, "C")]` built **inside** the body. Return the first band whose threshold the score meets, or `"F"`. Print the grade for every value in `scores`, then call it once with a custom `bands` of your own.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Order matters at the call site too. Write `tag(name, *tags, owner="nobody", **meta)` printing all four parts. Call it once the correct way — name, three tags, `owner=`, two extra keywords — and once **without** naming the owner, and compare the two outputs.
# > **THE SECOND CALL DOES NOT RAISE.** Worksheet 10 Q8 is the same shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Print a function's own signature information. For `tag`, print `tag.__name__`, `tag.__defaults__` and `tag.__kwdefaults__`. Then do the same for `connect` and for `grade`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Call `connect` with a host positionally **and** `host=` as a keyword: `connect("db1", host="db2")`. Read the error, then write in a comment which of Q1's four calls it most resembles.
# > **THIS CELL IS SUPPOSED TO RAISE.** A working call prints first.

# %%
############################
## Your Code Here
############################
