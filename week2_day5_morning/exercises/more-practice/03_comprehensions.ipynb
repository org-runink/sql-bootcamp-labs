# %% [markdown]
# # Week 2, day 5 (morning) — Extra practice 03: Comprehensions   (L05)
#
# A second pass at worksheet 03, on different data, plus three things the first
# sheet did not reach: `any()` and `all()` over a comprehension, a comprehension
# that reads a dictionary and returns a list, and the point at which a
# comprehension should go back to being a loop.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 54–66.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 03 — Comprehensions. Run this once.
prices = [4.5, 12.0, 0.0, 7.25, 30.0, 0.0]
skus = ["AA-1", "bb-2", "CC-3", "dd-4"]

sales = {"north": 1200, "south": 0, "east": 830, "west": 455}
matrix = [[1, 2, 3], [4, 5, 6]]

pairs = [("ana", 88), ("bo", 42), ("cai", 95), ("dee", 61)]

print("prices:", prices)
print("sales: ", sales)

# %% [markdown]
# ### Question 1
#
# Build `with_tax`, every price in `prices` multiplied by `1.2`, and `upper_skus`, every sku uppercased. Print both with their lengths.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Filter form. Build `nonzero`, the prices above `0`, and `dashed`, the skus whose second character is a lowercase letter (`s[1].islower()`). Print both with their lengths next to the length of the input.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Map form. Build `capped`, where every price above `10` becomes `10` and the rest stay as they are. Print it with its length, and print `len(capped) == len(prices)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `any()` and `all()` take a comprehension and give back one boolean. Print whether **any** price is `0`, whether **all** prices are above `0`, whether **all** skus contain a `-`, and whether **any** region in `sales` sold nothing.
# > **THIS IS THE SHAPE TO REMEMBER** for a validation check: one line, one boolean, no loop and no flag variable.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Read a dictionary, return a list. Build `busy`, the names of the regions in `sales` that sold more than `500`, sorted alphabetically. Then build `report`, a list of `"north: 1200"`-style strings using an f-string.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Dictionary comprehensions over `pairs`. Build `scores` keyed by name, then `passed` holding only the entries scoring `60` or more, then `banded` mapping every name to `"pass"` or `"fail"`. Print all three with their lengths.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Two nested comprehensions over `matrix`. Build `flat`, every number in one list, and `doubled_rows`, a list of lists with each number doubled. Print both.
# > **THE SECOND ONE HAS BRACKETS INSIDE BRACKETS.** The inner comprehension is the expression the outer one produces.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Now go too far. In **one** comprehension over `pairs`, produce `"ana: A"`-style strings where the letter is `A` at 90+, `B` at 80+, `C` at 60+ and `F` below, skipping anyone scoring under `50`. Print it. Then write the same thing as a plain loop, print that, and print whether the two agree.
# > **BOTH ARE CORRECT.** Decide which one you would rather find in a file you did not write.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Build a set comprehension of the `pairs` tuples themselves — `{p for p in pairs}` — and print it. Then try the same over `matrix`, whose items are lists. Read the error.
# > **THIS CELL IS SUPPOSED TO RAISE.** The first set prints normally.

# %%
############################
## Your Code Here
############################
