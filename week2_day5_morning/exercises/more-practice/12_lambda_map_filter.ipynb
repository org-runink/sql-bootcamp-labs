# %% [markdown]
# # Week 2, day 5 (morning) — Extra practice 12: Lambda, map and filter   (L06)
#
# A second pass at worksheet 12, plus three things the first sheet did not reach:
# sorting on **two** fields at once, `map` over **two** lists, and a dictionary of
# lambdas used as a lookup table of behaviour.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 59–67.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 12 — Lambda, map and filter. Run this once.
prices = [4.5, 12.0, 0.0, 7.25, 30.0]
quantities = [2, 1, 5, 3, 1]

books = [
    {"title": "Dune", "author": "Herbert", "year": 1965, "pages": 412},
    {"title": "Neuromancer", "author": "Gibson", "year": 1984, "pages": 271},
    {"title": "Ancillary Justice", "author": "Leckie", "year": 2013, "pages": 386},
    {"title": "Count Zero", "author": "Gibson", "year": 1986, "pages": 246},
]

print(len(books), "books")

# %% [markdown]
# ### Question 1
#
# Warm-up. Use a lambda with `map` to add 20% to every price, and a lambda with `filter` to keep the prices above `5`. Print both as lists with their lengths.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# `map` can walk **two** lists at once. Use `map(lambda p, q: p * q, prices, quantities)` to get the line totals, print them as a list, and print their sum. Then do it again with `quantities` one element shorter, and count the results.
# > **THE SECOND ONE IS `zip`'s BEHAVIOUR ALL OVER AGAIN.** Extra practice 02 Q4.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Sort `books` by year, then by pages descending, printing just the titles each time. Then sort by **two** fields at once — author, then year — by returning a **tuple** from the key function.
# > **A TUPLE KEY SORTS BY ITS FIRST ELEMENT, THEN THE SECOND.** That is how you get a two-level ordering in one call.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Use `max` and `min` with `key=lambda` to find the longest and shortest book, printing the title and page count. Then print the total pages using `sum` with a generator expression, and the average.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# `any` and `all` with a lambda-shaped test. Print whether **any** book is from before 1970, whether **all** books are over 200 pages, whether **any** is by `"Asimov"`, and whether **all** have a `title` key.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# A dictionary of lambdas. Build `ops = {"double": lambda x: x * 2, "half": lambda x: x / 2, "square": lambda x: x ** 2}`, then loop it printing each name and its result on `12`. Finally look one up by a name held in a variable and call it.
# > **THIS IS A `switch` STATEMENT, WHICH PYTHON DOES NOT HAVE.** A dict of functions is the usual replacement.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# No lambda needed. Sort the titles with `key=len`, with `key=str.lower`, and print `list(map(str.strip, [" a ", " b "]))`. Then print `sorted(books, key=len)` in a comment with what it would do.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# One-shot again, with `zip`. Build `pairs = zip(prices, quantities)`, print `list(pairs)`, then print `list(pairs)` a second time. Then print `sum(p * q for p, q in zip(prices, quantities))`.
# > **SAME TRAP AS WORKSHEET 12 Q10, DIFFERENT ITERATOR.** `zip`, `map`, `filter` and `enumerate` all behave this way.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Call a two-argument lambda with one argument: `(lambda x, y: x + y)(1)`. Read the error, then write in a comment what `map(lambda p, q: p * q, prices)` would do instead.
# > **THIS CELL IS SUPPOSED TO RAISE.** A working call prints first.

# %%
############################
## Your Code Here
############################
