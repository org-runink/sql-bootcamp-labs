# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 09: Defining functions   (L06)
#
# The first sheet of the **L06** material. Everything up to worksheet 08 was
# written without a single `def`; from here on that is the whole point.
#
# A function is a block of code with a name, which runs only when you call it,
# takes data in as parameters and hands data back with `return`. This sheet is
# about those four things and the one confusion that trips up everybody:
# **printing a value and returning a value are not the same.**
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 4–20.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 09 — Defining functions. Run this once.
PI = 3.14159265359

orders_2019 = [2.50, 4.50, 2.00, 2.75, 2.50, 5.00, 8.00, 2.25]
orders_2020 = [3.50, 7.50, 1.10, 1.75, 3.50, 6.30, 4.60, 5.25]

readings = [4.2, 0.0, 7.9, 3.1, 12.5]

# For the login question -- what somebody typed, instead of input().
attempts = ["hunter2", "password", "D4t4Sc13nc3!"]
bad_attempts = ["aaa", "bbb", "ccc", "D4t4Sc13nc3!"]

print(len(orders_2019), "orders in 2019,", len(orders_2020), "in 2020")

# %% [markdown]
# PART A — def, call, return

# %% [markdown]
# ### Question 1
#
# Slide 14. Write `circumference_of_circle(radius)`: it multiplies `2 * PI * radius` and **returns** the answer. Print the result for a radius of `5` and of `1`, and print the sum of the two.
# > **FOUR PARTS:** the `def` keyword, a name, parentheses holding the parameters, and a colon — then the body indented underneath.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Write **two** functions that look almost identical. `shout_print(name)` **prints** `HELLO ANA` and returns nothing; `shout_return(name)` **returns** the same string and prints nothing. Call each one, then capture each one's result in a variable and print that variable.
# > **THIS IS THE MOST IMPORTANT QUESTION ON THE SHEET.** Predict all four outputs before you run it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `min_max(values)` that walks a list and returns **two** things — the smallest and the largest — without using `min()` or `max()`. Call it on `readings`, unpacking the result into two variables, and print them. Then print the raw return value and its `type()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Give `min_max` a **docstring** — a string as the very first line of the body, saying what it does and what it returns. Print `min_max.__doc__`, then call `help(min_max)`.
# > **A COMMENT IS FOR THE NEXT PERSON READING THE CODE. A DOCSTRING IS FOR THE NEXT PERSON *CALLING* IT.** Only one of them survives into `help()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# A function is a value like any other. Print `circumference_of_circle` **without** parentheses, then with them and an argument. Then assign it to a new name `circ`, call `circ(5)`, and print whether `circ is circumference_of_circle`.
# > **THE PARENTHESES ARE THE CALL.** Without them you are talking about the function; with them you are running it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Returning early, and returning nothing

# %% [markdown]
# ### Question 6
#
# Write `classify(n)` with three `return` statements: `"negative"` below zero, `"zero"` at zero, `"positive"` above. Put `print("still running")` as the last line of the function body. Call it on `-3`, `0` and `7`, and say in a comment how many times `still running` appeared.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Slide 17. Write `predict_fraud(amount_usd, card_country, countries_used)` exactly as the deck has it — nested `if`s returning `1.00`, `0.50` or `0.25` — and call it four times so that **every** branch runs at least once. Print each score with the arguments that produced it.
# > **FOUR BRANCHES, FOUR CALLS.** A function you have only called once has only been tested once.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Functions that use other functions

# %% [markdown]
# ### Question 8
#
# Write `average(values)` returning the mean, then `describe(name, values)` that **calls** `average` and returns a dictionary holding the name, the count, the total, the average, and the min and max from `min_max`. Print `describe` for `orders_2019` and for `orders_2020`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Slide 16, without `input()`. Write `login(guesses, password)` that walks the guesses, stops at the first correct one, and **returns** `True` or `False` — printing an attempt line each time. Call it once with `attempts` and once with `bad_attempts`, capped at three tries in both cases.
# > **RETURN THE ANSWER, DO NOT PRINT IT.** The deck's version prints and returns nothing, so the caller cannot act on the result.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Write `safe_average(values)` that returns `None` when the list is empty and the mean otherwise. Call it on `readings`, on `[]`, and print both results. Then print what `average([])` would need in order not to break, in a comment.
# > **THE EMPTY CASE IS NOT A CORNER CASE.** It is what an empty file, a filtered-out group, and a first run all look like.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Slide 24. Call `predict_fraud` with only two arguments. Read the error, then write in a comment how it differs from calling it with four.
# > **THIS CELL IS SUPPOSED TO RAISE.** The correct call prints first.

# %%
############################
## Your Code Here
############################
