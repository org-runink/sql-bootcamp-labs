# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 04: While loops   (L05)
#
# A `for` loop is a **definite** loop — the collection says how many passes there
# will be. A `while` loop is an **indefinite** one: it runs until a condition
# stops being true, and nothing guarantees that ever happens. That is the whole
# difference, and every question on this sheet comes back to it.
#
# The deck drives its examples with `input()`. Nothing here does — an `input()`
# call blocks the kernel and makes a notebook impossible to re-run cleanly, so
# the guessing game reads from a fixed list of guesses instead.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 67–77.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 04 — While loops. Run this once.
balance = 1000.0          # Q3 halves this
funds = 1000.0            # Q5 spends this
withdrawals = [120.0, 300.0, 250.0, 400.0, 90.0]

job_queue = ["job-a", "job-b", "job-c"]

secret = 37
guesses = [50, 25, 30, 37]   # what a player happened to try, in order

print("balance:    ", balance)
print("withdrawals:", withdrawals)
print("job_queue:  ", job_queue)

# %% [markdown]
# PART A — The shape of a while loop, and the one line people forget

# %% [markdown]
# ### Question 1
#
# Slides 72–73. Print `0` to `4` with a `while` loop driven by a `count` variable. Print `count` again *after* the loop. Then print the same five numbers with a `for` loop over `range(5)`, and print that loop's variable afterwards too.
# > **THREE PARTS, ALL REQUIRED:** set the counter before the loop, test it in the condition, and change it inside the body. Miss the third and the loop never ends.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Now leave the counter alone on purpose. Write `while count < 5:` with **no** `count = count + 1` in the body — but add a second condition, `guard < 20`, and increment `guard` instead. Print how many times the body ran and what `count` ended up as.
# > **THE GUARD IS WHY THIS CELL IS SAFE TO RUN.** Without it this is an infinite loop and you would have to interrupt the kernel.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — When you cannot know the number of passes in advance

# %% [markdown]
# ### Question 3
#
# Halve `balance` until it drops below `100`. Count the passes, and print the balance and the number of halvings afterwards. Then write in a comment why this could not have been a `for` loop without working the answer out first.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Drain `job_queue` with `while job_queue:` — no counter, no length test. Inside the loop take the first job with `.pop(0)`, print `running <job>` and how many are left. Print the queue after the loop.
# > **THE CONDITION IS THE LIST ITSELF.** This is worksheet 01's truthiness, doing real work: a list with items in it is true, an empty one is false.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Spend `withdrawals` out of `funds`, in order, but **stop before overdrawing**: only take the next withdrawal if it still fits. Use a `while` over an index. Print each withdrawal you clear, then how many cleared, how many were left untried, and the closing balance.
# > **NOTICE WHAT THIS CANNOT DO.** It stops at the first one that does not fit — it does not skip it and carry on to the next.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — while True, and how to get back out

# %% [markdown]
# ### Question 6
#
# Slides 74–75, without `input()`. Walk through `guesses` inside a `while True:` loop, comparing each with `secret`. Print `Guess higher...` or `Guess lower...` as appropriate, and `break` out when the guess is right, printing how many tries it took.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# The same loop is one bad input away from running forever — if the right guess is never in the list, `break` never fires and `guesses[i]` eventually runs off the end. Rewrite it with a **cap**: `while tries < 10:` instead of `while True:`, and after the loop print whether it found the answer. Then run it against `[50, 25, 30]`, which does not contain the secret.
# > **THIS IS THE PATTERN TO KEEP.** Every retry loop you write in real work — a network call, a poll, a queue read — needs a maximum number of attempts.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Three ways a while loop goes wrong

# %% [markdown]
# ### Question 8
#
# Start `x = 0.0` and loop `while x != 1.0:` adding `0.1` each pass — with a guard capping it at 50 passes. Print `x` and the number of passes afterwards, then print `x == 1.0` and `0.1 + 0.2 == 0.3`.
# > **PREDICT THE NUMBER OF PASSES.** Ten seems obvious. Read what actually comes out.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# The condition is checked **before** the first pass, not after it. Write `while funds > 10000:` with a counter in the body, and print how many times the body ran. Then print `funds` to confirm nothing was touched.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Not a `while` question, but it belongs next to Q4. Build `jobs = ["a", "b", "c", "d"]` and try to empty it with `for job in jobs: jobs.remove(job)`. Print the list afterwards, then do the same job properly with a `while`.
# > **THIS RAISES NOTHING AND DOES NOT WORK.** Count what is left.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Build `pending = ["x", "y"]` and drain it with `while True:` and `.pop(0)`, with **no** check for emptiness and no `break`. Read the error, then write in a comment which two of this sheet's loops would have prevented it.
# > **THIS CELL IS SUPPOSED TO RAISE.** The two jobs print first.

# %%
############################
## Your Code Here
############################
