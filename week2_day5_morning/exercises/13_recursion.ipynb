# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 13: Recursion   (L06)
#
# A recursive function calls itself until a **base case** stops it. Slides 68–87
# build factorial and Fibonacci that way, and finish by comparing recursion with
# iteration.
#
# This sheet does both, and then asks the two questions the deck raises without
# answering: **what does recursion actually cost**, and **when is it worth it?**
# The honest answers are "much more than you think" and "less often than you
# think" — with one clear exception, in Q9.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 68–87.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 13 — Recursion. Run this once.
nested = [1, [2, 3, [4, 5]], 6, [[7], 8]]
flat_numbers = [4, 8, 15, 16, 23, 42]
long_list = list(range(1, 101))

print("nested:", nested)
print("flat_numbers:", flat_numbers)

# %% [markdown]
# PART A — Factorial, the deck's example

# %% [markdown]
# ### Question 1
#
# Slide 79. Write `factorial(n)`: return `1` when `n == 1`, otherwise return `n * factorial(n - 1)`. Print the factorial of `1`, `4` and `5`.
# > **TWO PARTS, BOTH COMPULSORY:** a base case that returns without calling, and a recursive case that calls itself with a *smaller* argument.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Now trace it. Write `factorial_traced(n)` that prints `called with n = <n>` on the way **in** and `intermediate result for <n> * factorial(<n-1>): <res>` on the way **out**. Call it on `5` and compare your output line by line with slide 79's.
# > **COUNT THE `called with` LINES AND COMPARE THE FIRST ONE WITH THE SLIDE'S.**

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Ask what `factorial` does with `0`, without letting it run away. Write `depth_reached(n, depth=0)` that follows the deck's `n == 1` base case but returns the depth instead of a product, and gives up at `20`. Print the depth for `5` and for `0`. Then write `factorial_fixed(n)` with `n <= 1` as the base case and call it on `0`, `1` and `5`.
# > **`0!` IS 1.** Work out what the deck's `n == 1` base case does when you hand it a zero, before you run this.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# See the stack unwind. Write `countdown(n)` that prints `going down: n`, calls itself with `n - 1` until `n == 0`, and then prints `coming back up: n` **after** the recursive call. Call it on `3` and read the order of the six lines.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Fibonacci, and what it costs

# %% [markdown]
# ### Question 5
#
# Slide 86. Write `fib(n)` returning `n` when `n <= 1` and `fib(n-1) + fib(n-2)` otherwise. Print `fib` of `0` through `10` on one line as a list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Now count the work. Write `fib_counted(n)` returning a **tuple** of the answer and the number of calls it took. Print the value and call count for `n` of `5`, `10`, `20` and `25`.
# > **LOOK AT HOW THE CALL COUNT GROWS** as `n` goes up in steps of 5. The deck says recursion is "inefficient and slower" and leaves it there.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Write `fib_iterative(n)` with a loop and two variables, and print `n`, the recursive answer, the iterative answer, and the number of loop passes for the same four values of `n`. Confirm the answers agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Slide 87, checked

# %% [markdown]
# ### Question 8
#
# Slide 87 presents a recursive and an iterative factorial side by side as two ways to do the same thing. Type both exactly as printed — note the recursive base case is `if n < 0 or n == 1` — and print both answers for `n` of `3`, `1` and **`0`**.
# > **THE DECK OFFERS THESE AS EQUIVALENT.** Run all six and compare them in pairs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Where recursion actually wins

# %% [markdown]
# ### Question 9
#
# Write `flatten(items)` that returns every value in a nested list as one flat list, calling itself whenever it meets a list. Use `isinstance(item, list)`. Print `flatten(nested)`, and print `nested` afterwards to confirm it is unchanged.
# > **TRY TO WRITE THIS WITH A `for` LOOP AND NO RECURSION.** You cannot, unless you keep your own stack — the nesting has no fixed depth.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Write `total(values)` that sums a list recursively — empty list returns `0`, otherwise the first item plus `total` of the rest. Call it on `flat_numbers` and on `long_list`, and compare both with `sum()`. Then say in a comment what would happen on a list of 10,000.
# > **THE SECOND CALL IS 100 DEEP.** Python's default limit is about 1,000 frames.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Write `no_base(n)` that returns `n * no_base(n - 1)` with **no** base case at all, and call it on `5`. Read the error, then write in a comment what the deck says about this on slide 69.
# > **THIS CELL IS SUPPOSED TO RAISE.** It may take a moment and the traceback will be very long — that is the point.

# %%
############################
## Your Code Here
############################
