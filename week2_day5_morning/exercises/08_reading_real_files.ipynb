# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 08: Reading real files   (L05)
#
# Every loop so far has run over a list somebody typed into a cell. This one runs
# over four files on disk — the **same superstore data** you queried with SQL on
# week 2, day 2, this time read a line at a time with nothing but `open()`, `split()` and
# the control flow from worksheets 01 to 07.
#
# This is the sheet that matches the course's own `Python Exercises 2`. That
# notebook expects a `data/` folder the course zip does not ship, so it cannot be
# run; this one asks the same kinds of question against data that is actually
# here.
#
# `data/` holds four **tab-separated** files, each with a header row:
#
# | File | Rows | Columns |
# |---|---|---|
# | `orders.csv` | 1,093 | `OrderID`, `ProductID`, `CustomerID`, `OrderDate`, `OrderPriority`, `OrderQuantity`, `Sales`, `Discount`, `ShipMode`, `Profit`, `UnitPrice`, `ShippingCost` |
# | `customers.csv` | 1,832 | `CustomerID`, `CustomerName`, `Province`, `Region`, `CustomerSegment` |
# | `products.csv` | 1,237 | `ProductID`, `ProductName`, `ProductCategory`, `ProductSubCategory`, `ProductContainer`, `ProductBaseMargin` |
# | `returns.csv` | 572 | `OrderID`, `Status` |
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# No imports — not `csv`, not `pandas`. `open()` is built in.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 08 — Reading real files. Run this once.
#
# `data/` sits next to this notebook, so these relative paths work whether you
# opened it in the shared console or in a git clone.

with open("data/orders.csv", encoding="utf-8") as fh:
    order_lines = fh.readlines()

with open("data/customers.csv", encoding="utf-8") as fh:
    customer_lines = fh.readlines()

with open("data/products.csv", encoding="utf-8") as fh:
    product_lines = fh.readlines()

with open("data/returns.csv", encoding="utf-8") as fh:
    return_lines = fh.readlines()

print("orders.csv   ", len(order_lines), "lines")
print("customers.csv", len(customer_lines), "lines")
print("products.csv ", len(product_lines), "lines")
print("returns.csv  ", len(return_lines), "lines")

# %% [markdown]
# PART A — What you actually got back

# %% [markdown]
# ### Question 1
#
# Before counting anything, look at what `readlines()` handed you. Print the `repr()` of `order_lines[0]` and of `order_lines[1]`, print the number of lines, and print the number of **data rows** — which is not the same number.
# > **USE `repr()`, NOT `print()`.** It shows you the characters that are there but invisible, and one of them is about to matter.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Split the header on tabs and print each column name with its index, using `enumerate`. Then split `order_lines[1]` the same way and print the `repr()` of its **last** field. Finally do it again with `.strip()` applied first.
# > **THE LAST FIELD OF EVERY ROW CARRIES THE LINE BREAK.** Every row, every file, always.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — One pass, one answer

# %% [markdown]
# ### Question 3
#
# How many distinct customers placed an order? Build a set of the `CustomerID` column from the data rows and print its size. Then print how many customers are on file in `customers.csv`, and how many of them **never ordered**.
# > **HINT:** slice `[1:]` to skip the header. It is the single most common mistake in this whole sheet.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Count the orders. Build a dictionary of `OrderID` to the number of lines it has, then print: the number of data rows, the number of distinct orders, how many orders have more than one line, and the largest number of lines on a single order.
# > **IF YOU DID WEEK 2, DAY 2, YOU HAVE MET THIS BEFORE.** `orders.csv` is one row per order **line**, not per order — `COUNT(*)` and `COUNT(DISTINCT OrderID)` in Python form.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Find the highest `UnitPrice` **without using `max()`**. Walk the rows keeping the best seen so far, then walk them a second time collecting every row that matches it. Print the price and how many order lines are at it.
# > **TWO PASSES, NOT ONE.** You cannot collect the winners until you know what winning is — and there may be more than one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Joining two files

# %% [markdown]
# ### Question 6
#
# Build `product_name`, a dictionary from `ProductID` to `ProductName`, and use it to name the product from Q5. Then print how many **data rows** `products.csv` has, how many **keys** the dictionary ended up with, how many distinct products were ordered, and how many were never ordered.
# > **COMPARE THE ROW COUNT WITH THE KEY COUNT.** They ought to be the same number.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Build `customer_region` from `customers.csv`, then report by region **two ways**: the number of order **lines**, and the number of distinct **orders**. Print both tables sorted by region name, and print the totals underneath.
# > **HINT:** a dictionary whose values are sets is how you count distinct things per group. Two things to look at in the output: one region name is not spelled the way you expect, and the `TOTAL` row disagrees with Q4.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Dates, without importing anything

# %% [markdown]
# ### Question 8
#
# `OrderDate` is text in `YYYY-MM-DD` form. Count the order lines per **year** by splitting the date on `"-"`, and print them in order. Then count the lines per month for `2012` only, printing the months in order.
# > **NO `datetime` HERE.** For "which year is this in", string slicing is the whole job — and it cannot throw a timezone at you.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART E — The numbers, and their denominators

# %% [markdown]
# ### Question 9
#
# Build the set of returned `OrderID`s from `returns.csv`. Then print: how many returned orders are in that file at all, how many of them appear in `orders.csv`, how many order **lines** belong to a returned order, and the return rate **three ways** — per line, per order, and against the whole returns file.
# > **THREE PERCENTAGES, ALL ARITHMETICALLY CORRECT.** Only one of them is the return rate.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Total the `Sales` column, and total it per region using `customer_region`. Print the grand total, each region's share sorted by name, and then print the sum of the per-region totals next to the grand total.
# > **THE LAST LINE IS THE RECONCILIATION.** If the parts do not add up to the whole, rows are going somewhere you have not looked.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Total the `Sales` column again, but loop `order_lines` instead of `order_lines[1:]`. Read the error, then write in a comment what would have happened if the header had said `0` instead of `Sales`.
# > **THIS CELL IS SUPPOSED TO RAISE**, and it is the friendliest thing in this worksheet.

# %%
############################
## Your Code Here
############################
