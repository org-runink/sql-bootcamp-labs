# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 10: Function arguments   (L06)
#
# Slides 21–41 are the longest stretch of the deck, and they are all about one
# question: **which value ends up in which parameter?**
#
# Positional arguments, keyword arguments, defaults, `*args`, `**kwargs`, and the
# order they have to be written in. Two of these questions come from places where
# the deck's printed output does not match its own code.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 21–41.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 10 — Function arguments. Run this once.
spring_cohort = [65, 87, 83, 53, 72, 78, 72, 78, 82, 73, 76, 74, 81]

student = {"name": "Jeff", "program": "DS", "gpa": 4.8}
grades = {"sql": 4.2, "ml": 5.5}

print(len(spring_cohort), "grades in spring_cohort")

# %% [markdown]
# PART A — Defaults

# %% [markdown]
# ### Question 1
#
# Slides 21–24. Write `welcome(service, greeting)` printing `Welcome to EC2!` from an f-string, and call it with both arguments. Then write `welcome_d(service="AWS", greeting="Welcome to")` with defaults for both, and call it three times: with nothing, with `"EC2"`, and with both.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Slide 25 calls `welcome('Hi, welcome to')` on the version with defaults and prints `welcome to Hi!` underneath. Run exactly that call. Then write in a comment which parameter the argument actually landed in.
# > **COMPARE YOUR OUTPUT WITH THE SLIDE'S, WORD FOR WORD.** They are not the same sentence.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Call `welcome_d` four ways and print the result of each: both arguments positionally; both by keyword in the **written** order; both by keyword in the **reverse** order; and one positional followed by one keyword. Then say in a comment which of the four are the same call.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — The default that is not what you think

# %% [markdown]
# ### Question 4
#
# Write `add_item(item, basket=[])` that appends `item` to `basket` and returns it. Call it three times in a row with `"apple"`, `"pear"` and `"fig"` — each time with **no** second argument — printing the result each time.
# > **PREDICT ALL THREE LINES BEFORE YOU RUN IT.** Almost nobody gets this right the first time, and it is not in the deck.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Arbitrary arguments

# %% [markdown]
# ### Question 5
#
# Slide 33. Write `calc_standard_deviation(*args)` — count them, take the mean, build the squared distances with a comprehension, and return the sample standard deviation. Call it with `65, 87, 83`, then with six numbers, then with the whole `spring_cohort` list unpacked using `*`. Print `type(args)` from inside as well.
# > **`*args` COLLECTS.** `*a_list` at the *call* site does the opposite — it spreads. Same star, opposite directions.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Slide 37. Write `print_gpa(**kwargs)` that pulls `name`, `gpa` and `program` out with `.get()` and prints them in one f-string. Call it once with all three and once with only `name` and `gpa`. Print `kwargs` itself as well.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Ordering, and what it silently changes

# %% [markdown]
# ### Question 7
#
# Slide 41, the version that works. Write `print_student_profile(name, *hobbies, location="Toronto", **grades)` printing all four, and call it exactly as the slide does: `'Jeff'`, three hobbies, `location='Brazil'`, `python=4.4`, and `**grades` unpacked.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Now call the same function without naming `location` — `print_student_profile("Jeff", "Brazil", "Soccer", "Poker")`. Print the output and say in a comment where `"Brazil"` ended up and what `location` is.
# > **NOTHING RAISES HERE.** Read all four lines of output.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Unpack at the call site. Using the `student` dictionary from setup, call `print_gpa(**student)`. Then build `all_grades` by merging `grades` with `{"python": 4.4}` and call `print_student_profile("Ada", *["Chess", "Running"], location="Lisbon", **all_grades)`.
# > **`**a_dict` AT A CALL** turns each key into a keyword argument. The keys must be valid parameter names — and strings that are not, like `"order id"`, fail here rather than at the definition.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Readability. Write `export(rows, header=True, overwrite=False, compress=False)` that just prints its four arguments. Call it once with three bare booleans positionally, and once with the same values named. Then say in a comment which call you could review without opening the definition.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Slide 34 renames the parameter to `*nums` but leaves `sum(args)` in the body. Type it exactly as the slide has it and call it with `65, 87, 83`. Read the error, then write in a comment why the slide's own output could not have come from that code.
# > **THIS CELL IS SUPPOSED TO RAISE.** The correct version prints first.

# %%
############################
## Your Code Here
############################
