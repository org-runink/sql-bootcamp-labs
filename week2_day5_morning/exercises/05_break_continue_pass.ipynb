# %% [markdown]
# # Week 2, day 5 (morning) — Worksheet 05: break, continue, pass   (L05)
#
# The learning objectives on slide 2 list `break`, `continue` and `pass`, and then
# the deck spends one word on them. This sheet is the missing part: what each one
# actually does, how they differ, and the `else` clause on a loop — which almost
# no one meets until they read someone else's code.
#
# Three of them, one sentence each, and it is worth getting these exactly right:
# `break` **leaves the loop**, `continue` **skips to the next pass**, and `pass`
# **does nothing at all**.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 2 and 76–77.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 05 — break, continue, pass. Run this once.
names = ["ana", "bo", "cai", "dee"]

rows = [
    {"id": "r1", "amount": 10.0},
    {"id": "r2", "amount": -5.0},     # negative -- skip it
    {"id": "r3", "amount": 0.0},
    {"id": "r4", "amount": 22.5},
    {"id": "r5", "amount": -1.0},     # negative -- skip it
]

# A feed that ends with a sentinel row rather than just running out.
feed = [4.0, 9.5, -2.0, 3.0, "END", 100.0, 200.0]

grid = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

print(len(names), "names,", len(rows), "rows,", len(feed), "feed entries")

# %% [markdown]
# PART A — break: leave the loop now

# %% [markdown]
# ### Question 1
#
# Find the first name in `names` that starts with `"c"`. Count how many names you looked at, `break` as soon as you find it, and print both the name and the count. Then run the same loop again with the `break` removed and print the count from that one too.
# > **HINT:** `name.startswith("c")` — or `name[0] == "c"`, which does the same thing until the name is an empty string.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# A loop can have an `else`. It runs **only if the loop finished without breaking**. Search `names` for one starting with `"z"`, with an `else` on the `for` printing `no match`. Then run the identical loop searching for `"c"` and see which branch you get.
# > **THE INDENTATION IS THE WHOLE THING.** The `else` lines up with `for`, not with `if`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# The same `else` works on `while`. Count `n` down from 3 to 0 with a `while n > 0:` loop and an `else` printing `countdown complete`. Then write it again with a `break` when `n` reaches 1, and see whether the `else` runs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — continue: skip to the next pass

# %% [markdown]
# ### Question 4
#
# Total the `amount` of every row in `rows`, but `continue` past any row with a negative amount. Count how many you skipped and how many you totalled, and print the total plus both counts.
# > **COMPARE THIS WITH WORKSHEET 04 Q5**, which *stopped* at the first bad value instead of skipping it. Same data shape, different policy, very different answer.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# `continue` in a `while` loop is where people get hurt. Write `while i < 5:` that prints `i`, but `continue`s when `i == 2` — with the `i = i + 1` at the **bottom** of the body, and a guard capping the loop at 20 passes. Print how many passes ran and what `i` ended on.
# > **THE GUARD IS WHY THIS IS SAFE TO RUN.** Work out what `continue` skips over before you read the output.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — pass: do nothing, on purpose

# %% [markdown]
# ### Question 6
#
# Loop over `[1, 2, 3, 4]`. When the number is even, run `pass`. Print `saw <n>` after the `if`, unindented back to the loop body. Print how many lines came out.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Now the same loop with `continue` instead of `pass`, and nothing else changed. Print how many lines come out this time, then write in a comment the difference between the two in one sentence.
# > **THEY LOOK INTERCHANGEABLE AND ARE NOT.** People reach for `pass` when they mean `continue` because both read as "skip this one".

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Nested loops: break only gets you out of one

# %% [markdown]
# ### Question 8
#
# Search `grid` for the value `5` with a loop inside a loop, `break`ing when you find it. Count how many times the **outer** loop body ran and how many times the **inner** one did, and print both after the search.
# > **THE COUNTS ARE THE ANSWER.** The value is found on the second row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Fix it so the search really stops. Use a `found` flag: `break` the inner loop as before, then `break` the outer loop too if `found` is true. Print the same two counts and compare them with Q8.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART E — All three at once

# %% [markdown]
# ### Question 10
#
# Process `feed`: skip anything negative with `continue`, stop at the sentinel `"END"` with `break`, and total everything else. Put an `else` on the loop that prints `reached the end of the feed`. Print the total, the number of values used, the number skipped, and how many entries were never reached.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Loop over the **empty** list `[]` with a loop variable called `entry_2`, and print `entry_2` after the loop. Read the error, then write in a comment how this connects to worksheet 04 Q9.
# > **THIS CELL IS SUPPOSED TO RAISE.** The successful loop above it prints first.

# %%
############################
## Your Code Here
############################
