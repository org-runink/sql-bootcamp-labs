# %% [markdown]
# # Week 3, day 2 — Worksheet 08: Binning   (L05)
#
# Binning turns exact numbers into groups. `cut` uses edges you choose; `qcut`
# uses edges the data chooses. The interesting parts are the boundaries and the
# values that fall outside them.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L05]`, slides 26–29.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 08 — Binning. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")

print("Sales range: %.2f to %.2f" % (orders["Sales"].min(), orders["Sales"].max()))
print("Quantity range: %d to %d" % (orders["Quantity"].min(), orders["Quantity"].max()))

# %% [markdown]
# PART A — cut: edges you choose

# %% [markdown]
# ### Question 1
#
# Run the deck's own example: `ages = [5, 17, 22, 35, 45, 67, 90]`, `bins = [0, 12, 19, 35, 60, 100]`, five labels. Print each age next to its label, and count the edges against the labels.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the same `cut` **without** labels, so you can see the intervals. Note which end of each interval is closed, and check where age 35 landed.
# > **NOTE:** 35 is an edge. Which of its two neighbouring bins claimed it?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now bin a value that sits outside the edges: print `pd.cut([0, 5, 120], bins=bins, labels=labels)`. Look at what happened to `0` and to `120`.
# > **NOTE:** the deck says there is always one more edge than label, and stops there. It does not say what happens to values beyond the outermost edges.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Bin the real `Sales` column with business edges `[0, 100, 500, 2000, 10000]` and labels `["small", "medium", "large", "huge"]`. Print `value_counts()` including `NaN`, and check the total against the row count.
# > **NOTE:** the maximum sale is above 10,000. Work out what that means before you run it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Fix it two ways: extend the top edge to `orders["Sales"].max()`, and separately use `float("inf")`. Confirm both bin every row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — qcut: edges the data chooses

# %% [markdown]
# ### Question 6
#
# Split `Sales` into four quartiles with `pd.qcut(orders["Sales"], q=4, labels=["Q1","Q2","Q3","Q4"])`. Print `value_counts()` and the actual boundaries `qcut` picked.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Compare the two approaches on the same column: print the `value_counts()` of the `cut` from Q5 and of the `qcut` from Q6 side by side. Say which one tells you about the business and which about the distribution.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Use the bins for something: group by the `cut` band and print the count, total and mean `Profit` per band. Round the money to 2dp.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Bin `Quantity` into 4 quantiles and print the intervals. Then print `orders["Quantity"].value_counts().head()` and say why the group sizes are not equal.
# > **NOTE:** `qcut` promises roughly equal groups. 'Roughly' is doing work here whenever values repeat.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, `qcut` a column with too few distinct values: build `pd.Series([1, 1, 1, 1, 1, 2, 3, 100])` and call `pd.qcut(s, q=4)`. **This is supposed to fail.** Read the exception — it names the fix.

# %%
############################
## Your Code Here
############################
