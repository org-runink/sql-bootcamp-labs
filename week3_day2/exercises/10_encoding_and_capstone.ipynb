# %% [markdown]
# # Week 3, day 2 — Worksheet 10: Encoding, sampling, and a capstone   (L05)
#
# The last two tools — turning categories into numbers, and taking a reproducible
# sample — and then the whole day put together: load a messy file, clean it,
# transform it, reshape it, and produce a report you could defend.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L05]`, slides 33–35, and the checklist slide.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 10 — Encoding, sampling, capstone. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")
cust = pd.read_csv("data/customers_messy.csv")

print("orders:", orders.shape, "| customers:", cust.shape)
print("categories:", list(orders["Category"].unique()))

# %% [markdown]
# PART A — one-hot encoding

# %% [markdown]
# ### Question 1
#
# One-hot encode `Category`: print `pd.get_dummies(orders[["Category"]], columns=["Category"]).head()` and the resulting column names.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the `dtypes` of that result. The deck's slide shows the cells as `0` and `1`. Check what they actually are, then produce the deck's version with `dtype=int`.
# > **NOTE:** this changed in pandas 2.0 and the slide predates it. The values are equivalent; the dtype is not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Booleans still add up. Print the column sums of the boolean version and of the int version, and confirm they match `orders["Category"].value_counts()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Use `drop_first=True` and print the column names and shape. Say what information is still recoverable and what is not.
# > **NOTE:** with three categories, two columns carry all the information. That is why the option exists.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — sampling

# %% [markdown]
# ### Question 5
#
# Take `orders.sample(n=5, random_state=42)` twice and confirm you get the same rows. Then take it with a different seed and confirm you do not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Shuffle the whole frame with `sample(frac=1, random_state=42)` and print the first three `OrderID`s before and after. Then confirm the shuffled frame still holds every row, by comparing sorted `OrderID` lists.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# A 10% sample is not a small copy of the data. Take `orders.sample(frac=0.1, random_state=42)` and compare its `Region` proportions with the full file's, printing both as percentages.
# > **NOTE:** look at the smallest region in particular.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — capstone: the whole day, in order

# %% [markdown]
# ### Question 8
#
# **Clean.** Load `customers_messy.csv`, replace the `-` and `?` markers with `NaN`, strip whitespace from `CustomerName`, drop exact duplicate rows, and print the row count and missing count at each step.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# **Transform and reshape.** Bin `orders["Sales"]` into the four business bands from worksheet 08, then build a `Region` x `Band` table of total sales with `pivot_table`, and confirm the grand total matches the raw total.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, one-hot encode a column that is not there: `pd.get_dummies(orders, columns=["Segment"])`. **This is supposed to fail.** Read the exception — and note that `Segment` exists in the *customers* file, not this one.

# %%
############################
## Your Code Here
############################
