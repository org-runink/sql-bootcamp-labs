# %% [markdown]
# # Week 3, day 2 — Worksheet 05: pivot and pivot_table   (L04)
#
# `pivot()` rearranges values. `pivot_table()` rearranges *and* aggregates. The
# difference sounds small and decides whether your code runs at all — and, when it
# runs, what the numbers in the cells actually mean.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L04]`, slides 15–20.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 05 — pivot and pivot_table. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")

# One row per region-year: no repeated pairs, so pivot() will work.
unique_pairs = orders.groupby(["Region", "Year"])["Sales"].sum().round(2).reset_index()

print("raw orders:", orders.shape)
print("one row per region-year:", unique_pairs.shape)
print()
print(unique_pairs.head())

# %% [markdown]
# PART A — pivot: rearranging only

# %% [markdown]
# ### Question 1
#
# Pivot the pre-aggregated frame: `unique_pairs.pivot(index="Region", columns="Year", values="Sales")`. Print it and its shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Confirm `pivot()` moved values without changing them: compare the total of the pivoted table with the total of `unique_pairs["Sales"]`, and with `orders["Sales"]`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now try `pivot()` on the *raw* orders, which have many rows per region-year: `orders.pivot(index="Region", columns="Year", values="Sales")`. Catch the exception and print it.
# > **NOTE:** this is the situation the deck describes as 'when pivot() breaks'. Compare the exact message with what the slide prints.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — pivot_table: rearranging and aggregating

# %% [markdown]
# ### Question 4
#
# Run `orders.pivot_table(index="Region", columns="Year", values="Sales")` — with **no** `aggfunc`. Print it, then print the Ontario/2012 cell alongside the *sum* of Ontario 2012 sales from the raw data.
# > **NOTE:** the deck's worked example shows this producing a total. Check what it actually produced.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Ask for the total explicitly: `aggfunc="sum"`. Print the table and confirm the grand total matches `orders["Sales"].sum()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# The same cells, three meanings. Build one table with `aggfunc=["sum", "mean", "count"]`, print its shape and column levels, and print the Ontario row.
# > **NOTE:** multiple aggfuncs add a column level. Useful, and harder to read.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Add row and column totals with `margins=True`. Print the table and check the `All` corner against `orders["Sales"].sum()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Watch what `margins=True` does with a **mean**. Build the same table with `aggfunc="mean", margins=True` and check whether the `All` row equals the mean of the column above it.
# > **NOTE:** the margin is computed from the raw rows, not from the cells it sits under. Those are different numbers.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Handle the missing combinations: pivot the Technology subset with `aggfunc="sum"`, then again with `fill_value=0`. Print both and the count of `NaN`s in each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, pivot on a column that does not exist: `orders.pivot_table(index="Region", columns="Quarter", values="Sales", aggfunc="sum")`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
