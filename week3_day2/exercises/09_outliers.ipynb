# %% [markdown]
# # Week 3, day 2 — Worksheet 09: Outliers   (L05)
#
# Two standard rules for flagging extreme values: the IQR fence and the z-score.
# They disagree, and on skewed data they disagree a lot. Neither of them tells you
# a value is wrong — that is a judgement you have to make afterwards.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L05]`, slides 31–32.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 09 — Outliers. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")
sales = orders["Sales"]

print(sales.describe().round(2).to_string())

# %% [markdown]
# PART A — the IQR fence

# %% [markdown]
# ### Question 1
#
# Compute `Q1`, `Q3` and `IQR` for `Sales`, then the lower and upper fences at 1.5 x IQR. Print all five numbers.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Count how many orders fall outside those fences, below and above separately. Print the counts and the percentage of the file.
# > **NOTE:** the lower fence is negative. Work out whether any sale can be below it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Look at what you flagged before deciding anything. Print the ten largest flagged orders with their `Region` and `Category`.
# > **NOTE:** the deck is explicit that outliers are flags for review, not errors. This is the review.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the z-score

# %% [markdown]
# ### Question 4
#
# Compute `z = (sales - sales.mean()) / sales.std()` and count how many rows have `|z| > 3`. Compare that count with the IQR count from Q2.
# > **NOTE:** both rules are standard, both are defensible, and they will not agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Explain the gap by looking at the distribution. Print the mean, median, standard deviation and skew of `Sales`, and say which method the shape favours.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Show that directly: print the standard deviation of all sales, and of sales with the IQR-flagged rows removed. Then recompute the `|z| > 3` count on the trimmed data.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — what removing them costs

# %% [markdown]
# ### Question 7
#
# Compare the dataset with and without the IQR-flagged rows: print the row count, total `Sales` and mean `Sales` for each, and the percentage of revenue you would be discarding.
# > **NOTE:** these are real orders. Removing them is a decision about the business, not about the data.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Flag rather than delete. Add an `Outlier` column marking the IQR-flagged rows, then print the count and mean `Sales` per `Region` for flagged and unflagged rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Check whether the outliers are spread evenly. Print, per `Category`, the number of flagged orders and what percentage of that category's orders they represent.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, compute a z-score on a text column: `(orders["Region"] - orders["Region"].mean()) / orders["Region"].std()`. **This is supposed to fail.** Read the exception.
# > **NOTE:** both outlier rules assume a numeric column. Neither checks for you.

# %%
############################
## Your Code Here
############################
