# %% [markdown]
# # Week 3, day 2 — Worksheet 07: Transforming values   (L05)
#
# Four tools that all change values, and are not interchangeable: `map` for a
# lookup, `apply` for custom logic, `replace` for exact swaps, and `.loc[mask]`
# for conditions. Picking the wrong one usually still runs.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L05]`, slides 12–21.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 07 — Transforming values. Run this once.
import numpy as np
import pandas as pd

cust = pd.read_csv("data/customers_messy.csv")
orders = pd.read_csv("data/orders_long.csv")

print("customers:", cust.shape)
print("distinct Province values:", cust["Province"].nunique(dropna=False))
print("Province NaN rows:", int(cust["Province"].isna().sum()))

# %% [markdown]
# PART A — replace: exact values you already know

# %% [markdown]
# ### Question 1
#
# Print every distinct `Province` value with `repr()`. Sorting will fail — work out why before you work around it. Then pick out the values that are not provinces.
# > **NOTE:** the file was written with three different missing-markers in this column: `N/A`, `-` and `?`. Check how many of them you can actually see.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# The file was written with three markers. Count how many rows carry each one, and count the `NaN`s. Account for the marker you cannot find.
# > **NOTE:** `read_csv` has a built-in list of strings it treats as missing. One of these three is on it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Replace all three with `np.nan` in one call: `cust["Province"].replace(["N/A", "-", "?"], np.nan)`. Print the `isna()` count before and after.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Now do it wrong on purpose: replace only `["N/A", "?"]`, missing the `-`. Print the resulting `isna()` count and the remaining distinct values, then say what a downstream `dropna()` would do.
# > **NOTE:** a partial clean-up is more dangerous than none, because the column now *looks* clean.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Use a dictionary to make several different replacements at once: map `Segment` values so `"Small Business"` becomes `"SMB"` and `"Home Office"` becomes `"HO"`, leaving the rest alone. Print `value_counts()` before and after.
# > **NOTE:** `replace` leaves unlisted values untouched. Compare that with `map`, which does not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Do the same thing with `map` and the same dictionary. Print `value_counts(dropna=False)` and compare with Q5.
# > **NOTE:** same dictionary, same column, very different result.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — .loc for conditions, not values

# %% [markdown]
# ### Question 7
#
# On `orders`, cap any `Discount` above `0.10` at `0.10` using `.loc[mask, col] = value`. Print how many rows were affected and the max before and after.
# > **NOTE:** `replace` cannot express 'anything above 0.10' — it swaps values you can name. This is the other tool.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Use `.loc` to mark rather than overwrite: add a `Flag` column that is `"capped"` where `Discount > 0.10` and `"normal"` elsewhere, then print `value_counts()`. Say why marking is usually better than overwriting.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Combine the tools on `Profit`: build a `Result` column that is `"loss"` below zero, `"break-even"` at exactly zero, and `"profit"` above. Print `value_counts()` and confirm the three counts add to the row count.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, use `map` with a function that cannot handle every value: `cust["Province"].map(lambda p: p.split()[1])` — some provinces are one word. **This is supposed to fail.** Read the exception.
# > **NOTE:** `map` returned `NaN` for unmapped *dictionary* keys in Q6 without complaint. Give it a *function* that raises, and it stops.

# %%
############################
## Your Code Here
############################
