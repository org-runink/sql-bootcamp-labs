# %% [markdown]
# # Week 3, day 2 — Graded 03: Diagnosis   (tier 3 of 4)
#
# **Tier 3.** Every question below hands you code that **runs without error and
# gives the wrong answer.** Your job is to find out why, and produce the right
# number.
#
# That is the whole skill. Tiers 1 and 2 were about making Pandas do what you
# meant; this one is about noticing when it did something else.
#
# Work in this order for each question: *reproduce the wrong number → find what
# it is actually measuring → produce the right one → say how you would have
# caught it.*
#
# **Question 10 is supposed to raise an error** — and it is the only one here
# that does.
#
# Covers `[Python_Pandas_L04]` and `[Python_Pandas_L05]`.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Graded 03 — Diagnosis. Run this once.
import numpy as np
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")
cust = pd.read_csv("../data/customers_messy.csv")

TRUE_TOTAL = round(orders["Sales"].sum(), 2)
print("orders:", orders.shape)
print("the true total Sales, for checking against:", TRUE_TOTAL)

# %% [markdown]
# TIER 3 — it ran, and it is wrong

# %% [markdown]
# ### Question 1
#
# **[medium]** A colleague reports regional sales for 2012 with `orders.pivot_table(index="Region", columns="Year", values="Sales")` and quotes the Ontario cell as Ontario's 2012 revenue. Reproduce it, show what the cell really is, and produce the revenue figure they meant.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# **[medium]** A banding report uses `pd.cut(orders["Sales"], bins=[0, 100, 1000, 10000], labels=["S","M","L"])` and its three bands sum to less than the real total. Find how much is missing and where it went.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# **[medium]** Someone maps `Category` to a margin target with `{"Technology": 0.25, "Furniture": 0.15}` and reports the mean target as the company-wide figure. Show what fraction of rows that mean is actually computed over.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# **[medium]** A cleaning step runs `cust.drop_duplicates()` and reports the row count as the number of distinct customers. Show that it is not, and produce the real figure.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# **[harder]** A dashboard shows 'average order value by region' and then quotes a single company-wide average by taking the mean of those eight regional averages. Compute both that figure and the true average order value, and explain the gap.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# **[harder]** A pipeline builds a Technology `Region` x `Year` table, stacks it back to long, and reports the row count as 'region-years with Technology sales'. Show that the number is too high and by how much.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# **[harder]** A report rounds regional totals to 2dp for display, then sums those rounded figures for the company total, and it does not match. Reproduce the mismatch and show which regions are responsible.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# **[harder]** A summary groups `cust` by `Province` after the `-` and `?` markers have been turned into `NaN`, and the group sizes do not add up to the row count. Show how many rows vanished and how to keep them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# **[hardest]** An analyst removes outliers with the 1.5 x IQR fence on `Sales` and reports the remaining mean as 'the typical order, with anomalies excluded'. Quantify what was excluded, and give one number that makes the claim indefensible.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# **[error]** Finally, one that does stop you. A colleague tries to widen the customer table with `cust.pivot(index="CustomerID", columns="Region", values="Province")`. **This is supposed to fail.** Read the exception, then say which of the nine questions above it most resembles — and why that one raised while the others did not.

# %%
############################
## Your Code Here
############################
