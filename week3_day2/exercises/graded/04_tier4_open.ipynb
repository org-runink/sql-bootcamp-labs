# %% [markdown]
# # Week 3, day 2 — Graded 04: Open problems   (tier 4 of 4)
#
# **Tier 4.** Business questions, no method prescribed. Each one has several
# defensible answers and at least one plausible wrong one, and the marking
# criterion is not the number — it is whether you stated what you counted.
#
# For each question, produce: **the figure, the denominator it is computed over,
# and one sentence on what would change it.** A number without those three is not
# an answer.
#
# The solutions show *an* approach, not *the* approach. If yours differs and you
# can defend the difference, yours is fine.
#
# **Question 8 is supposed to raise an error.**
#
# Covers `[Python_Pandas_L04]` and `[Python_Pandas_L05]`.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Graded 04 — Open problems. Run this once.
import numpy as np
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")
cust = pd.read_csv("../data/customers_messy.csv")

print("orders:", orders.shape, "| customers:", cust.shape)
print("years:", sorted(orders["Year"].unique()))

# %% [markdown]
# TIER 4 — state the figure, the denominator, and what would move it

# %% [markdown]
# ### Question 1
#
# **Which region is growing?** Produce a defensible answer, and say explicitly what you compared.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# **What is a typical order?** Give a number a stakeholder could use, and justify the statistic you chose.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# **Which category should we stop discounting?** Use `Discount` and `Profit`, and show your reasoning.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# **How complete is the customer file?** Produce a single completeness figure and say what you counted as complete.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# **Is the business seasonal?** Answer with a number, and be explicit about what you are comparing across.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# **Where is the revenue concentrated?** Quantify it, choosing your own unit of concentration.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# **Build the one table you would put in front of a manager.** One `pivot_table`, with counts included, and say in a comment why you chose that shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# **[error]** Finally: try to answer 'what is the average `Region`?' with `orders["Region"].mean()`. **This is supposed to fail.** Read the exception, then say — in one sentence — why this question is different in kind from the seven above.

# %%
############################
## Your Code Here
############################
