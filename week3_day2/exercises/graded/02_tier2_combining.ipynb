# %% [markdown]
# # Week 3, day 2 — Graded 02: Combining   (tier 2 of 4)
#
# **Tier 2.** Every question needs two or three operations chained together, and
# the order you do them in matters in at least three of them.
#
# Nothing here is a new technique — it is all tier 1 material, composed. If you
# are stuck, the usual reason is that you are trying to do it in one step.
#
# **Question 10 is supposed to raise an error.**
#
# Covers `[Python_Pandas_L04]` and `[Python_Pandas_L05]`.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Graded 02 — Combining. Run this once.
import numpy as np
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")
cust = pd.read_csv("../data/customers_messy.csv")
wide = pd.read_csv("../data/technology_wide.csv")

print("orders:", orders.shape, "| customers:", cust.shape, "| wide:", wide.shape)

# %% [markdown]
# TIER 2 — two or three steps

# %% [markdown]
# ### Question 1
#
# **[easy]** For 2012 orders only, print total `Sales` per `Category`, largest first.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# **[medium]** Clean `cust` two ways and compare: (a) `drop_duplicates()` then strip whitespace from `CustomerName`; (b) strip first, then `drop_duplicates()`. Print the row count each way.
# > **NOTE:** same two operations, and one order leaves rows behind.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# **[medium]** Band `Sales` into `small`/`medium`/`large` with edges `[0, 500, 5000, inf]`, then build a `Region` x band table of **total** sales. Print it and check the grand total.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# **[medium]** Take the wide Technology file, turn it into long format, and print total sales per year from the result. Remember `Region` has to become the index first.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# **[medium]** Build a `Region` x `Year` table of total sales, then add a column holding each region's four-year total, and sort by it descending. Print the top four rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# **[harder]** Compute margin per `Region` as total `Profit` divided by total `Sales`, as a percentage to 1dp, sorted worst to best. Do it from two pivots rather than a per-row column.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# **[harder]** Flag orders outside the 1.5 x IQR fence on `Sales`, then print — per `Category` — how many were flagged and what share of that category's revenue they carry.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# **[harder]** Two ways to get average `Sales` per `Region` for 2012: (a) filter to 2012, then `groupby("Region").mean()`; (b) build a `Region` x `Year` `pivot_table` with `aggfunc="mean"` and read the 2012 column. Print both and confirm they agree — then do it a third way, averaging the per-region 2012 *totals*, and say why that one differs.
# > **NOTE:** two of these three are the same number. The third is a mean of a different thing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# **[harder]** Reshape and back: build a `Region` x `Year` table from the Technology subset, then stack it back to long. Print the row count at each stage and say where the extra rows came from.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# **[error]** Bin `Sales` with edges `[0, 500, 5000]` — deliberately too low at the top — then `groupby` the band and sum. Print the total and compare with the real one. Then try `pd.qcut(orders["Year"], q=10)`. **The second one is supposed to fail.**
# > **NOTE:** the first half runs and is wrong; the second half stops you. That contrast is the point of tier 3.

# %%
############################
## Your Code Here
############################
