# %% [markdown]
# # Week 3, day 2 — Graded 01: Foundations   (tier 1 of 4)
#
# A ladder, not a topic sheet. These four notebooks get harder as you go, mixing
# both lectures throughout — start here and stop when it hurts.
#
# **Tier 1** is recall: every question is a single operation and should take one
# or two lines. If any of these is slow, go back to the numbered worksheet for
# that topic before continuing.
#
# Difficulty within the sheet also rises — Q1 should be instant, Q9 should make
# you think for a moment.
#
# **Question 10 is supposed to raise an error.**
#
# Covers `[Python_Pandas_L04]` and `[Python_Pandas_L05]`.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Graded 01 — Foundations. Run this once.
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")
cust = pd.read_csv("../data/customers_messy.csv")

print("orders:", orders.shape, "| customers:", cust.shape)

# %% [markdown]
# TIER 1 — one operation per question

# %% [markdown]
# ### Question 1
#
# **[easy]** Print the number of rows in `orders` and the list of its column names.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# **[easy]** Print how many orders there are in each `Category`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# **[easy]** Print how many rows of `cust` are exact duplicates of an earlier row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# **[easy]** Print total `Sales` per `Region`, sorted from largest to smallest, rounded to 2dp.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# **[medium]** Group `Sales` by `Region` **and** `Year`. Print the number of rows in the result and the names of its index levels.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# **[medium]** Take that grouped result and turn `Year` into columns. Print the shape of what comes back.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# **[medium]** Put every order into one of three `Sales` bands using edges `[0, 500, 5000, inf]` and labels `["small", "medium", "large"]`. Print how many landed in each, and confirm none were left out.
# > **NOTE:** use `float("inf")` for the top edge, and check the total.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# **[medium]** In `cust`, the `Province` column uses `-` and `?` as missing markers. Replace both with `NaN` and print the missing count before and after.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# **[harder]** Build a `Region` x `Category` table of **total** `Sales` with `pivot_table`. Print it, and confirm the grand total matches `orders["Sales"].sum()`.
# > **NOTE:** the default `aggfunc` is not `sum`. Say what you mean.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# **[error]** Now try the same reshape with `pivot()` instead of `pivot_table()`: `orders.pivot(index="Region", columns="Category", values="Sales")`. **This is supposed to fail.** Read the exception and say what `pivot_table` was doing that `pivot` will not.

# %%
############################
## Your Code Here
############################
