# %% [markdown]
# # Week 3, day 2 — Worksheet 01: Long and wide   (L04)
#
# The same numbers can be laid out two ways, and which one you want depends
# entirely on what you are about to do next. Long is for collecting and filtering.
# Wide is for comparing side by side.
#
# Everything on this sheet uses `data/orders_long.csv` — 1,093 real orders.
#
# **Question 10 is supposed to raise an error** — that is the answer, not a
# mistake.
#
# Lecture reference: `[Python_Pandas_L04]_reshaping_and_pivoting_data_with_Pandas.pdf`,
# slides 4–5.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 01 — Long and wide. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")

print("shape:", orders.shape)
print("columns:", list(orders.columns))
print()
print(orders[["OrderID", "Year", "Region", "Category", "Sales"]].head())

# %% [markdown]
# PART A — reading the shape you have

# %% [markdown]
# ### Question 1
#
# Print `orders.shape`, and then `orders["Region"].nunique()` and `orders["Year"].nunique()`. Work out how many region-year cells a wide table would have, and compare that with the number of rows you have now.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# This is long format: one observation per row. Print the first eight rows of just `Year`, `Region` and `Sales`, and confirm that the same region appears on many rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Long format is good for filtering and grouping. Print total `Sales` per `Region` with `groupby`, sorted descending, and the number of orders behind each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the wide shape

# %% [markdown]
# ### Question 4
#
# Now read the wide version: `pd.read_csv("data/technology_wide.csv")`. It holds **Technology orders only**. Print it, its shape and its columns, and note what the column names actually are.
# > **NOTE:** look at the column names carefully. Three of them are not variables.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# The year columns are values pretending to be variables. Print `wide.dtypes`, then answer 'what were total Technology sales in 2010?' from the wide frame and from `orders`, and confirm they agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Count the empty cells in the wide frame with `wide.isna().sum()`, and find which region-year combination is blank. Then check how many rows the long table has for that same combination.
# > **NOTE:** a blank cell in a wide table and a missing row in a long table look nothing alike, and they mean the same thing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Count how many region-year combinations actually occur in the long data, and compare with the total number of cells in the wide table from Q1.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — which shape for which job

# %% [markdown]
# ### Question 8
#
# Do a job that suits long format: total `Sales` per `Category` per `Year`, as a long result. Print the first eight rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Now do a job that suits wide format: compare 2009 and 2012 Technology sales per region side by side, computing the change and the percentage. Build it from the wide file, and look at what happens to the region with the blank cells.
# > **NOTE:** this comparison is awkward in long format — you would have to join the table to itself. That is the whole argument for the wide shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, ask the wide frame for a year it does not have: print `wide["2013"]`. **This is supposed to fail.** Read the exception, then print the columns to see why.
# > **NOTE:** in long format the same question — orders in 2013 — returns an empty frame and no error. Two shapes, two failure modes.

# %%
############################
## Your Code Here
############################
