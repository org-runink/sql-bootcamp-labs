# %% [markdown]
# # Week 3, day 2 — Worksheet 04: stack   (L04)
#
# `stack()` is the mirror of `unstack()`: it folds columns down into the row
# index. Its main job in real work is rescuing spreadsheet exports whose column
# names are actually values.
#
# It is also the function whose behaviour changed most in pandas 3, so anything
# you read online about it is worth checking against what your Pandas does.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L04]`, slides 11–13 and 23.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 04 — stack. Run this once.
import pandas as pd

# The spreadsheet-style export: Technology sales, regions down, YEARS across.
wide = pd.read_csv("data/technology_wide.csv")

orders = pd.read_csv("data/orders_long.csv")

print(wide.to_string(index=False))
print()
print("columns:", list(wide.columns))

# %% [markdown]
# PART A — rescuing a wide export

# %% [markdown]
# ### Question 1
#
# `stack()` works on the columns, so `Region` has to become the index first. Print `wide.set_index("Region")` and then `.stack()`. Print the result's type, length and index names.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# The new inner level has no name. Give it one with `rename_axis`, then `reset_index` to get a proper long frame with three columns. Print the first six rows and the shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now `Year` is data. Prove it by grouping: print total Technology sales per year from the stacked frame, and compare with the same figure computed from `orders`.
# > **NOTE:** you could not have written this `groupby` against the wide frame. That is the point of stacking.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Count the rows the stacked frame has and compare with the number of cells in the wide frame (excluding the `Region` column). Account for the difference.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the round trip

# %% [markdown]
# ### Question 5
#
# Take a complete grid — `orders.groupby(["Region", "Year"])["Sales"].sum().unstack()` — then `.stack()` it back. Compare with the original `groupby` result using `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Now do the same round trip on the Technology data, which has gaps. Print the lengths before and after and whether they are equal.
# > **NOTE:** older tutorials will tell you `stack()` drops missing values by default. Check whether that is true here before you believe it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Print the rows of that stacked result that are `NaN`, so you can see which combinations they are.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Drop them yourself with `.dropna()` and confirm you get back exactly the original `groupby` result.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — stacking a two-level column index

# %% [markdown]
# ### Question 9
#
# Build a frame with two column levels — `orders.groupby(["Region", "Year", "Category"])["Sales"].sum().unstack(["Year", "Category"])` — then stack one level back with `.stack("Category")`. Print the shapes at each step.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, try the old way of controlling missing values: `wide.set_index("Region").stack(dropna=False)`. **This is supposed to fail.** Read the exception carefully — it tells you the implementation changed.
# > **NOTE:** this argument worked for years and appears in most tutorials. Q6 showed why it is no longer needed.

# %%
############################
## Your Code Here
############################
