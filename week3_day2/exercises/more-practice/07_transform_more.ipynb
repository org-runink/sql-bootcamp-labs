# %% [markdown]
# # Week 3, day 2 — Extra practice 07: Transforming values   (L05)
#
# A second pass at worksheet 07, on both files — including the columns whose
# values need standardising before anything downstream can join on them.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 07 — Transforming values. Run this once.
import numpy as np
import pandas as pd

cust = pd.read_csv("../data/customers_messy.csv")
orders = pd.read_csv("../data/orders_long.csv")

print("customers:", cust.shape, "| orders:", orders.shape)
print("regions in customers:", sorted(cust["Region"].unique()))

# %% [markdown]
# ### Question 1
#
# The region column carries a misspelling. Print `value_counts()` for `Region` in both files and confirm the same wrong spelling appears in each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Fix it with `replace` in both frames, then confirm no row anywhere still says the wrong spelling.
# > **NOTE:** correcting it in one file and not the other is worse than leaving it — a join would then match nothing for that region.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Show what a half-fix costs. Correct `Region` in `cust` only, then count how many distinct regions the two frames now share, using set intersection.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Standardise the `Segment` column to lower case with no spaces, using `.str` methods rather than a lookup. Print the distinct values before and after.
# > **NOTE:** `.str` methods are vectorised — no `map`, no `apply`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Use `.loc` to floor negative `Profit` at zero in a copy of `orders`, then compare the total profit before and after and say what you have just asserted.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Build a `Tier` column on `orders`: `"key"` where `Sales > 5000`, `"watch"` where `Profit < 0`, `"standard"` otherwise — applying `watch` first and then `key`. Print `value_counts()`, check it totals the row count, and count how many orders satisfy **both** conditions.
# > **NOTE:** these two conditions are not mutually exclusive. A big order can also lose money.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Order matters. Rewrite Q6 with the two `.loc` lines swapped and compare the counts. Explain which rows moved.
# > **NOTE:** the conditions overlap. An order can be both over 5000 and loss-making.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, call a `.str` method on a numeric column: `orders["Sales"].str.upper()`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
