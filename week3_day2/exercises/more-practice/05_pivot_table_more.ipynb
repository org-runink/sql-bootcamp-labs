# %% [markdown]
# # Week 3, day 2 — Extra practice 05: pivot_table   (L04)
#
# A second pass at worksheet 05, mostly about `aggfunc` — the argument that
# decides what the numbers in your table mean.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 05 — pivot_table. Run this once.
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")

print("rows:", len(orders))
print("categories:", list(orders["Category"].unique()))
print("ship modes:", list(orders["ShipMode"].unique()))

# %% [markdown]
# ### Question 1
#
# Build a `Category` x `ShipMode` table of total `Sales` with `aggfunc="sum"`. Print it and confirm the grand total matches the raw total.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Build the same table four ways — `sum`, `mean`, `count`, `max` — and print the `Technology` / `Regular Air` cell from each. Say what question each number answers.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Aggregate two different columns at once: pass `values=["Sales", "Profit"]` with `aggfunc="sum"`. Print the shape, the column levels, and the `Furniture` row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Use a different aggregate per column: `aggfunc={"Sales": "sum", "Profit": "mean"}`. Print the table rounded to 2dp.
# > **NOTE:** this is usually what you want for a report — totals for money in, averages for margin.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Add `margins=True` to a **count** table. Check whether the `All` row equals the sum of the column above it, and explain why this case behaves differently from worksheet 05 Q8.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Compute a derived metric from a pivot: build sum-of-Profit and sum-of-Sales tables and divide them to get a margin percentage per cell. Print it rounded to 1dp.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Show why that is not the same as averaging a per-row margin. Add a `RowMargin` column to `orders` and pivot its **mean**, then print both tables' `Furniture` rows side by side.
# > **NOTE:** ratio-of-sums and mean-of-ratios are different numbers. One of them is the margin; the other is the average of a set of percentages.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, pass an aggregate that does not exist: `aggfunc="total"`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
