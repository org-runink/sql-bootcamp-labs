# %% [markdown]
# # Week 3, day 2 — Extra practice 03: unstack   (L04)
#
# A second pass at worksheet 03, on different slices of the same real orders.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 03 — unstack. Run this once.
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")

by_cat_mode = orders.groupby(["Category", "ShipMode"])["Sales"].sum().round(2)
print(by_cat_mode.to_string())

# %% [markdown]
# ### Question 1
#
# Unstack `by_cat_mode` and print the result with its shape. Check whether every category-shipmode combination exists.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Unstack the other level instead and print it. Say which of the two layouts you would put in a report and why.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Build a grouping that *does* have gaps: `orders.groupby(["Region", "ShipMode"])["Sales"].count()`, unstack it, and count the `NaN`s. Print which region-shipmode pairs are missing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# That was a **count**, so it started as `int64`. Print the dtype before and after unstacking, and explain the change.
# > **NOTE:** worksheet 03 Q5 could not show this, because its column was already float.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Compare the totals: sum the unstacked count table with and without `fill_value=0`, and compare both with `len(orders)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Unstack a mean instead of a sum: `orders.groupby(["Region", "Category"])["Profit"].mean().unstack()`. Print it rounded to 2dp, then list the negative cells. Count them two ways — with and without `.dropna()` after the `.stack()` — and say which count is right.
# > **NOTE:** `m[m < 0]` blanks the cells that fail the test rather than removing them. Then `stack()` keeps `NaN` rows — worksheet 04 Q6.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Show that `fill_value=0` would be wrong here. Take the count table's missing pairs from Q3 and say what a `0` in a **mean profit** table would assert.
# > **NOTE:** the same argument, opposite conclusion to worksheet 03 Q6. The fill value is a claim about the world, and the world differs by column.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, unstack a Series that has a plain index rather than a MultiIndex: `orders.groupby("Region")["Sales"].sum().unstack()`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
