# %% [markdown]
# # Week 3, day 2 — Extra practice 09: Outliers   (L05)
#
# A second pass at worksheet 09, on a different column and within groups —
# because a single global fence treats categories with different scales as if
# they were the same.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 09 — Outliers. Run this once.
import pandas as pd

orders = pd.read_csv("../data/orders_long.csv")

print(orders[["Sales", "Profit", "Quantity"]].describe().round(2).to_string())

# %% [markdown]
# ### Question 1
#
# Apply the 1.5 x IQR fence to `Profit` instead of `Sales`. Print the fences and the counts below and above.
# > **NOTE:** unlike `Sales`, this column has genuine negative values. Expect both tails to be populated.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the five most negative and five most positive `Profit` values with their `Sales`, so you can see whether the extremes look like errors.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Now apply the fence **within each category**. For each, print Q1, Q3, the upper fence and the number of flagged orders.
# > **NOTE:** worksheet 09 Q9 showed the flag rate differing by category under a single global fence. This is the fix.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Count the total flagged by the per-category fences and compare with the single global fence from worksheet 09. Print both numbers and the overlap.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Print the rows flagged by the per-category fence but **not** by the global one, with their category and sales. Say why the global fence missed them.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Use a percentile rule instead of either fence: flag the top 1% of `Sales` with `quantile(0.99)`. Print the threshold, the count, and what share of revenue those orders carry.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Compare all three rules side by side — IQR, `|z| > 3`, and top 1% — printing the count and the share of revenue each would remove.
# > **NOTE:** three defensible rules, three different answers, and the choice is never in the data.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, compute a quantile on a text column: `orders["Category"].quantile(0.75)`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
