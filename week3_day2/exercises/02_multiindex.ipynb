# %% [markdown]
# # Week 3, day 2 — Worksheet 02: MultiIndex   (L04)
#
# A MultiIndex is an index with more than one level. You rarely build one on
# purpose — it arrives, because `groupby` on two columns produces one. This sheet
# is about reading it, selecting from it, and getting back out of it.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L04]`, slides 7–8.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 02 — MultiIndex. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")

# groupby on two columns -> a MultiIndex, without asking for one.
by_ry = orders.groupby(["Region", "Year"])["Sales"].sum().round(2)

print(by_ry.head(8))
print()
print("index type:", type(by_ry.index).__name__)

# %% [markdown]
# PART A — where it came from

# %% [markdown]
# ### Question 1
#
# Print `by_ry.index.names`, `by_ry.index.nlevels`, and `len(by_ry)`. Then print `by_ry.index.levels` and note that the levels list every value, not every combination.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the whole of `by_ry`. Look at the order the rows come out in, and say what it is sorted by.
# > **NOTE:** `groupby` sorted this for you. Check whether the order is the one your data was in.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Select on the outer level: print `by_ry.loc["Ontario"]`. Then select one cell with a tuple: `by_ry.loc[("Ontario", 2012)]`. Note what the first one returns and what happened to the level you selected on.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Now try to select on the *inner* level the same way: print `by_ry.loc[2012]`, catching the exception. Then do it correctly with `by_ry.xs(2012, level="Year")`.
# > **NOTE:** the outer level is cheap to select on and the inner level is not. That asymmetry is decided by the order you passed to `groupby`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Swap the levels with `by_ry.swaplevel()` and print the first eight rows. Then sort it with `.sort_index()` and print again. Say why the first version looked wrong.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — getting back out

# %% [markdown]
# ### Question 6
#
# Print `by_ry.reset_index()` and its shape and columns. Confirm the two index levels became ordinary columns.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Go the other way: take the flat frame from Q6 and rebuild the MultiIndex with `set_index(["Region", "Year"])`. Confirm you get back what you started with using `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Aggregate across one level: print `by_ry.groupby(level="Region").sum()`, then compare it with `orders.groupby("Region")["Sales"].sum()` rounded the same way. Print the per-region difference.
# > **NOTE:** you can group a MultiIndexed object by one of its own levels — that is how you collapse a level without going back to the raw data. Whether that gives the same answer is a separate question.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Build a three-level index: `orders.groupby(["Region", "Year", "Category"])["Sales"].sum()`. Print how many rows it has, compare with the number of possible combinations, and print the first six rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, ask for a combination that does not exist: print `by_ry.loc[("Nunavut", 2013)]`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
