# %% [markdown]
# # Week 3, day 2 — Worksheet 03: unstack   (L04)
#
# `unstack()` takes a row level and turns it into columns. It is how you get from
# a `groupby` result to something you can read side by side — and it is where
# `NaN`s appear that were never in your data.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L04]`, slides 9–10.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 03 — unstack. Run this once.
import pandas as pd

orders = pd.read_csv("data/orders_long.csv")

# Every combination is present in the full data...
by_ry = orders.groupby(["Region", "Year"])["Sales"].sum().round(2)

# ...but Technology has gaps: no Nunavut orders in 2009 or 2012.
tech = orders[orders["Category"] == "Technology"]
by_tech = tech.groupby(["Region", "Year"])["Sales"].sum().round(2)

print("all orders:", len(by_ry), "combinations")
print("technology:", len(by_tech), "combinations")

# %% [markdown]
# PART A — the operation

# %% [markdown]
# ### Question 1
#
# Print `by_ry.unstack()`. Note which level became the columns, and print the result's shape.
# > **NOTE:** you did not tell it which level to move. Check which one it picked.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Name the level explicitly: print `by_ry.unstack("Year")` and confirm it matches Q1 with `.equals()`. Then print `by_ry.unstack("Region")` and describe how it differs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Unstacking is reversible when nothing is missing. Print `by_ry.unstack().stack()` and compare it with `by_ry` using `.equals()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the cells nobody filled

# %% [markdown]
# ### Question 4
#
# Now unstack the Technology data: print `by_tech.unstack()`. Count the `NaN`s with `.isna().sum().sum()` and compare the number of cells with the number of rows that went in.
# > **NOTE:** no data was added or lost. The `NaN`s are combinations that never happened, made visible by the shape.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Print the dtype of `by_tech` and then of `by_tech.unstack()`. Something changed that you did not ask for.
# > **NOTE:** compare with Q1, where the full data had no gaps.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Use `fill_value=0`: print `by_tech.unstack(fill_value=0)` and its dtypes. Then say, in a comment, what you have just asserted about Nunavut.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Show the difference the fill makes. Compute the column totals of `by_tech.unstack()` and of `by_tech.unstack(fill_value=0)` and compare them.
# > **NOTE:** `sum()` skips `NaN` by default, but `mean()` also skips it — and dividing by a different count is not the same operation. Work out which of the two summaries should differ before you run it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — on a three-level index

# %% [markdown]
# ### Question 8
#
# Build `orders.groupby(["Region", "Year", "Category"])["Sales"].sum()` and unstack only the `Category` level. Print the shape and the first six rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Unstack two levels at once: print `three.unstack(["Year", "Category"]).shape` and the first few column labels. Count the filled and empty cells, and say what the column index has become.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, unstack a level that does not exist: print `by_ry.unstack("Category")`. **This is supposed to fail.** Read the exception.

# %%
############################
## Your Code Here
############################
