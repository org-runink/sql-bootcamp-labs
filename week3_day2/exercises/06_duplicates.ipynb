# %% [markdown]
# # Week 3, day 2 — Worksheet 06: Duplicates   (L05)
#
# A repeated row inflates every count and shifts every average, and it does it
# without any sign that something is wrong. This sheet is about finding them,
# deciding whether they *are* duplicates, and only then removing them.
#
# `data/customers_messy.csv` has real problems in it. Some are obvious and some
# are one character wide.
#
# **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L05]_data_transformation_with_Pandas.pdf`,
# slides 5–10.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 06 — Duplicates. Run this once.
import pandas as pd

cust = pd.read_csv("data/customers_messy.csv")

print("shape:", cust.shape)
print(cust.head())

# %% [markdown]
# PART A — finding them

# %% [markdown]
# ### Question 1
#
# Print `cust.duplicated()` summed, and `len(cust)`. Then print the first six rows flagged as duplicates.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# `duplicated()` marks the **second** occurrence, not the first. Prove it: count with the default, then with `keep=False`, and explain the difference between the two numbers.
# > **NOTE:** one of these answers 'which rows should I delete', the other answers 'which rows are involved'.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Look at one repeated group before deleting anything. Take the `CustomerID` of the first flagged row, print every row with that ID, and confirm they really are identical.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Remove them: print `len(cust.drop_duplicates())`, and confirm the number removed matches Q1. Then check whether `cust` itself changed.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the ones that only look identical

# %% [markdown]
# ### Question 5
#
# Count the distinct `CustomerID`s and compare with the row count of the de-duplicated frame. They disagree. Find an ID that still appears twice and print those rows with `repr()` applied to `CustomerName`.
# > **NOTE:** `drop_duplicates()` compares whole rows. Two rows differing by one invisible character are not duplicates as far as it is concerned.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Count how many `CustomerName` values have leading or trailing whitespace, using `!= .str.strip()`. Then strip the column and re-run `drop_duplicates()`, and compare the row count with Q4.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Print `cust["Region"].unique()` and then `type(...)` of it. The deck says this returns a NumPy array with `dtype=object`. Check both claims.
# > **NOTE:** two separate assertions on that slide, and this Pandas disagrees with both.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — duplicates on a subset

# %% [markdown]
# ### Question 8
#
# Define duplicates by `CustomerID` alone: print `len(cust.drop_duplicates(subset=["CustomerID"]))`, and compare with `keep="last"`. Then check whether the two results are the same rows.
# > **NOTE:** with `subset`, you are asserting that one column identifies a customer. Q5 showed rows where that is true and the whole row still differs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Show why the choice matters. For an ID that appears more than once with different content, print the row kept by `keep="first"` and the row kept by `keep="last"` side by side.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, de-duplicate on a column that does not exist: `cust.drop_duplicates(subset=["Customer_ID"])`. **This is supposed to fail.** Read the exception.
# > **NOTE:** the underscore is the whole difference. Compare with worksheet 06 of 30/08, where `drop(errors="ignore")` swallowed the same class of typo.

# %%
############################
## Your Code Here
############################
