# %% [markdown]
# # Morning class 27/08 — Worksheet 01: Conditionals   (L05)
#
# A conditional is how a program stops doing the same thing every time. This
# sheet covers `if` / `elif` / `else`, the operators that go inside them, nesting,
# truthiness, and the one-line conditional expression.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 2–23.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 01 — Conditionals. Run this once.
dozen_egg_price = 3.49
fraud_score = 0.25
basket_total = 84.50
membership = "gold"
weight_kg = 12.0
region = "north"

# Deliberately empty / zero / blank values, for the truthiness question.
items_in_stock = 0
customer_name = ""
pending_orders = []

print("dozen_egg_price:", dozen_egg_price)
print("fraud_score:    ", fraud_score)
print("basket_total:   ", basket_total)
print("membership:     ", membership)

# %% [markdown]
# PART A — if / else, and the operators that go inside

# %% [markdown]
# ### Question 1
#
# Warm-up, straight off slide 9. Print `'Too expensive!'` if `dozen_egg_price` is greater than `2.99`, otherwise `'Just the right price!'`. Then write it a second time the other way round — test `<= 2.99` and swap the two branches — and confirm you get the same word out.
# > **NOTE:** the colon at the end of the `if` line and the four-space indent underneath it are not decoration. Python uses the indentation to decide where the block ends.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the result of comparing `basket_total` with `84.50` using all six comparison operators: `==`, `!=`, `>`, `<`, `>=`, `<=`. Label each line so you can tell which is which.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Free shipping needs a basket of at least `50` **and** a gold membership. Print whether this basket qualifies. Then print the `or` version of the same two tests, and print `not` applied to the gold-membership test. Finally print the three-way chained comparison `0 <= fraud_score <= 1`.
# > **HINT:** `and`, `or` and `not` are words in Python, not `&&`, `||` and `!`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — elif chains, and the bug that hides in them

# %% [markdown]
# ### Question 4
#
# Slides 12–16. Set `score = 77` and print a grade band with a full `if` / `elif` / `elif` / `else` chain: `90` and over is `'A'`, `80` and over `'B'`, `70` and over `'C'`, anything else `'F'`. Then change `score` to `95` and to `12` and run it again to check both ends.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Now the same chain with the branches in the wrong order: test `>= 70` first, then `>= 80`, then `>= 90`, with `score = 95`. Run it. Print which band you got, then write in a comment how many of the `elif` branches can **ever** run.
# > **READ THE OUTPUT CAREFULLY.** This cell raises nothing. It just quietly gives the wrong grade.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Nesting, and flattening it again

# %% [markdown]
# ### Question 6
#
# Slides 17–20. Work out a shipping charge with a **nested** `if`: if `region` is `"north"`, then charge `15.0` when `weight_kg` is over `10` and `8.0` otherwise; for any other region charge `25.0` when over `10` and `12.0` otherwise. Store the number in `shipping` and print it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Write the *same* rule again without any nesting — one flat `if` / `elif` / `elif` / `else` using `and`. Store it in `shipping_flat` and print both numbers plus `shipping == shipping_flat`.
# > **WHY BOTHER:** two levels of nesting is readable. Four is not, and four is what happens when the rule grows a third condition next month.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Truthiness: what counts as True when it is not a comparison

# %% [markdown]
# ### Question 8
#
# `if` does not need a comparison — it accepts any value. Print `bool()` of each of `items_in_stock`, `customer_name`, `pending_orders`, `0.0`, `"0"`, `[0]` and `" "`. Then write an `if` / `else` on `pending_orders` that prints `'nothing to do'` or `'work to do'`.
# > **THE SURPRISE IS IN THE LAST THREE.** Empty is false; *containing* something falsy is not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART E — The conditional expression

# %% [markdown]
# ### Question 9
#
# Slides 21–23. Set `fraud_flag` with a one-line conditional expression: `True` if `fraud_score` is over `0.85`, otherwise `False`. Print it. Then set `fraud_flag2` to the plain comparison with no `if` at all, print that too, and print whether the two agree.
# > **COMPARE THIS WITH SLIDE 23.** The slide prints `True` for the one-liner and `False` for the `if`/`else` above it. Run it and see which one your Python agrees with.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Use a conditional expression inside something else. Build `label` as `"expensive"` or `"cheap"` depending on whether `dozen_egg_price` is over `2.99`, and print the sentence `Eggs are expensive at 3.49` using an f-string. Then print the same sentence with the conditional expression written directly inside the f-string's braces.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. `basket_total` is a number but suppose it arrived from a file as text. Print `"84.50" > 50`. Read the error, then write in a comment what you would have to do first.
# > **THIS CELL IS SUPPOSED TO RAISE.** Everything before it in the cell will print normally.

# %%
############################
## Your Code Here
############################
