# %% [markdown]
# # Morning class 27/08 — Worksheet 14: Capstone — building a toolkit   (L06)
#
# The L06 capstone, and it is deliberately the same job as worksheet 07.
#
# That sheet built a pipeline out of loops written inline, one after another —
# validate, join, summarise, report. This one builds the **same pipeline out of
# functions**, and then does something worksheet 07 could not: runs it twice, on
# two different feeds, with two different rules, without editing a line of it.
#
# That is what "code reusability" means in the title of the lecture. The test is
# not whether it works once; it is whether the second feed costs you one line or
# forty.
#
# Nothing here raises. Run the setup cell once, then work down. **Q10 is the one
# to read twice.**
#
# Lecture reference: all of
# `[Python_L06]_Python_functions_and_code_reusability.pdf`.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 14 — Capstone. Run this once.

# The same shape of feed as worksheet 07: amounts are TEXT, and some rows
# are unusable.
feed_a = [
    {"id": 101, "user": "u1", "amount": "12.50"},
    {"id": 102, "user": "u2", "amount": "8.00"},
    {"id": 103, "user": "u1", "amount": ""},
    {"id": 104, "user": "u9", "amount": "31.00"},
    {"id": 105, "user": "u2", "amount": "-4.00"},
    {"id": 106, "user": "u3", "amount": "17.25"},
    {"id": 107, "user": "u1", "amount": "n/a"},
    {"id": 108, "user": "u3", "amount": "9.99"},
]

# A second feed, arriving later, with different data and the same problems.
feed_b = [
    {"id": 201, "user": "u2", "amount": "40.00"},
    {"id": 202, "user": "u7", "amount": "5.50"},
    {"id": 203, "user": "u3", "amount": "0.00"},
    {"id": 204, "user": "u1", "amount": "oops"},
]

customers = {"u1": "north", "u2": "south", "u3": "north"}

print(len(feed_a), "rows in feed_a,", len(feed_b), "in feed_b")

# %% [markdown]
# PART A — One job per function

# %% [markdown]
# ### Question 1
#
# Write `parse_amount(text)`: return the value as a `float` if the text is a number, and `None` if it is blank or not numeric. Give it a docstring. Test it on `"12.50"`, `"-4.00"`, `""`, `"n/a"` and `"0.00"`, printing the input and the result for each.
# > **RETURN, DO NOT PRINT.** Everything on this sheet has to be usable by the function above it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Write `check_row(row)` returning a **tuple** of `(value, reason)`: the parsed amount and `None` when the row is good, or `None` and a short reason when it is not. Reject blanks, non-numbers and negatives. Print the result for every row in `feed_a`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `validate(rows)` that calls `check_row` on each and returns `(clean, rejects)` — `clean` a list of rows with a real `amount`, `rejects` a list of `(id, reason)` pairs. Run it on `feed_a` and print both lengths and the rejects.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Functions general enough to reuse

# %% [markdown]
# ### Question 4
#
# Write `join(rows, lookup, key_field, new_field)` that adds `new_field` to each row from `lookup[row[key_field]]`, and returns `(joined, orphans)`. Use it to add `region` from `customers`, then use the **same function** to add a `tier` from a different lookup of your own.
# > **NO MENTION OF `customers` OR `region` INSIDE THE FUNCTION.** That is what makes it reusable rather than merely extracted.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Write `summarise(rows, group_field, value_field)` returning a dictionary of group to total. Call it **three times** on `tiered_a` — by `region`, by `user` and by `tier` — printing each.
# > **ONE FUNCTION, THREE REPORTS.** Worksheet 07 needed a fresh loop for each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Passing behaviour, not just data

# %% [markdown]
# ### Question 6
#
# Write `keep_if(rows, rule)` where `rule` is a **function** returning `True` or `False` for a row. Call it three times on `tiered_a`: amounts over `10`, rows in the north, and rows whose id is even. Print how many survive each.
# > **THIS IS WORKSHEET 12's `key=` IDEA, THE OTHER WAY ROUND.** The caller supplies the decision; the function supplies the loop.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Write `run(rows, lookup, min_amount=0.0)` that validates, joins, drops anything below `min_amount`, and returns a **report dictionary** with the input count, rejects, orphans, kept count, total, and the per-region totals. Run it on `feed_a` with the default, then with `min_amount=10.0`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Now the payoff. Run the **same** `run` on `feed_b`, and print both reports. Then print the combined total from running it on `feed_a + feed_b`.
# > **COUNT THE LINES YOU HAD TO WRITE FOR THE SECOND FEED.**

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Write `reconcile(report)` returning `True` when `rejected + orphaned + below_min + kept` equals `rows_in`. Run it on all three reports. Then write `check_total(report)` comparing the `total` with the sum of `by_region`, using a tolerance of `0.01` rather than `==`.
# > **THE TOLERANCE IS NOT PEDANTRY.** Worksheet 08 Q10 is what `==` on two float totals does to you.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — The function that is right and useless

# %% [markdown]
# ### Question 10
#
# Write `average_by_region(rows)` returning the mean amount per region, and run it on the kept rows of `feed_a`. Then print the number of rows behind each average. Finally, print what `average_by_region` returns for a region with no rows.
# > **EVERY NUMBER IT RETURNS IS A CORRECT MEAN.** That is not the same as a number you can put in a report.

# %%
############################
## Your Code Here
############################
