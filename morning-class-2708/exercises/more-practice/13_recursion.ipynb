# %% [markdown]
# # Morning class 27/08 — Extra practice 13: Recursion   (L06)
#
# A second pass at worksheet 13, on different problems, plus the two cases where
# recursion is genuinely the right answer: **walking a nested structure of unknown
# depth**, and **halving a search space**.
#
# Every question asks you to name the base case first. If you cannot, the function
# is not ready to be written.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 68–87.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 13 — Recursion. Run this once.
config = {
    "db": {"host": "localhost", "port": 5432, "opts": {"ssl": True, "pool": 5}},
    "app": {"name": "lab", "debug": False},
    "version": 3,
}

sorted_ids = [2, 5, 9, 14, 21, 30, 44, 51, 68, 77]

print("sorted_ids:", sorted_ids)

# %% [markdown]
# ### Question 1
#
# Write `digit_sum(n)` adding the digits of a positive integer recursively: the base case is a single digit, and the recursive case peels off `n % 10` and recurses on `n // 10`. Print it for `7`, `123` and `98765`.
# > **`//` NOT `/`.** Integer division keeps this an integer; `/` would give you floats and never reach the base case cleanly.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Write `reverse(text)` returning the string backwards, recursively — empty string is the base case, otherwise the last character plus the reverse of the rest. Print it for `""`, `"a"` and `"recursion"`, and compare the last one with `"recursion"[::-1]`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `power(base, exp)` computing `base ** exp` for a non-negative `exp`, recursively. The base case is `exp == 0`. Print `power(2, 0)`, `power(2, 10)` and `power(3, 4)`, and check each against `**`.
# > **ANYTHING TO THE POWER ZERO IS 1.** That base case is not a special case, it is the foundation of the whole chain.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Where recursion earns it

# %% [markdown]
# ### Question 4
#
# Write `depth(value)` returning how deeply a dictionary is nested — `1` for a flat dictionary, more for nested ones. Print `depth(config)`, and print the depth of `{}` and of `{"a": 1}`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Write `flatten_config(value, prefix="")` returning a flat dictionary whose keys are dotted paths — `"db.opts.ssl"` and so on. Print the result for `config`, and print how many leaves it found.
# > **THIS IS THE JOB RECURSION IS FOR.** The nesting depth is not known when you write the function.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Write `find(values, target, low=0, high=None)` doing a recursive binary search over a **sorted** list, returning the index or `-1`. Search `sorted_ids` for `21`, for `2`, for `77` and for `22`, printing each result.
# > **HALVING, NOT WALKING.** Ten items need at most four comparisons.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Count the work. Write `find_counted(values, target, low=0, high=None, steps=0)` returning `(index, steps)`. Print the steps for the same four targets, and print how many steps a plain `for` loop would need for each.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Write `gcd(a, b)` using Euclid's method — the base case is `b == 0`, otherwise recurse on `(b, a % b)`. Print the gcd of `(48, 18)`, `(270, 192)` and `(17, 5)`, and print `gcd(5, 0)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Write `digit_sum_zero_base(n)` — the same function but with `n == 0` as its base case instead of `n < 10` — and call it on `-123`. Print `digit_sum(-123)` first and compare. Read the error, then write in a comment why the base case is never reached.
# > **THIS CELL IS SUPPOSED TO RAISE.** A working call prints first.

# %%
############################
## Your Code Here
############################
