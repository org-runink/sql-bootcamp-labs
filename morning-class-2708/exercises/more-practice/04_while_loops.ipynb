# %% [markdown]
# # Morning class 27/08 — Extra practice 04: While loops   (L05)
#
# A second pass at worksheet 04, on different data, plus three shapes the first
# sheet did not reach: two indexes moving through one list, a loop that must run
# at least once, and a `while` nested inside a `while`.
#
# Every loop on this sheet carries a guard. Get into the habit now.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 67–77.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 04 — While loops. Run this once.
tokens = ["get", "rows", "from", "orders", ";", "get", "more"]
letters = ["p", "y", "t", "h", "o", "n"]
word_chars = ["r", "o", "t", "a", "t", "o", "r"]

credits = 100
cost_per_call = 12

page_sizes = [3, 3, 3, 1, 0]      # what each API page returned; 0 means done
target = 1000

print(len(tokens), "tokens,", credits, "credits, cost", cost_per_call, "each")

# %% [markdown]
# ### Question 1
#
# Print the first five even numbers with a `while` loop, using a counter and a `found` count. Print the counter afterwards.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Spend `credits` on API calls costing `cost_per_call` each, while there is enough left for another one. Count the calls, and print the number of calls and the credits left over.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Walk `tokens` with an index inside a `while`, stopping at the `";"`. Print each token as you take it, then print how many you consumed and how many were left behind.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Two indexes, one list. Check whether `word_chars` reads the same backwards by moving `left` up from `0` and `right` down from the last index until they meet, comparing as you go. Print the verdict and the number of comparisons. Then run the identical loop over `letters`.
# > **HOW MANY COMPARISONS FOR SEVEN LETTERS?** Not seven — and the second run needs fewer still.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Python has no do-while. Emulate one: use `while True:` to fetch pages from `page_sizes` in order, add each size to a running total, and `break` at the **bottom** when the page comes back empty. Print the rows fetched and the pages requested.
# > **THE TEST GOES AT THE BOTTOM.** That is the whole difference — the body always runs at least once.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Double a value from `1` until it passes `target`, counting the doublings, with a guard at 50 passes. Print the value, the number of doublings, and whether the guard was what stopped it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# A `while` inside a `while`. Print a 3-by-4 grid of `row,col` labels using two counters. Count how many times the inner body runs, and print it.
# > **THE INNER COUNTER MUST BE RESET** at the top of every outer pass. Forget that and the grid has one row.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Build the string `"python"` from `letters` with a `while` loop and `.pop(0)`, printing the partial string on each pass. Print `letters` afterwards.
# > **LOOK AT WHAT IS LEFT.** Building the answer destroyed the input.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Walk `page_sizes` with `while page <= len(page_sizes):` — note the `<=` — printing each size and incrementing `page` inside the loop. Read the error, then write in a comment what the largest valid index of a list actually is.
# > **THIS CELL IS SUPPOSED TO RAISE.** Every real size prints first, which is what makes the bug easy to miss.

# %%
############################
## Your Code Here
############################
