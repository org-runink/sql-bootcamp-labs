# %% [markdown]
# # Morning class 27/08 — Extra practice 11: Scope and side effects   (L06)
#
# A second pass at worksheet 11, plus two things the first sheet did not reach:
# what happens when you shadow a **built-in** name, and the difference between a
# function you can test and one you cannot.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error**, and it is the error most people meet before they understand it.
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 43–58.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 11 — Scope and side effects. Run this once.
THRESHOLD = 10
counter = 0

inventory = {"widget": 5, "gizmo": 0}
queue = ["a", "b", "c"]

print("THRESHOLD:", THRESHOLD, "| inventory:", inventory)

# %% [markdown]
# ### Question 1
#
# Write `over(value)` returning `value > THRESHOLD`, reading the global. Print it for `5` and `50`. Then write `over_explicit(value, limit)` and print the same two with `THRESHOLD` passed in.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Write `try_to_count()` that does `counter = counter + 1`... no. Instead write `bump()` that does `local_counter = counter + 1` and prints it, leaving `counter` alone. Print `counter` before and after calling it.
# > **READING A GLOBAL IS FINE.** It is assigning to it that changes the rules — Q9.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Write `restock(stock, item, qty)` that does `stock[item] = stock.get(item, 0) + qty` and returns nothing. Print `inventory`, call it for `"widget", 3` and `"sprocket", 7`, and print `inventory` again.
# > **THE FUNCTION RETURNS NOTHING AND CHANGES EVERYTHING.**

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Write the non-mutating twin. `restocked(stock, item, qty)` returns a **new** dictionary and leaves the original alone. Run it on a fresh `{"a": 1}`, printing the original and the result.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Shadow a builtin, on purpose, and then undo it. Print `len(queue)`. Then set `len = 99` and print `len`. Then use `del len` and print `len(queue)` again.
# > **BETWEEN THE SECOND AND THIRD LINES, `len()` DOES NOT WORK.** That is the B in LEGB being covered up.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Nested functions. Write `make_greeting(greeting)` that defines an inner `greet(name)` returning `f"{greeting}, {name}!"` and **returns the inner function**. Build `hello = make_greeting("Hello")` and `hi = make_greeting("Hi")`, then call both on `"ana"`.
# > **`hello` AND `hi` ARE TWO DIFFERENT FUNCTIONS**, each remembering the `greeting` it was built with.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Write `drain(items)` that empties a list with `.pop(0)` and returns what it took. Print `queue`, call `drain(queue)` printing the result, then print `queue` and call `drain(queue)` a second time.
# > **CALL IT TWICE.** A function that consumes its input is not the same as one that reads it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Two ways to add up. Write `total_pure(values)` returning the sum, and `total_impure(values)` that adds to a global `running` and returns it. Set `running = 0`, then call each function **twice** on `[1, 2, 3]` and print all four results.
# > **ONE OF THESE GIVES THE SAME ANSWER TWICE.**

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Write `increment()` that does `counter = counter + 1` and prints it — with no `global` declaration — and call it. Read the error, then write in a comment why it mentions a *local* variable when `counter` clearly exists.
# > **THIS CELL IS SUPPOSED TO RAISE.** Read the error name carefully; it is not `NameError`.

# %%
############################
## Your Code Here
############################
