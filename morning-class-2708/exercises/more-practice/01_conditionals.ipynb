# %% [markdown]
# # Morning class 27/08 — Extra practice 01: Conditionals   (L05)
#
# A second pass at worksheet 01, on different data, plus four things the first
# sheet did not reach: `in` as a test, what `and` and `or` actually *hand back*,
# short-circuiting, and comparing strings.
#
# Run the setup cell once, then work down. **Question 9 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 2–23.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 01 — Conditionals. Run this once.
role = "analyst"
years = 3
certified = False

allowed_roles = ["analyst", "engineer", "scientist"]
region_codes = {"north": "N1", "south": "S1"}

username = "Ana"
fallback_name = "guest"
supplied_name = ""

reading = 0.0
threshold = 0.5

print("role:", role, "| years:", years, "| certified:", certified)
print("allowed_roles:", allowed_roles)

# %% [markdown]
# ### Question 1
#
# Warm-up. Print `'senior'` if `years` is `5` or more, `'mid'` if `3` or more, and `'junior'` otherwise. Then run the same chain again with `years` set to `5` and to `1`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# `in` is a condition in its own right. Print whether `role` is in `allowed_roles`, whether `"manager"` is **not** in it, whether `"north"` is in `region_codes`, and whether `"N1"` is in `region_codes`. Then print whether `"ana"` is in `"Ana Lima"`.
# > **THE FOURTH ONE IS THE TRAP.** `in` on a dictionary asks about its keys.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Build an access rule with `and`, `or` and `not`, printing each on its own line: allowed **and** certified; allowed **or** certified; **not** certified; and allowed **and not** certified.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# `and` and `or` do not have to produce booleans. Print `supplied_name or fallback_name`, then `username or fallback_name`, then `supplied_name and username`. Print the `type()` of the first one.
# > **READ THE OUTPUT, NOT THE OPERATOR NAME.** None of these prints `True` or `False`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# `and` and `or` stop as soon as they know the answer. Print `False and undefined_thing`, then `True or undefined_thing` — where `undefined_thing` is a name that does not exist anywhere. Then print `len(allowed_roles) > 0 and allowed_roles[0]`.
# > **NEITHER OF THE FIRST TWO RAISES A NameError.** Work out why before running it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Strings compare too. Print `"apple" < "banana"`, `"Zoe" < "ana"`, `"10" < "9"`, and `10 < 9`. Then print `"Zoe".lower() < "ana".lower()`.
# > **THREE OF THESE SURPRISE PEOPLE.** Two of them are the same surprise.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Nest, then flatten. Write a nested `if` that prints `'full access'` when the role is allowed **and** certified, `'read only'` when allowed but not certified, and `'no access'` otherwise. Then write the same rule as one flat `if`/`elif`/`else`. Run both against all three combinations, so every branch prints at least once.
# > **THREE BRANCHES, THREE TESTS.** A rule you have only run once has only been checked once.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Comparing floats. Print `reading < threshold`, then `reading == 0.0`, then `0.1 + 0.1 + 0.1 == 0.3`, then `abs((0.1 + 0.1 + 0.1) - 0.3) < 0.000001`. Then set `status` with a conditional expression — `"over"` or `"under"` at the threshold — and print it in an f-string.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Last one, and it is meant to fail. Print `region_codes["north"]`, then print `region_codes["east"]`. Read the error, then write in a comment the two ways to ask for a key that might not be there.
# > **THIS CELL IS SUPPOSED TO RAISE.** The first line prints normally.

# %%
############################
## Your Code Here
############################
