# %% [markdown]
# # Morning class 27/08 — Worksheet 06: Combined challenges   (L05)
#
# The capstone. One dataset — a morning of clickstream events — and ten questions
# that need everything from worksheets 01 to 05: conditionals, `for`, `range`,
# `while`, comprehensions, `break`, `continue` and the loop `else`.
#
# The questions get harder as you go. Q1 to Q4 are warm-ups; Q5 and Q9 are the
# two that need a piece of state carried from one pass to the next, which is the
# skill this whole lecture has been building towards.
#
# Nothing here raises. **Q10 is the one to read twice** — it produces three
# correct numbers, and at most one of them answers the question that was asked.
#
# Run the setup cell once, then work down.
#
# Lecture reference: all of `[Python_L05]_Python_control_flow_and_iteration.pdf`.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 06 — Combined challenges. Run this once.
#
# One morning of clickstream, already sorted by time.
# (minutes since 09:00, user, action)
events = [
    (0,  "u1", "view"),
    (3,  "u1", "view"),
    (5,  "u2", "view"),
    (9,  "u1", "cart"),
    (12, "u1", "purchase"),
    (48, "u1", "view"),
    (50, "u3", "view"),
    (52, "u2", "cart"),
    (55, "u1", "view"),
    (61, "u2", "purchase"),
    (95, "u3", "view"),
    (97, "u3", "cart"),
]

SESSION_GAP = 30      # a gap longer than this starts a new session

print(len(events), "events, from minute", events[0][0], "to", events[-1][0])

# %% [markdown]
# PART A — Counting things

# %% [markdown]
# ### Question 1
#
# Print how many events there are, how many distinct users, and how many distinct actions. Use a set comprehension for the last two, and print the sets as well as their sizes.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Count the events per user and the events per action, as two dictionaries built with a counting loop. Print both.
# > **HINT:** worksheet 02 Q11 is the pattern — check `in`, add one if present, start at one if not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Build `first_seen` and `last_seen`: for each user, the minute of their first and their last event. The data is already sorted by time, so one pass is enough. Print both dictionaries, and print each user's span (last minus first).

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — Looking at neighbours

# %% [markdown]
# ### Question 4
#
# Build `gaps`, the list of minutes between each event and the one before it, using `range(1, len(events))`. Print the gaps, the largest one, and which two minutes it sits between.
# > **WHY START AT 1:** the first event has nothing before it. Twelve events give eleven gaps.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Sessionise, per user. A user's events belong to the same session until they are more than `SESSION_GAP` minutes apart; a bigger gap starts a new session. Count the sessions for each user and print the dictionary, plus the total number of sessions.
# > **THIS IS THE HARD ONE.** You need to remember, for each user, when you last saw them. A dictionary is the right place to keep that.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Searching

# %% [markdown]
# ### Question 6
#
# Find the first `purchase` in the whole log: print the minute and the user, and `break`. Then run the same search for the first purchase by `u3`, with an `else` on the loop reporting that there wasn't one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Two comprehensions. Build `u1_actions`, the actions of `u1` in order, with the filter form. Build `halves`, one entry per event labelled `"first half"` or `"second half"` depending on whether the minute is under 50, with the map form. Print both with their lengths.
# > **CHECK THE LENGTHS AGAINST 12.** One of these should match it and one should not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Build `did`, a dictionary mapping each user to the **set** of actions they performed. Then print, for each user, whether they completed the funnel — viewed **and** carted **and** purchased — and print how many users completed it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Carrying state between passes

# %% [markdown]
# ### Question 9
#
# Find the longest run of consecutive events belonging to the **same** user. Walk the log once, keeping a current run length and the best seen so far, and print the best run, which user it belonged to, and where it started.
# > **THE SECOND HARD ONE.** Three variables survive from one pass to the next: the current user, the current run length, and the best run so far.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART E — The number that does not mean what it says

# %% [markdown]
# ### Question 10
#
# Report the conversion rate. Count the purchases, then print it three ways: purchases per event, purchases per user, and purchases per session (reuse `sessions` from Q5). Then write in a comment which one you would put in a report, and what you would have to ask first.
# > **ALL THREE ARE ARITHMETICALLY CORRECT.** The highest is four times the lowest.

# %%
############################
## Your Code Here
############################
