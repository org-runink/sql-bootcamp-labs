# %% [markdown]
# # Morning class 27/08 — Worksheet 02: For loops   (L05)
#
# A `for` loop is a **definite** loop: it runs once per item in a collection, and
# the collection decides how many times. This sheet walks the deck's tour —
# lists, `range()`, strings, unpacking, dictionaries, nesting — and stops on three
# places where the slides and Python do not agree.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error**, and several questions change their data in place, so run them in order.
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 24–53.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 02 — For loops. Run this once.
enrollment = [
    ("jack", "DS101"),
    ("lucy", "DS301"),
    ("dominic", "DE101"),
    ("jen", "DA101"),
    ("luke", "DA101"),
    ("marie", "BI201"),
]

produce = {
    "Red kidney beans": 1.99,
    "White beans": 3.99,
    "Green lentils": 1.19,
    "Chopped tomatoes": 4.99,
}

grocery_list = ["Tuna", "Salmon", "Mackerel", "Pasta", "Rice", "Bread",
                "Salmon", "Mackerel", "Pasta", "Salmon", "Mackerel", "Tuna"]

courses = [
    ["Apache Spark", "EC2", "S3"],
    ["SageMaker", "AWS Lambda", "Redshift"],
    ["Python", "Sklearn", "SQL"],
]

random_str = "Data Science"

print(len(enrollment), "enrolments,", len(produce), "products,",
      len(grocery_list), "grocery items")

# %% [markdown]
# PART A — The shape of a for loop

# %% [markdown]
# ### Question 1
#
# Loop over `enrollment` and print each item as it comes. Then loop over it a second time **unpacking in the loop header** — `for name, course in enrollment:` — and print `jack is on DS101` and so on.
# > **HINT:** unpacking works because every item is a 2-tuple. Two names on the left, two values on the right.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Total the prices in `produce` by hand: start `total = 0`, add each value inside the loop, and print the total after the loop. In the same loop count how many products cost more than `2.00`, and print that too. Then print `sum(produce.values())` to check yourself.
# > **WATCH THE INDENTATION.** `print(total)` belongs *outside* the loop. Indent it by mistake and you print a running total instead of a final one — no error, four lines of output instead of one.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — range()

# %% [markdown]
# ### Question 3
#
# Slides 38–42. Print `list()` of each of these: `range(5)`, `range(1, 5)`, `range(1, 5, 2)`, `range(5, 0, -1)`, and `range(5, 0)`. Label each line.
# > **THE LAST ONE IS NOT A TYPO.** Predict it before you run it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Slide 43 numbers the enrolments with a hand-rolled counter and an `if`/`else` where both branches do the same `i += 1`. Print the index and the name of every enrolment **twice**: once with `range(len(enrollment))`, once with `enumerate(enrollment)`. Then print `enumerate(enrollment)` itself, without `list()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Slide 46 is titled *reversing a list* and loops `range(num_students - 1, 0, -2)`. Run exactly that over `enrollment`, printing the index and the name, and count how many lines it prints. Then write the loop that really does reverse the list, print that, and count again.
# > **COUNT THE LINES.** Six enrolments go in. How many come out of the slide's version, and which name never appears at all?

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Looping over a string

# %% [markdown]
# ### Question 6
#
# Build a lowercase copy of `random_str` the long way: make an empty list, append `char.lower()` for each character, print the list, then print `"".join(...)` of it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Slide 48. Turn `random_str` into a list of characters, uppercase every character whose index is produced by `range(0, len(char_str), 2)`, and print the joined result. Then print the indexes that loop actually visits, and say in a comment whether they are the odd ones or the even ones.
# > **READ THE SLIDE'S TITLE, THEN READ ITS CODE.** They describe different things.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Looping over a dictionary

# %% [markdown]
# ### Question 8
#
# Slide 51. Print the products three ways: the keys (by looping the dictionary directly), the values (with `.values()`), and both together (with `.items()` and two loop variables). Then print `produce.keys()` on its own, without `list()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Slide 51 raises every price by 13% with `for k in produce: produce[k] = produce[k] * 1.13`. Run exactly that, print `produce`, and compare it line by line with the output printed on the slide.
# > **THE SLIDE'S OUTPUT CANNOT BE RIGHT.** Four different starting prices; look at what it claims comes out.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Now try to add a key while looping. Loop over `produce` and, inside the loop, set `produce[k + " (organic)"] = 0.0`. Run it and read the error. Then print `len(produce)` and write in a comment what happened before it stopped.
# > **THIS CELL IS SUPPOSED TO RAISE.** Q9 only *changed* values, which is allowed. Adding a key is not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Slide 52. Count how many times each item appears in `grocery_list`. Build an empty dictionary, loop the list, and use `if item in counts:` to decide between adding one and starting at one. Print the dictionary, then print how many distinct items there were.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART E — Nesting

# %% [markdown]
# ### Question 12
#
# Slide 53. `courses` is a list of lists. Flatten it into `courses_unpacked` with a loop inside a loop and print it, then print its length and the length of `courses`. Finally, print the number of times the **inner** line runs versus the number of times the **outer** line runs.
# > **THE COST IS MULTIPLICATIVE.** Three lists of three is nine — and three lists of a thousand is three thousand.

# %%
############################
## Your Code Here
############################
