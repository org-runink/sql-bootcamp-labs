# %% [markdown]
# # Morning class 27/08 — Worksheet 12: Lambda, map and filter   (L06)
#
# A `lambda` is a function with no name and one expression. Slides 59–67 show
# what it is and pair it with `filter` and `map`.
#
# The deck stops there. This sheet goes two steps further, to the place lambdas
# actually earn their keep — `sorted(key=...)`, `max(key=...)` — and to the two
# things about `map` and `filter` that will catch you: they are **lazy**, and they
# are **one-shot**.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L06]_Python_functions_and_code_reusability.pdf`,
# slides 59–67.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 12 — Lambda, map and filter. Run this once.
numbers = [1, 22, 35, 4, 5, 7, 8]
words = ["extract", "Load", "transform", "QA"]

staff = [
    {"name": "ana", "role": "engineer", "years": 6},
    {"name": "bo", "role": "analyst", "years": 2},
    {"name": "cai", "role": "engineer", "years": 9},
    {"name": "dee", "role": "analyst", "years": 4},
]

print("numbers:", numbers)
print("words:  ", words)

# %% [markdown]
# PART A — What a lambda is

# %% [markdown]
# ### Question 1
#
# Slides 60–62. Write `value_double(x)` with `def`, returning `x * 2`, and call it on `5`. Then write the same thing as a lambda assigned to `double`, call that on `5`, and print both results plus `type(double)`.
# > **A LAMBDA IS AN EXPRESSION, NOT A STATEMENT.** There is no `return` — the single expression *is* the return value.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Slide 62 calls a lambda without ever naming it: `(lambda x: x * 2)(5)`. Print that. Then print `(lambda x, y: x * y)(6, 7)` and `(lambda: "no arguments at all")()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Slide 65. Print the result of all four argument styles on lambdas: positional `(1, 2, 3)`; a default `z=3` called with `(1, 2)`; `*args` summed, called with `(1, 2, 3)`; and `**kwargs` summed over its values, called with `one=1, two=2, three=3`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — filter and map

# %% [markdown]
# ### Question 4
#
# Slide 66. Use `filter` with a lambda to keep the even values in `numbers`, and print the result as a list. Then print the `filter(...)` object itself, **without** `list()`.
# > **THE SECOND PRINT IS THE POINT.** `filter` does not return a list.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Slide 67. Use `map` with a lambda to get `x % 2` for every value in `numbers`, and print it as a list. Then use `map` to uppercase every word in `words`. Print the lengths of both results next to the lengths of their inputs.
# > **`filter` CAN SHORTEN THE LIST. `map` NEVER DOES.** It is worksheet 03 Q5 again, wearing different names.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# The same job three ways. Get the squares of the even numbers in `numbers` using (a) `map` and `filter` together, (b) one list comprehension, and (c) a plain `for` loop. Print all three and print whether they are all equal.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Where lambdas actually earn their keep

# %% [markdown]
# ### Question 7
#
# Not in the deck, and the most useful thing here. Sort `staff` by `years` ascending, then descending, then by `name`, using `sorted` with a `key=lambda`. Print just the names in each order.
# > **`key=` TAKES A FUNCTION**, and calls it once per item to work out what to sort on. This is the reason lambdas exist.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Use `max` and `min` with `key=lambda` to find the most and least experienced member of `staff`, and print each one's name and years. Then print `max(staff, key=lambda p: p["role"])` and say in a comment what that even means.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# A lambda is not always needed. Sort `words` by length with `key=len`, uppercase them with `map(str.upper, words)`, and sort them case-insensitively with `key=str.lower` — **no `lambda` anywhere**. Print all three.
# > **IF THE LAMBDA JUST CALLS ONE FUNCTION, PASS THAT FUNCTION.** `key=lambda w: len(w)` and `key=len` do the same thing; only one of them is worth reading.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Lazy and one-shot

# %% [markdown]
# ### Question 10
#
# Build `doubled = map(lambda x: x * 2, numbers)` and assign it to a variable. Print `list(doubled)`. Then print `list(doubled)` **again**, from the same object. Then print `sum(...)` over a fresh `map` and try `len()` on another one in a comment.
# > **RUN IT AND READ BOTH LINES.** Nothing raises. The second one is not a typo.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. Sort `staff` by a field that does not exist — `key=lambda p: p["salary"]`. Read the error, then write in a comment how you would sort by a field that is missing from *some* records.
# > **THIS CELL IS SUPPOSED TO RAISE.** A working sort prints first.

# %%
############################
## Your Code Here
############################
