# %% [markdown]
# # Morning class 27/08 — Worksheet 03: Comprehensions   (L05)
#
# A comprehension is a `for` loop that builds a collection, written on one line.
# Nothing on this sheet does anything you could not do with worksheet 02's loops —
# the point is that the one-line form says *what you want* instead of *how to
# accumulate it*.
#
# The deck shows `if` in two different places (slides 60–61 and 62–63) without
# ever putting them side by side. Questions 3–5 do exactly that, because the two
# positions mean genuinely different things.
#
# Run the setup cell once, then work down. **Question 11 is supposed to raise an
# error.**
#
# Lecture reference: `[Python_L05]_Python_control_flow_and_iteration.pdf`,
# slides 54–66.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 03 — Comprehensions. Run this once.
temps_c = [0, 12, 18, 23, 31, 7]
words = ["Extract", "transform", "LOAD", "validate"]

inventory = {"widget": 12, "gizmo": 0, "doohickey": 7, "sprocket": 0}
readings = [("s1", 4.2), ("s2", 0.0), ("s3", 7.9), ("s4", 3.1)]

on_sale_items = ["Chopped tomatoes", "Banana", "Red kidney beans"]
teams = [["ana", "bo"], ["cai", "dee", "eve"], ["fay"]]

# name -> the skills they listed. The skills are a LIST. Remember that for Q11.
tagged = [("ana", ["sql", "python"]), ("bo", ["go"]), ("cai", ["sql"])]

print("temps_c:  ", temps_c)
print("words:    ", words)
print("inventory:", inventory)

# %% [markdown]
# PART A — The same loop, written twice

# %% [markdown]
# ### Question 1
#
# Slide 55. Build `double_value` for `range(10)` the long way — empty list, `for`, `append` — and print it. Then build `double_comp` with a list comprehension, print it, and print whether the two lists are equal.
# > **THE ORDER READS THE SAME.** `[2 * i for i in range(10)]` — the `for` part is what the loop header said, and the `2 * i` part is what went inside `append()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Two more, no filtering. Build `temps_f` by converting every value in `temps_c` with `c * 9 / 5 + 32`. Build `lengths` as the `len()` of every word in `words`. Print both, and print the length of each result next to the length of its input.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — The two places `if` can go

# %% [markdown]
# ### Question 3
#
# Slides 62–63, the **filter** form: the `if` goes at the **end**. Build `warm` as every value in `temps_c` above 15, and `loud` as every word in `words` that is not all lowercase (`w != w.lower()`). Print both and their lengths.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Slides 60–61, the **map** form: the `if` goes at the **front** and must have an `else`. Run the deck's own example — `[e ** 2 if e % 2 == 0 else e / 2 for e in [1, 2, 3, 4, 5]]` — and print it with its length. Then build `banded`, which turns every value in `temps_c` into `"warm"` or `"cold"` at the 15 mark.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Now put them side by side. Using the **same** test (`t > 15`) and the **same** input, print the filter version and the map version of `temps_c` on two lines, each followed by its length. Then write in a comment which of the two can change the length of the result, and which one is allowed to leave out `else`.
# > **THIS IS THE QUESTION THAT MATTERS ON THIS SHEET.** Same words, same order of reading, two completely different jobs.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — Dictionaries, sets, and pairs

# %% [markdown]
# ### Question 6
#
# Slide 65. Build a dictionary mapping every name in `on_sale_items` to the string `"On sale"`, and print it. Then compare it, key by key, with the output printed on the slide.
# > **READ THE SLIDE'S CODE, THEN READ ITS OUTPUT.** They are not the same dictionary.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Slide 66 uses `.items()` with two loop variables. Build three dictionaries from `inventory` and print each: `doubled` with every count multiplied by 2; `out_of_stock` holding only the items whose count is `0`; and `by_count`, the inverse — count as the key, name as the value.
# > **LOOK HARD AT `by_count`.** Four items go in.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Build `sensor_ids` as a **set** comprehension of the first element of every pair in `readings`, and print it with its length. Then build `readings_dict` from the same pairs with a dict comprehension. Finally build `numbered`, a list of `"1. Extract"`-style strings from `words`, using `enumerate` with `start=1` and an f-string.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART D — Nesting, scope, and where to stop

# %% [markdown]
# ### Question 9
#
# Flatten `teams` into one list of names with a **nested** comprehension, and print it with its length. Then write the same thing as the two nested `for` loops from worksheet 02, and print whether the two results are equal.
# > **CLAUSE ORDER:** the `for` clauses in a nested comprehension read left to right in the same order you would write the loops top to bottom. Outer first.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Set `x = "untouched"`. Build `squares` as a comprehension that uses `x` as its loop variable over `range(3)`, then print `squares` and `x`. Now run a plain `for x in range(3):` loop with `pass` in the body, and print `x` again.
# > **PREDICT BOTH PRINTS BEFORE YOU RUN IT.** Most people get one of the two wrong.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 11
#
# Last one, and it is meant to fail. `tagged` pairs a name with a **list** of skills. Try to build a dictionary keyed by the skills — `{skills: name for name, skills in tagged}`. Read the error, then write in a comment what you would key it by instead.
# > **THIS CELL IS SUPPOSED TO RAISE.** The dictionary that works prints first.

# %%
############################
## Your Code Here
############################
