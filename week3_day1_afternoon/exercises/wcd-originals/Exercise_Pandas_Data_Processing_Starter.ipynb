# %% [markdown]
# <center>
#     <img src="https://weclouddata.s3.amazonaws.com/images/logos/wcd_logo_new_2.png" width='20%'>
# </center>
#
# ----------
#
# <h1 align="center"> Exercise - Pandas Data Processing </h1>
#
#
# ----------

# %% [markdown]
# # Exercise 1
# Load all the data files into Python

# %%
import pandas as pd
import csv

# %%
# TODO: load all the data files into pandas DataFrames
# Files: DimSalesOrder, DimProduct, DimProductCategory, DimProductSubCategory,
# DimCustomer, DimReseller, DimDate, DimGeography, DimSalesTerritory
# Base URL: https://weclouddata.s3.amazonaws.com/datasets/retail/adventureworks/csv/

# %% [markdown]
# Look at each table to make sure they have been read the way you wanted

# %%
reseller

# %%
# TODO: the reseller table isn't loading correctly (all columns combined into
# one, and one row is misaligned). Fix it so each column loads separately with
# the correct header names.

# %%
# TODO: continue fixing the reseller table here

# %%
# TODO: the column names are sitting in the first data row. Promote that row
# to be the header

# %% [markdown]
# # Exercise 2
# Which table should be used as the fact table?
#
# fact table: contains all the data to be analyzed
#
# dimension table: contains all the data which the data in the fact table can be analyzed by

# %%
sales.head()

# %% [markdown]
# Check if there are any empty cells in this table

# %%
# TODO: check whether there are any empty cells in the sales table

# %% [markdown]
# Checking the NA values:

# %%
# isna() - for checking the NA values

# %% [markdown]
# Remove columns you don't think are useful

# %%
# TODO: remove the columns you don't think are useful for analysis

# %% [markdown]
# # Exercise 3
# Calculate total sales, costs, and gross profit

# %%
# Total sales

# %%
# Total costs

# %%
# Total gross profit = total sales - total costs

# %% [markdown]
# Make a new column in sales which contains gross profit by row

# %%
# TODO: create a new column in sales called GrossProfit

# %%
sales

# %% [markdown]
# # Exercise 4
# Find the top 5 largest orders placed by direct customers

# %%
sales['CustomerKey']

# %%
# Filter out resellers
# (rows where CustomerKey is -1 are reseller orders, not direct customers)

# %%
# TODO: check how often each direct customer appears using value_counts

# %%
# TODO - METHOD 1: sort sales_customer by SalesAmount descending and display
# the top 5 orders, keeping CustomerKey, SalesAmount, and GrossProfit

# %%
# TODO - METHOD 2: add an AmountRank column using rank() on SalesAmount
# (largest order = rank 1), then filter to the rows where the rank is 5 or less

# %% [markdown]
# Additional Exercise: Find the first and last names of the customers who placed these orders

# %%
# TODO: look up one of the top customers in the customer table using a
# boolean mask on CustomerKey

# %%
# TODO: look up all five at once: build a list of the five CustomerKey values
# from Method 1, then use isin() to build a boolean mask that matches any of
# them
