# %% [markdown]
# # Week 3, day 1 (afternoon) — Extra practice 01: Series   (L01)
#
# A second pass at worksheet 01. Same ideas, different data — the real sales file
# instead of three invented students.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 01 — Series. Run this once.
import pandas as pd

sales = pd.read_csv("../data/sales.csv")
profit = sales["Profit"]
region = sales["Region"]

print("rows:", len(sales))
print(profit.head())

# %% [markdown]
# ### Question 1
#
# Print `profit.dtype`, `profit.name`, and the first three values. Then print `type(profit)` to confirm a single column really is a Series.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print `profit.sum()`, `.mean()`, `.min()` and `.max()`, each labelled and rounded to 2 decimal places.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Some orders lose money. Count how many have negative `Profit`, and print that as a percentage of all orders.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Print the total profit of the loss-making orders and the total of the profitable ones. Then confirm the two add back up to `profit.sum()`.
# > **NOTE:** check the addition with `round(...)` on both sides, not `==` on the raw floats.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# `region` is a text Series. Print its `.dtype`, `.nunique()`, and `.value_counts()`. Then print `.unique()` and note the order the values come back in.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Build a Series indexed by something meaningful: `by_region = sales.groupby("Region")["Sales"].sum()`. Print it, its index, and then look up `by_region["Yukon"]` by label.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Sort `by_region` descending and print the top three. Then print what share of total sales the top three regions account for.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, look up a region that is not in the data — remember how it is spelled in this file. Print `by_region["Prairie"]`. **This is supposed to fail.**
# > **NOTE:** the file spells it `Prarie`. The correct English spelling is the one that raises.

# %%
############################
## Your Code Here
############################
