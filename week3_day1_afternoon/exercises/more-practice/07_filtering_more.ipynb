# %% [markdown]
# # Week 3, day 1 (afternoon) — Extra practice 07: Filtering   (L02)
#
# A second pass at worksheet 07. More conditions, combined more ways, on the same
# 300 real orders.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 07 — Filtering. Run this once.
import pandas as pd

sales = pd.read_csv("../data/sales.csv", parse_dates=["OrderDate"])

print("rows:", len(sales))
print("categories:", list(sales["Category"].unique()))
print("ship modes:", list(sales["ShipMode"].unique()))

# %% [markdown]
# ### Question 1
#
# Count the orders that are both `Technology` and shipped by `Express Air`. Then count each condition on its own.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Count the orders that are `Technology` but **not** `Express Air`, two ways: with `&` and `~`, and by subtracting the counts from Q1. Confirm they agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Filter on a date now that `OrderDate` is parsed: count the orders placed in 2012, and print the earliest and latest dates in that subset.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Combine a date range with a value threshold: count orders from 2011 onwards with `Sales` over 2000, and print their total `Sales`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Use `.isin()` on two columns at once: count orders whose `ShipMode` is `Regular Air` or `Delivery Truck` **and** whose `Category` is not `Office Supplies`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Find the rows where `Profit` is negative but `Sales` is above the median. Print how many, and their mean `Discount`. Then print the mean `Discount` of everything else, and compare.
# > **NOTE:** two means computed from real subsets. Before you conclude anything, look at how many rows each is built from.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Filtering returns a copy. Take `big = sales[sales["Sales"] > 5000]`, then set `big["Flag"] = True` and print `"Flag" in sales.columns`. Then do it the supported way with `.loc` on the original and check again.
# > **NOTE:** worksheet 06 Q2's lesson, in its most confusing form — writing into a filtered frame.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, combine two masks with Python's `or` instead of `|`: run `sales[(sales["Category"] == "Technology") or (sales["Sales"] > 5000)]`. **This is supposed to fail.**

# %%
############################
## Your Code Here
############################
