# %% [markdown]
# # Week 3, day 1 (afternoon) — Extra practice 11: Reading files   (L03)
#
# A second pass at worksheet 11. Same four files, different questions — mostly
# about proving a load was correct rather than assuming it.
#
# **Question 8 is supposed to raise an error.**

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Extra practice 11 — Reading files. Run this once.
import pandas as pd

EXPECTED_COLUMNS = ["OrderID", "OrderDate", "Region", "Category", "Product",
                    "ShipMode", "Quantity", "Sales", "Discount", "Profit"]
EXPECTED_ROWS = 300

print("we expect %d rows and %d columns" % (EXPECTED_ROWS, len(EXPECTED_COLUMNS)))

# %% [markdown]
# ### Question 1
#
# Write a `check(df)` function that returns `True` only if the frame has the expected row count and exactly the expected columns in order. Run it on `pd.read_csv("../data/sales.csv")`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Run the same `check` against all four `skiprows` readings of `../data/sales_report.csv` — 2, 3, 4 and 5 — and print which values pass.
# > **NOTE:** this is worksheet 11 Q4 turned into a test. The value of the test is that it fails where reading the output by eye would not.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Prove the TSV and the CSV hold the same data: load both correctly and compare with `.equals()`. Then compare their file sizes on disk with `os.path.getsize` and explain the difference.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 4
#
# Count how many `Product` values contain a comma, and print two of them. Then confirm they survived the round trip by checking one value is identical in both frames.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Load `../data/sales_messy.csv` correctly, then write a small report: for every column with missing values, print the column, the count, and the percentage of the file.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Show the cost of forgetting `na_values`: load the messy file without it, and print the dtype of every column alongside the dtype the clean file gives. Print only the columns where they differ.
# > **NOTE:** a dtype comparison is a cheaper and more reliable load check than eyeballing `head()`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Write a subset out and read it back. Take the 2012 orders, write them to `/tmp/y2012.csv` with `index=False`, read them back and confirm the shape and the `Sales` total round-trip.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Finally, ask for a column that is not in the file: `pd.read_csv("../data/sales.csv", usecols=["OrderID", "Revenue"])`. **This is supposed to fail.**
# > **NOTE:** `usecols` validates its argument against the header. That is a good thing — compare it with `drop(errors="ignore")` from worksheet 06.

# %%
############################
## Your Code Here
############################
