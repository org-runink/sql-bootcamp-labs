# %% [markdown]
# # Week 3, day 1 (afternoon) — Worksheet 07: Filtering   (L02)
#
# Filtering keeps the rows where a condition is true. One condition is easy. The
# sheet gets interesting when you need two, because the operators you would reach
# for from ordinary Python are the wrong ones — and one of them is an error.
#
# This is the first sheet on the real sales file. Run the setup cell once, then
# work down. **Question 10 is supposed to raise an error.**
#
# Lecture reference: `[Python_Pandas_L02]_Pandas_core_functionalities.pdf`,
# slides 14–17.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 07 — Filtering. Run this once.
import pandas as pd

sales = pd.read_csv("data/sales.csv")

print("shape:", sales.shape)
print("columns:", list(sales.columns))
print()
print(sales[["OrderID", "Region", "Category", "Quantity", "Sales"]].head())

# %% [markdown]
# PART A — one condition

# %% [markdown]
# ### Question 1
#
# Print how many orders have `Sales` above 1000: build the mask `sales["Sales"] > 1000`, print its `.sum()`, then print the first five matching rows.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# Print the number of rows for each region with `sales["Region"].value_counts()`. Then filter to Ontario only and confirm the row count matches what `value_counts` reported.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Filtering keeps the original index. Filter to the `West` region, print the first eight surviving labels and the first three rows. Then print `west.iloc[0]["OrderID"]` alongside `sales.iloc[0]["OrderID"]` and say whether position `0` means the same order in both.
# > **NOTE:** the same lesson as worksheet 04 Q8, now on 300 real rows instead of three invented ones. Try it with Ontario too — this file happens to start with the Ontario rows, so that filter hides the effect entirely.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — more than one condition

# %% [markdown]
# ### Question 4
#
# Combine two conditions with `&`, remembering the parentheses: print the number of rows where `Region` is Ontario **and** `Sales` is over 1000.
# > **NOTE:** each condition must be wrapped in its own parentheses. `&` binds tighter than `>`, so without them Pandas sees something quite different.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Now use `|` for 'or': count the rows where `Category` is `Technology` **or** `Sales` is over 3000. Then count each condition separately and check whether the two counts add up to the `or` count.
# > **NOTE:** they will not add up, and the gap is the rows that satisfy both. That gap is the reason you cannot answer 'or' questions by adding.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Use `~` to negate: print the number of rows that are **not** in Ontario, two ways — with `~(sales["Region"] == "Ontario")` and with `sales["Region"] != "Ontario"`. Confirm they agree.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Use `.isin()` for a set of values: count rows where `Region` is one of `["Ontario", "West", "Quebec"]`. Then write the same thing with three `|` conditions and confirm the counts match.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 8
#
# Count orders with `Quantity` between 10 and 20, two ways: with `.between(10, 20)`, and with `(sales["Quantity"] >= 10) & (sales["Quantity"] <= 20)`. Then try `.between(10, 20, inclusive="neither")` and compare all three counts.
# > **NOTE:** 'between 10 and 20' is ambiguous English. Two of these three answers are defensible readings of the same sentence.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Filter and aggregate in one line: print the total `Sales` for Ontario orders over 1000, and the number of rows behind that total. Then print the mean, and say why quoting the mean without the count would be misleading.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, combine two conditions with Python's `and` instead of `&`: run `sales[(sales["Region"] == "Ontario") and (sales["Sales"] > 1000)]`. **This is supposed to fail.** Read the exception message carefully — it tells you exactly what to use instead.
# > **NOTE:** `and` is the word English uses, and it is the wrong operator here. Q4 is the right one.

# %%
############################
## Your Code Here
############################
