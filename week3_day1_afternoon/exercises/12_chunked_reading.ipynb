# %% [markdown]
# # Week 3, day 1 (afternoon) — Worksheet 12: Reading files in chunks   (L03)
#
# `chunksize` turns `read_csv` into an iterator, so you can process a file larger
# than memory a batch at a time. The mechanics are easy. The interesting part is
# that processing the same numbers in a different order does not always give the
# same answer.
#
# Run the setup cell once, then work down. **Question 10 is supposed to raise an
# error** — that is the answer, not a mistake.
#
# Lecture reference: `[Python_Pandas_L03]_reading_and_writing_data_with_Pandas.pdf`,
# slides 11–14.

# %% [markdown]
# Run this cell once to set up the data. Then work down the sheet.

# %%
# Worksheet 12 — Chunked reading. Run this once.
import pandas as pd

# The full file: every one of the 1,093 orders, not the 300-row sample.
PATH = "data/big_sales.csv"

whole = pd.read_csv(PATH)
print("whole file:", whole.shape)
print("Sales column dtype:", whole["Sales"].dtype)

# %% [markdown]
# PART A — the mechanics

# %% [markdown]
# ### Question 1
#
# Run `reader = pd.read_csv(PATH, chunksize=250)` and print `type(reader)`. Then loop over it, printing each chunk's shape, and count the chunks.
# > **NOTE:** the object you get back is not a DataFrame. Nothing has been read yet at the point you create it.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 2
#
# The last chunk is smaller than the rest. Print `1093 / 250` and the size of the final chunk, and confirm the chunk sizes add back up to 1093.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 3
#
# Accumulate a count across chunks: loop and add up `len(chunk)` for each, then compare with `len(whole)`.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART B — the same sum, two ways

# %% [markdown]
# ### Question 4
#
# Now sum the `Sales` column across chunks, exactly as the deck's slide does: `total = 0`, then `total += chunk["Sales"].sum()` for each chunk. Print the result with `repr()`.
# > **NOTE:** use `repr()`, not `print()` of the number alone. You need every digit for the next question.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 5
#
# Now sum the same column in one go: print `repr(whole["Sales"].sum())`. Compare the two numbers digit by digit, and print whether they are equal.
# > **NOTE:** same file, same column, same addition. Nothing was filtered and nothing was missing.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 6
#
# Show that it is the *order* of addition that matters, not the chunking. Sum `whole["Sales"]` again after sorting it, and compare with the unsorted sum.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 7
#
# Decide whether it matters. Print the two totals rounded to 2 decimal places, and print the difference as a fraction of the total.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# PART C — filtering while you stream

# %% [markdown]
# ### Question 8
#
# Use the deck's `pd.concat` pattern: collect only the rows with `Sales` over 3000 from each chunk into a list, then concatenate with `ignore_index=True`. Print the shape and compare with filtering `whole` directly.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 9
#
# Look at what `ignore_index=True` changed: repeat Q8 without it and print the first 12 index labels of each version. Check whether the un-renumbered index is still unique, then try `kept.loc[0]` inside a `try`.
# > **NOTE:** each chunk carries its own slice of the original index, so the labels survive. Whether that is a problem depends entirely on what you do next.

# %%
############################
## Your Code Here
############################

# %% [markdown]
# ### Question 10
#
# Finally, try to use the chunk iterator twice. Create `reader = pd.read_csv(PATH, chunksize=250)`, consume it fully in one loop, then call `next(reader)`. **This is supposed to fail.** Read the exception.
# > **NOTE:** this is why every question above re-created the reader instead of reusing one.

# %%
############################
## Your Code Here
############################
