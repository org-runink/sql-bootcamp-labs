# %% [markdown]
# # __      __          ____    ___                       __  ____              __
#
# /\ \  __/\ \        /\  _`\ /\_ \                     /\ \/\  _`\           /\ \__
# \ \ \/\ \ \ \     __\ \ \/\_\\/\ \     ___   __  __   \_\ \ \ \/\ \     __  \ \ ,_\    __
# \ \ \ \ \ \ \  /'__`\ \ \/_/_\ \ \   / __`\/\ \/\ \  /'_` \ \ \ \ \  /'__`\ \ \ \/  /'__`\
# \ \ \_/ \_\ \ /\  __/\ \ \L\ \\_\ \_/\ \L\ \ \ \_\ \/\ \L\ \ \ \_\ \/\ \L\._\ \ \_\/\ \L\._\
# \ `\___x___/\ \____\\ \____//\____\ \____/\ \____/\ \___,_\ \____/\ \__/\.\_\\ \__\ \__/\.\_\
# ' \/__//__/  \/____/ \/___/ \/____/\/___/  \/___/  \/__,_ /\/___/  \/__/\/_/ \/__/\/__/\/_/
#  Week 2, day 2 (afternoon) — Worksheet 07 SOLUTIONS: subqueries   (L08)
#  File: Subqueries
#  Developed by: WeCloudData

# %% [markdown]
# Run this once to connect. Then every `%%sql` cell below works.

# %%
# %load_ext sql
# %config SqlMagic.autocommit = True
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = False
# %sql mysql+pymysql://root:123456@mysql:3306/?local_infile=1

# %% [markdown]
# ## Check Database Tables

# %% [markdown]
# List databases

# %%
# %%sql
# SHOW DATABASES;

# %% [markdown]
# Select default database

# %%
# %%sql
# USE company;

# %% [markdown]
# Check selected database

# %%
# %%sql
# SELECT DATABASE();

# %% [markdown]
# ## Subqueries

# %% [markdown]
# ### Question 1
#
# What is the highest performance score?

# %%
# %%sql
# SELECT MAX(performance)
# FROM review;

# %% [markdown]
# ### Question 2
#
# Which employee(s) had the highest performance score?

# %%
# %%sql
# SELECT name as employee_id, performance
# FROM review
# WHERE performance = (SELECT MAX(performance) FROM review);

# %% [markdown]
# ### Question 3
#
# What is the average salary of employees with the highest performance score?

# %%
# %%sql
# SELECT AVG(salary) AS avg_salary_high_performance
# FROM employee
# WHERE employee_id IN (
#     SELECT name as employee_id
#     FROM review
#     WHERE performance = (SELECT MAX(performance) FROM review)
# );

# %% [markdown]
# ## EXERCISE

# %% [markdown]
# Use superstore data to answer the following questions

# %%
# %%sql
# USE superstore;

# %% [markdown]
# ### Question 1
#
# What was the total Sales loss due to returned products?
# > **Hint:** Total sales loss is calculated by summing the 'Sales' from the 'orders' table

# %%
# %%sql
# SELECT SUM(Sales) as tot_loss
# FROM orders o
# WHERE OrderID IN (SELECT OrderID FROM returns WHERE Status = 'Returned');

# %% [markdown]
# ### Question 2
#
# What is the highest single-day total sales number?
# > **Hint:** The subquery calculates the total sales per day, and the outer query selects the highest total.

# %%
# %%sql
# SELECT OrderDate, total_sales
# FROM (
#     SELECT OrderDate, SUM(Sales) AS total_sales
#     FROM orders
#     GROUP BY OrderDate
# ) AS daily_sales
# ORDER BY total_sales DESC
# LIMIT 1;
