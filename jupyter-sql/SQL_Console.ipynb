# %% [markdown]
# # SQL Bootcamp Lab — SQL Console
#
# This notebook is a lightweight SQL console for the `mysql-lan` database. The connection below is already configured — just run it once, then write your queries in `%%sql` cells further down. You shouldn't need any other Python in this notebook; every exercise can be done in SQL.

# %%
# %load_ext sql
# %config SqlMagic.autocommit = True
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = False
# %sql mysql+pymysql://root:123456@mysql:3306/?local_infile=1

# %% [markdown]
# ## Try it
#
# Every query cell below starts with `%%sql` on its own line — that tells the notebook "run this cell as SQL against mysql-lan," not as Python.

# %%
# %%sql
# SHOW DATABASES;

# %%
# %%sql
# USE superstore;
# SELECT COUNT(*) FROM customers;

# %%
# %%sql
# -- Write your own query here, e.g.:
# SELECT * FROM superstore.products LIMIT 5;
